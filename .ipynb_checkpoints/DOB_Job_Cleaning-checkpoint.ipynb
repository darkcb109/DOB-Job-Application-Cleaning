# %%
import openclean
import glob
import pandas as pd
import pyspark 
import numpy as np

# %%
pyspark.__version__
# Out:
# '3.2.0'

# %%
np.__version__
# Out:
# '1.21.4'

# %%
pd.__version__
# Out:
# '1.3.4'

# %%
import glob

# %%
glob.glob("*")
# Out:
# ['DOB_Job_Application_Filings.csv',
#  'DOB_Job_Cleaning mine.ipynb',
#  'DOB_Job_Cleaning.ipynb',
#  'ic3t-wcy2.tsv.gz',
#  'README.md',
#  'wordcount.py']

# %% [markdown]
# ## Import out dataset

# %%
df  = pd.read_csv('./DOB_Job_Application_Filings.csv', dtype='object')

# %% [markdown]
# ### Get some basic info about the dataset columns

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1774873 entries, 0 to 1774872
# Data columns (total 96 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   Job #                          1774873 non-null  object
#  1   Doc #                          1774873 non-null  object
#  2   Borough                        1774873 non-null  object
#  3   House #                        1774867 non-null  object
#  4   Street Name                    1774867 non-null  object
#  5   Block                          1774121 non-null  object
#  6   Lot                            1774117 non-null  object
#  7   Bin #                          1774873 non-null  object
#  8   Job Type                       1774873 non-null  object
#  9   Job Status                     1774873 non-null  object
#  10  Job Status Descrp              1774873 non-null  object
#  11  Latest Action Date             1774873 non-null  object
#  12  Building Type                  1774873 non-null  object
#  13  Community - Board              1773578 non-null  object
#  14  Cluster                        1131380 non-null  object
#  15  Landmarked                     1670754 non-null  object
#  16  Adult Estab                    1581426 non-null  object
#  17  Loft Board                     1400834 non-null  object
#  18  City Owned                     149402 non-null   object
#  19  Little e                       1046451 non-null  object
#  20  PC Filed                       602206 non-null   object
#  21  eFiling Filed                  1081520 non-null  object
#  22  Plumbing                       555711 non-null   object
#  23  Mechanical                     284299 non-null   object
#  24  Boiler                         49959 non-null    object
#  25  Fuel Burning                   21451 non-null    object
#  26  Fuel Storage                   14255 non-null    object
#  27  Standpipe                      14386 non-null    object
#  28  Sprinkler                      116387 non-null   object
#  29  Fire Alarm                     87703 non-null    object
#  30  Equipment                      306812 non-null   object
#  31  Fire Suppression               43370 non-null    object
#  32  Curb Cut                       61213 non-null    object
#  33  Other                          1041766 non-null  object
#  34  Other Description              1039964 non-null  object
#  35  Applicant's First Name         1774814 non-null  object
#  36  Applicant's Last Name          1774861 non-null  object
#  37  Applicant Professional Title   1774790 non-null  object
#  38  Applicant License #            1725704 non-null  object
#  39  Professional Cert              1396678 non-null  object
#  40  Pre- Filing Date               1774873 non-null  object
#  41  Paid                           1765805 non-null  object
#  42  Fully Paid                     1768295 non-null  object
#  43  Assigned                       1195882 non-null  object
#  44  Approved                       1444999 non-null  object
#  45  Fully Permitted                1309748 non-null  object
#  46  Initial Cost                   1774873 non-null  object
#  47  Total Est. Fee                 1774873 non-null  object
#  48  Fee Status                     1774873 non-null  object
#  49  Existing Zoning Sqft           1774873 non-null  object
#  50  Proposed Zoning Sqft           1774873 non-null  object
#  51  Horizontal Enlrgmt             45822 non-null    object
#  52  Vertical Enlrgmt               32149 non-null    object
#  53  Enlargement SQ Footage         1774873 non-null  object
#  54  Street Frontage                1774873 non-null  object
#  55  ExistingNo. of Stories         1774873 non-null  object
#  56  Proposed No. of Stories        1774873 non-null  object
#  57  Existing Height                1774873 non-null  object
#  58  Proposed Height                1774873 non-null  object
#  59  Existing Dwelling Units        644113 non-null   object
#  60  Proposed Dwelling Units        918750 non-null   object
#  61  Existing Occupancy             1270615 non-null  object
#  62  Proposed Occupancy             1062769 non-null  object
#  63  Site Fill                      1425022 non-null  object
#  64  Zoning Dist1                   1440085 non-null  object
#  65  Zoning Dist2                   193634 non-null   object
#  66  Zoning Dist3                   10263 non-null    object
#  67  Special District 1             262140 non-null   object
#  68  Special District 2             79918 non-null    object
#  69  Owner Type                     1701479 non-null  object
#  70  Non-Profit                     1703326 non-null  object
#  71  Owner's First Name             1774593 non-null  object
#  72  Owner's Last Name              1774658 non-null  object
#  73  Owner's Business Name          1424258 non-null  object
#  74  Owner's House Number           1003 non-null     object
#  75  Owner'sHouse Street Name       1003 non-null     object
#  76  City                           1003 non-null     object
#  77  State                          1003 non-null     object
#  78  Zip                            1001 non-null     object
#  79  Owner'sPhone #                 1763406 non-null  object
#  80  Job Description                1594531 non-null  object
#  81  DOBRunDate                     1774873 non-null  object
#  82  JOB_S1_NO                      1774873 non-null  object
#  83  TOTAL_CONSTRUCTION_FLOOR_AREA  1774873 non-null  object
#  84  WITHDRAWAL_FLAG                1774873 non-null  object
#  85  SIGNOFF_DATE                   1063365 non-null  object
#  86  SPECIAL_ACTION_STATUS          1754670 non-null  object
#  87  SPECIAL_ACTION_DATE            172200 non-null   object
#  88  BUILDING_CLASS                 1768455 non-null  object
#  89  JOB_NO_GOOD_COUNT              1774873 non-null  object
#  90  GIS_LATITUDE                   1769216 non-null  object
#  91  GIS_LONGITUDE                  1769216 non-null  object
#  92  GIS_COUNCIL_DISTRICT           1769216 non-null  object
#  93  GIS_CENSUS_TRACT               1769216 non-null  object
#  94  GIS_NTA_NAME                   1769216 non-null  object
#  95  GIS_BIN                        1752744 non-null  object
# dtypes: object(96)
# memory usage: 1.3+ GB

# %% [markdown]
# If any rows are complete duplicates, drop them

# %%
df = df.drop_duplicates()

# %% [markdown]
# Take an a look at some of the rows to get an idea of what the datset looks like

# %%
df
# Out:
#              Job # Doc #   Borough House #       Street Name  Block    Lot  \
# 0        440673512    01    QUEENS   10040        222 STREET  10780  00019
# 1        421133972    02    QUEENS   88-36      139TH STREET  09620  00033
# 2        421133972    03    QUEENS   88-36      139TH STREET  09620  00033
# 3        210182309    02     BRONX      97   WEST 169 STREET  02519  00027
# 4        210182309    03     BRONX      97   WEST 169 STREET  02519  00027
# ...            ...   ...       ...     ...               ...    ...    ...
# 1774868  302042858    01  BROOKLYN    2770      OCEAN AVENUE  07404  00020
# 1774869  302042867    01  BROOKLYN     313         76 STREET  05940  00078
# 1774870  302042876    01  BROOKLYN    1658         66 STREET  05559  00033
# 1774871  302042885    01  BROOKLYN     173  LEXINGTON AVENUE  01968  00043
# 1774872  302042894    01  BROOKLYN      52   LOMBARDY STREET  02834  00034
#
#            Bin # Job Type Job Status  ... SPECIAL_ACTION_STATUS  \
# 0        4231025       A2          R  ...                     N
# 1        4623670       NB          P  ...                     N
# 2        4623670       NB          P  ...                     N
# 3        2130622       NB          P  ...                     N
# 4        2130622       NB          P  ...                     N
# ...          ...      ...        ...  ...                   ...
# 1774868  3202124       A3          X  ...                     N
# 1774869  3148750       A2          R  ...                     N
# 1774870  3134197       A2          X  ...                     N
# 1774871  3056361       A2          Q  ...                     N
# 1774872  3069864       A2          X  ...                     N
#
#         SPECIAL_ACTION_DATE BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# 0                       NaN             A1                 0    40.714365
# 1                       NaN             G7                 0    40.703428
# 2                       NaN             G7                 0    40.703428
# 3                       NaN             V0                 0    40.839538
# 4                       NaN             V0                 0    40.839538
# ...                     ...            ...               ...          ...
# 1774868                 NaN             D1                 0    40.593831
# 1774869                 NaN             B1                 0    40.630611
# 1774870                 NaN             C3                 0    40.620486
# 1774871                 NaN             F9                 0    40.687159
# 1774872                 NaN             E1                 0    40.722087
#
#         GIS_LONGITUDE GIS_COUNCIL_DISTRICT GIS_CENSUS_TRACT  \
# 0          -73.731171                   27              568
# 1          -73.813796                   24              214
# 2          -73.813796                   24              214
# 3          -73.923177                   16              211
# 4          -73.923177                   16              211
# ...               ...                  ...              ...
# 1774868    -73.950368                   48              592
# 1774869    -74.027435                   43               66
# 1774870    -73.994067                   38              252
# 1774871    -73.955516                   36              233
# 1774872    -73.939063                   34              449
#
#                                            GIS_NTA_NAME  GIS_BIN
# 0                                        Queens Village  4231025
# 1                               Briarwood-Jamaica Hills      NaN
# 2                               Briarwood-Jamaica Hills      NaN
# 3                                            Highbridge      NaN
# 4                                            Highbridge      NaN
# ...                                                 ...      ...
# 1774868  Sheepshead Bay-Gerritsen Beach-Manhattan Beach  3202124
# 1774869                                       Bay Ridge  3148750
# 1774870                                Bensonhurst West  3134197
# 1774871                                         Bedford  3056361
# 1774872                               East Williamsburg  3069864
#
# [1774873 rows x 96 columns]

# %% [markdown]
# ## Describe columns in groups so they fit on screen

# %%
df[df.columns[:20]].describe()
# Out:
#             Job #    Doc #    Borough  House # Street Name    Block      Lot  \
# count     1774873  1774873    1774873  1774867     1774867  1774121  1774117
# unique    1584321       20          5    35646       29553    13816     1971
# top     103408705       01  MANHATTAN        1    BROADWAY    00016    00001
# freq           20  1583895     775342    17359       52273     6808   216451
#
#           Bin # Job Type Job Status Job Status Descrp Latest Action Date  \
# count   1774873  1774873    1774873           1774873            1774873
# unique   363786        9         17                17               7374
# top     1015862       A2          X        SIGNED OFF         10/13/2017
# freq       2413  1117095    1050470           1050470                793
#
#        Building Type Community - Board  Cluster Landmarked Adult Estab  \
# count        1774873           1773578  1131380    1670754     1581426
# unique             2               106        2          4           2
# top           OTHERS               105        N          N           N
# freq         1389737            210723  1122909    1461499     1581253
#
#        Loft Board City Owned Little e
# count     1400834     149402  1046451
# unique          2          4        5
# top             N          Y        N
# freq      1393398     149399   989667

# %%
# Notes:
# Building Type looks binary and has 2 values + maybe NAN
# Cluster looks binary and has 2 values + maybe NAN
# Landmarked looks binary and has 4 values + maybe NAN
# Adult Establishment looks binary and has 2 values + maybe NAN
# Loft Board looks binary and has 2 values + maybe NAN
# City Owned looks binary and has 4 values + maybe NAN
# Little e looks binary and has 5 values + maybe NAN

# %%
df[df.columns[20:40]].describe()
# Out:
#        PC Filed eFiling Filed Plumbing Mechanical Boiler Fuel Burning  \
# count    602206       1081520   555711     284299  49959        21451
# unique        2             2        1          1      1            1
# top           Y             Y        X          X      X            X
# freq     384720       1081518   555711     284299  49959        21451
#
#        Fuel Storage Standpipe Sprinkler Fire Alarm Equipment Fire Suppression  \
# count         14255     14386    116387      87703    306812            43370
# unique            2         1         1          1         1                1
# top               X         X         X          X         X                X
# freq          14254     14386    116387      87703    306812            43370
#
#        Curb Cut    Other Other Description Applicant's First Name  \
# count     61213  1041766           1039964                1774814
# unique        1        1             16626                  17354
# top           X        X      GEN. CONSTR.                MICHAEL
# freq      61213  1041766            316607                  51059
#
#        Applicant's Last Name Applicant Professional Title Applicant License #  \
# count                1774861                      1774790             1725704
# unique                 35220                          913               27089
# top                    HOQUE                           PE              083278
# freq                   19159                       924260               19195
#
#        Professional Cert
# count            1396678
# unique                 5
# top                    Y
# freq              859594

# %%
# PC Filed -- Other all look binary, and have 1-2 values + maybe NAN
#
# Take a look at Other Description for weird strings

#  Lots of the same First and Last name

# Check names and titles

# APPLICATNT LICENCSE # NEEDS TO BE A STRING TO PERSERVE THE 0 ON IT (PROBABLY)

# Professional Cert looks binary and has 5 values + maybe NAN

# %%
df[df.columns[40:60]].describe()
# Out:
#        Pre- Filing Date        Paid  Fully Paid    Assigned    Approved  \
# count           1774873     1765805     1768295     1195882     1444999
# unique             6623        6642        6709        6782        6888
# top          06/28/2019  06/28/2019  06/28/2019  07/01/2009  06/26/2008
# freq               1717        1700        1702         575         663
#
#        Fully Permitted Initial Cost Total Est. Fee Fee Status  \
# count          1309748      1774873        1774873    1774873
# unique            6122        98627          93203          3
# top         11/12/2015        $0.00        $100.00   STANDARD
# freq               487       477561         144802    1600970
#
#        Existing Zoning Sqft Proposed Zoning Sqft Horizontal Enlrgmt  \
# count               1774873              1774873              45822
# unique                18057                24620                  2
# top                       0                    0                  Y
# freq                1704887              1673008              45815
#
#        Vertical Enlrgmt Enlargement SQ Footage Street Frontage  \
# count             32149                1774873         1774873
# unique                2                   6970            1184
# top                   Y                      0               0
# freq              32140                1713529         1677540
#
#        ExistingNo. of Stories Proposed No. of Stories Existing Height  \
# count                 1774873                 1774873         1774873
# unique                    152                     319             945
# top                         0                       0               0
# freq                   821455                  396318          821473
#
#        Proposed Height Existing Dwelling Units
# count          1774873                  644113
# unique            1102                    1082
# top                  0                       1
# freq            454072                  117787

# %%
# Need to convert date columns to pd.datetime
# RENAME PAID TO PAID DATE
# RENAME FULLY PAID TO FULLY PAID DATE
# RENAME ASSISGNED TO ASSIGNED DATE
# RENAME APPROVED TO APPROVED DATE

# CHECK COHERENCE OF PAID DATE <= FULLY PAID DATE
# CHECK COHERENCE OF PRE FILING DATE <= PAID DATE
# CHECK COHERENCE OF ASSIGNED DATE <= APPROVED DATE
# 

# REMOVE $ FROM Initial Cost and Total Estimated Fee, and put them in column name, convert values to floats

# Check What fee status is

# Check Existing Zoning Sqft, Propsed Zoning Sqft, Enlargement SQ Footage for reasonable values
# Change either Sqft to SQ Footage or vvice-versa

# Horizontal Enlargement and Vertical Enlargement are booleans + NAN
# Change Enlrgmt to Enlargement

#Chcek ExisitngNo. of Stories and Proposed # of Stories for reasonableness
# Add space between Existing and No.
# Change either Job# to Job No. or vice versa
# maybe just change all the No./# to "number"

# Check Existing and proposed height for reasonableness. Add unit to column name

# check Existing Dwelling Units for reasonableness

# %%
df[df.columns[60:80]].describe()
# Out:
#        Proposed Dwelling Units Existing Occupancy Proposed Occupancy  \
# count                   918750            1270615            1062769
# unique                    1173                 47                 49
# top                          1                RES                RES
# freq                    172062             411653             289997
#
#              Site Fill Zoning Dist1 Zoning Dist2 Zoning Dist3  \
# count          1425022      1440085       193634        10263
# unique               5          229          196          135
# top     NOT APPLICABLE           R6          R8B         C6-6
# freq            717129       149653        19305         1554
#
#        Special District 1 Special District 2   Owner Type Non-Profit  \
# count              262140              79918      1701479    1703326
# unique                116                 15           14          2
# top                   MID               POPS  CORPORATION          N
# freq                84262              27848       575535    1594188
#
#        Owner's First Name Owner's Last Name Owner's Business Name  \
# count             1774593           1774658               1424258
# unique              93118            156871                412722
# top               MICHAEL             SINGH                 OWNER
# freq                40957             23629                 11056
#
#        Owner's House Number Owner'sHouse Street Name     City  State    Zip  \
# count                  1003                     1003      1003  1003   1001
# unique                  549                      756       114     9    212
# top                       2     555 WEST 23RD STREET  BROOKLYN    NY  11201
# freq                     19                       17       309   981     46
#
#        Owner'sPhone #
# count         1763406
# unique         359280
# top        7184728000
# freq            12732

# %%
# check Proposed Dwelling Units
## Why does Existing Occupancy have fewer cats than Proposed Occupancy. Check those.

# What is Site Fill. 

# Get list of NYC ZOning Districts and Special Districts

# Checmk Owner Typer for spelling issues

# Non Profit is binary

# Check Owners's First and last name

# Owner'sBuisness Name should not be "OWNER"

# Owner's house number, streeet name, city, state and zip have almost no values

# Why is the same phone number so common

# %%
df[df.columns[80:100]].describe()
# Out:
#                                           Job Description  \
# count                                             1594531
# unique                                            1247253
# top     PROPOSED INSTALLATION OF HEAVY DUTY SIDEWALK S...
# freq                                                 3985
#
#                  DOBRunDate JOB_S1_NO TOTAL_CONSTRUCTION_FLOOR_AREA  \
# count               1774873   1774873                       1774873
# unique                  298   1774873                         26598
# top     04/28/2021 00:00:00   3294002                             0
# freq                1674972         1                       1619567
#
#        WITHDRAWAL_FLAG SIGNOFF_DATE SPECIAL_ACTION_STATUS SPECIAL_ACTION_DATE  \
# count          1774873      1063365               1754670              172200
# unique              13         5920                     4                6374
# top                  0   02/12/2018                     N          10/24/2012
# freq           1752667          603               1519423                5513
#
#        BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE GIS_LONGITUDE  \
# count         1768455           1774873      1769216       1769216
# unique            199                13       217561        228338
# top                R0                 0    40.748276    -73.984690
# freq           211273           1772958         2409          2413
#
#        GIS_COUNCIL_DISTRICT GIS_CENSUS_TRACT           GIS_NTA_NAME  GIS_BIN
# count               1769216          1769216                1769216  1752744
# unique                   51             1328                    194   342803
# top                       4                7  Midtown-Midtown South  3000000
# freq                 236661            16439                 153871    15627

# %%
# That is a lot of unique job descriptions

# Add spaces to DOB Run Date name
# make DOB Run Date a datetime

# What is Job_S1_NO. It uses underscores.

# All the remaining columns have ALL CAPS NAMES WITH UNDERSCORES 
# TOTAL_CONSTRUCTION_FLOOR_AREA, WITHDRAWAL_FLAG

# SIGNOFF_DATE needs to be datetime
# SPECIAL_ACTION_STATUS
# SPECIAL_ACTION_DATE needs to be datetime
# BUILDING_CLASS
# What is JOB_NO_GOOD_COUNT
#
# maybe need GIS DATA
# GIS_LATITUDE
# GIS_LONGITUDE
# GIS_COUNCIL_DISTRICT
# GIS_CENSUS_TRACT
# GIS_NTA_NAME
# GIS_BIN
#

# %%
df.columns
# Out:
# Index(['Job #', 'Doc #', 'Borough', 'House #', 'Street Name', 'Block', 'Lot',
#        'Bin #', 'Job Type', 'Job Status', 'Job Status Descrp',
#        'Latest Action Date', 'Building Type', 'Community - Board', 'Cluster',
#        'Landmarked', 'Adult Estab', 'Loft Board', 'City Owned', 'Little e',
#        'PC Filed', 'eFiling Filed', 'Plumbing', 'Mechanical', 'Boiler',
#        'Fuel Burning', 'Fuel Storage', 'Standpipe', 'Sprinkler', 'Fire Alarm',
#        'Equipment', 'Fire Suppression', 'Curb Cut', 'Other',
#        'Other Description', 'Applicant's First Name', 'Applicant's Last Name',
#        'Applicant Professional Title', 'Applicant License #',
#        'Professional Cert', 'Pre- Filing Date', 'Paid', 'Fully Paid',
#        'Assigned', 'Approved', 'Fully Permitted', 'Initial Cost',
#        'Total Est. Fee', 'Fee Status', 'Existing Zoning Sqft',
#        'Proposed Zoning Sqft', 'Horizontal Enlrgmt', 'Vertical Enlrgmt',
#        'Enlargement SQ Footage', 'Street Frontage', 'ExistingNo. of Stories',
#        'Proposed No. of Stories', 'Existing Height', 'Proposed Height',
#        'Existing Dwelling Units', 'Proposed Dwelling Units',
#        'Existing Occupancy', 'Proposed Occupancy', 'Site Fill', 'Zoning Dist1',
#        'Zoning Dist2', 'Zoning Dist3', 'Special District 1',
#        'Special District 2', 'Owner Type', 'Non-Profit', 'Owner's First Name',
#        'Owner's Last Name', 'Owner's Business Name', 'Owner's House Number',
#        'Owner'sHouse Street Name', 'City ', 'State', 'Zip', 'Owner'sPhone #',
#        'Job Description', 'DOBRunDate', 'JOB_S1_NO',
#        'TOTAL_CONSTRUCTION_FLOOR_AREA', 'WITHDRAWAL_FLAG', 'SIGNOFF_DATE',
#        'SPECIAL_ACTION_STATUS', 'SPECIAL_ACTION_DATE', 'BUILDING_CLASS',
#        'JOB_NO_GOOD_COUNT', 'GIS_LATITUDE', 'GIS_LONGITUDE',
#        'GIS_COUNCIL_DISTRICT', 'GIS_CENSUS_TRACT', 'GIS_NTA_NAME', 'GIS_BIN'],
#       dtype='object')

# %% [markdown]
# ## Renaming columns

# %%
df = df.rename(columns={
                          "Owner'sPhone #": "Owner's Phone #" 
                        , "Owner'sHouse Street Name": "Owner's House Street Name"
                        , "Paid": "Paid Date"
                        , "Fully Paid": "Fully Paid Date"
                        , "Assigned": "Assigned Date"
                        , "Approved": "Approved Date"
                        , "Job Status Descrp": "Job Status Description"
                        , "Community - Board": "Community Board"
                        , "Adult Estab": "Adult Establishment"
                        , "Pre- Filing Date": "Pre-Filing Date"
                        , "Total Est. Fee": "Total Estimated Fee"
                        , "Horizontal Enlrgmt": "Horizontal Enlargement"
                        , "Vertical Enlrgmt": "Vertical Enlargement"
                        , "ExistingNo. of Stories": "Existing # of Stories"
                        , "Proposed No. of Stories": "Proposed # of Stories"
                        , "Zoning Dist1": "Zoning District 1"
                        , "Zoning Dist2": "Zoning District 2"
                        , "Zoning Dist3": "Zoning District 3"
                        , "City ": "Owner's House City"
                        , "State": "Owner's House State"
                        , "Zip": "Owner's House Zip"
                        , "DOBRunDate": "DOB Run Date"
                       })

#Lower cased but not sure if this is necessary
'''
df = df.rename(columns={
                        , "JOB_S1_NO": "Job S1 #"
                        , "TOTAL_CONSTRUCTION_FLOOR_AREA": "Total Construction Floor Area"
                        , "WITHDRAWAL_FLAG": "Withdrawl Flag"
                        , "SIGNOFF_DATE": "Signoff Date"
                        , "SPECIAL_ACTION_STATUS": "Special Action Status"
                        , "SPECIAL_ACTION_DATE": "Special Action Date"
                        , "BUILDING_CLASS": "Building Class"
                        , "JOB_NO_GOOD_COUNT": "Job No Good Count"
                        , "GIS_LATITUDE": "GIS Latitude"
                        , "GIS_LONGITUDE": "GIS Longitude"
                        , "GIS_COUNCIL_DISTRICT": "GIS Council District"
                        , "GIS_CENSUS_TRACT": "GIS Census Tract"
                        , "GIS_NTA_NAME": "GIS NTA Name"
                        , "GIS_BIN": "GIS Bin"
                        })
'''
# Out:
# '\ndf = df.rename(columns={\n                        , "JOB_S1_NO": "Job S1 #"\n                        , "TOTAL_CONSTRUCTION_FLOOR_AREA": "Total Construction Floor Area"\n                        , "WITHDRAWAL_FLAG": "Withdrawl Flag"\n                        , "SIGNOFF_DATE": "Signoff Date"\n                        , "SPECIAL_ACTION_STATUS": "Special Action Status"\n                        , "SPECIAL_ACTION_DATE": "Special Action Date"\n                        , "BUILDING_CLASS": "Building Class"\n                        , "JOB_NO_GOOD_COUNT": "Job No Good Count"\n                        , "GIS_LATITUDE": "GIS Latitude"\n                        , "GIS_LONGITUDE": "GIS Longitude"\n                        , "GIS_COUNCIL_DISTRICT": "GIS Council District"\n                        , "GIS_CENSUS_TRACT": "GIS Census Tract"\n                        , "GIS_NTA_NAME": "GIS NTA Name"\n                        , "GIS_BIN": "GIS Bin"\n                        })\n'

# %% [markdown]
# #### Method to get an idea of the top 10 values of a column

# %%
def show_vals(column_name, show_rows=10, df=df):
    print("Top {} {}:\n".format(show_rows, column_name))
    print(df[column_name].value_counts(dropna=False)[:show_rows])
    print()

# %% [markdown]
# ### Examining Job #s

# %% [markdown]
# Some repition in the Job #'s, but nothing major. We will check some of the repeated Job #s to be sure they actually refer to the same jobs

# %%
df['Job #'].value_counts(dropna=False)
# Out:
# 103408705    20
# 122705000    13
# 120438240    13
# 320843110    12
# 302136203    11
#              ..
# 220173489     1
# 220173498     1
# 420542960     1
# 121002379     1
# 302042894     1
# Name: Job #, Length: 1584321, dtype: int64

# %% [markdown]
# Nothing weird looking here

# %%
df['Job #'].min()
# Out:
# '100321046'

# %%
df['Job #'].max()
# Out:
# '577777776'

# %% [markdown]
# No Job #s starting with 0, so there are integer values, unlike Doc # which has values 01, 02, etc.

# %%
df.loc[df['Job #'].str.startswith('0')]
# Out:
# Empty DataFrame
# Columns: [Job #, Doc #, Borough, House #, Street Name, Block, Lot, Bin #, Job Type, Job Status, Job Status Description, Latest Action Date, Building Type, Community Board, Cluster, Landmarked, Adult Establishment, Loft Board, City Owned, Little e, PC Filed, eFiling Filed, Plumbing, Mechanical, Boiler, Fuel Burning, Fuel Storage, Standpipe, Sprinkler, Fire Alarm, Equipment, Fire Suppression, Curb Cut, Other, Other Description, Applicant's First Name, Applicant's Last Name, Applicant Professional Title, Applicant License #, Professional Cert, Pre-Filing Date, Paid Date, Fully Paid Date, Assigned Date, Approved Date, Fully Permitted, Initial Cost, Total Estimated Fee, Fee Status, Existing Zoning Sqft, Proposed Zoning Sqft, Horizontal Enlargement, Vertical Enlargement, Enlargement SQ Footage, Street Frontage, Existing # of Stories, Proposed # of Stories, Existing Height, Proposed Height, Existing Dwelling Units, Proposed Dwelling Units, Existing Occupancy, Proposed Occupancy, Site Fill, Zoning District 1, Zoning District 2, Zoning District 3, Special District 1, Special District 2, Owner Type, Non-Profit, Owner's First Name, Owner's Last Name, Owner's Business Name, Owner's House Number, Owner's House Street Name, Owner's House City, Owner's House State, Owner's House Zip, Owner's Phone #, Job Description, DOB Run Date, JOB_S1_NO, TOTAL_CONSTRUCTION_FLOOR_AREA, WITHDRAWAL_FLAG, SIGNOFF_DATE, SPECIAL_ACTION_STATUS, SPECIAL_ACTION_DATE, BUILDING_CLASS, JOB_NO_GOOD_COUNT, GIS_LATITUDE, GIS_LONGITUDE, GIS_COUNCIL_DISTRICT, GIS_CENSUS_TRACT, GIS_NTA_NAME, GIS_BIN]
# Index: []
#
# [0 rows x 96 columns]

# %% [markdown]
# Fraction of Rows with unique job numbers

# %%
df['Job #'].nunique()/df['Job #'].count()
# Out:
# 0.8926390789650865

# %% [markdown]
# Group by Job # and check if latitude and longitude are the same all the same for the job, which would indicate different instances of the Job # all refer to the same Job.

# %%
group = df[['Job #', 'GIS_LATITUDE', 'GIS_LONGITUDE']].groupby('Job #')

# %% [markdown]
# This will take a little while to run

# %%
tranformed = group.aggregate(lambda x: x.unique().shape[0])

# %% [markdown]
# Jobs with multiple latitude and longitudes:

# %%
# 107 potential bad jobs
tranformed.loc[(tranformed['GIS_LATITUDE']!=1)
              |(tranformed['GIS_LONGITUDE']!=1)]
# Out:
#            GIS_LATITUDE  GIS_LONGITUDE
# Job #
# 102724759             2              2
# 102769489             2              2
# 102875569             2              2
# 102904467             2              2
# 103122372             2              2
# ...                 ...            ...
# 500592110             2              2
# 500592138             2              2
# 500592147             2              2
# 500592156             2              1
# 520305937             2              2
#
# [107 rows x 2 columns]

# %%
potential_bad_jobs = list(tranformed.loc[(tranformed['GIS_LATITUDE']!=1)
              |(tranformed['GIS_LONGITUDE']!=1)].index.unique())

# %% [markdown]
# Separate these into a temporary dataframe to play around with:

# %%
df_temp = df.loc[df['Job #'].isin(potential_bad_jobs)].copy()

# %%
df_temp = df_temp.sort_values(['Job #', 'GIS_LATITUDE', 'GIS_LONGITUDE'])

# %% [markdown]
# Most of these are just missing lat and long values.
#
# The others look to be Jobs that manage multiple houses/lots in a small area, so are probably correct

# %%
df_temp[df_temp.duplicated(subset=['Job #', 'Block', 'Lot', 'Bin #', 'Job Type'], keep=False)]
# Out:
#              Job # Doc #        Borough House #         Street Name  Block  \
# 1344104  102724759    01      MANHATTAN     111            8 AVENUE  00739
# 77082    102724759    03      MANHATTAN     NaN                 NaN  00739
# 77679    102724759    02      MANHATTAN     NaN                 NaN  00739
# 1378448  102769489    02      MANHATTAN    1130  ST NICHOLAS AVENUE  02124
# 1378455  102769489    03      MANHATTAN    1130  ST NICHOLAS AVENUE  02124
# ...            ...   ...            ...     ...                 ...    ...
# 262615   500461895    01  STATEN ISLAND    1135        WOODROW ROAD  06108
# 262616   500461895    02  STATEN ISLAND    1135       WOODWARD ROAD  06108
# 1133140  520305937    03  STATEN ISLAND    2636     HYLAN BOULEVARD  03969
# 11227    520305937    01  STATEN ISLAND    2636    HYLAND BOULEVARD  03969
# 1133139  520305937    02  STATEN ISLAND    2636    HYLAND BOULEVARD  03969
#
#            Lot    Bin # Job Type Job Status  ... SPECIAL_ACTION_STATUS  \
# 1344104  00001  1013043       A2          R  ...                     W
# 77082    00001  1013043       A2          P  ...                     W
# 77679    00001  1013043       A2          G  ...                     W
# 1378448  00021  1062989       NB          X  ...                     A
# 1378455  00021  1062989       NB          X  ...                     A
# ...        ...      ...      ...        ...  ...                   ...
# 262615   00059  5135616       NB          X  ...                     N
# 262616   00059  5135616       NB          X  ...                     A
# 1133140  00031  5171652       NB          R  ...                     N
# 11227    00031  5171652       NB          R  ...                     N
# 1133139  00031  5171652       NB          R  ...                     N
#
#         SPECIAL_ACTION_DATE BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# 1344104          05/17/2019             O6                 0    40.740704
# 77082            05/17/2019             O6                 0          NaN
# 77679            05/17/2019             O6                 0          NaN
# 1378448                 NaN             I9                 0    40.839949
# 1378455                 NaN             I9                 0    40.839949
# ...                     ...            ...               ...          ...
# 262615                  NaN             B2                 0    40.542311
# 262616                  NaN             B2                 0          NaN
# 1133140                 NaN             K6                 0    40.567461
# 11227                   NaN             K6                 0          NaN
# 1133139                 NaN             K6                 0          NaN
#
#         GIS_LONGITUDE GIS_COUNCIL_DISTRICT GIS_CENSUS_TRACT  \
# 1344104    -74.001844                    3               83
# 77082             NaN                  NaN              NaN
# 77679             NaN                  NaN              NaN
# 1378448    -73.939761                   10              251
# 1378455    -73.939761                   10              251
# ...               ...                  ...              ...
# 262615     -74.202647                   51            20801
# 262616            NaN                  NaN              NaN
# 1133140    -74.112766                   50            12804
# 11227             NaN                  NaN              NaN
# 1133139           NaN                  NaN              NaN
#
#                                        GIS_NTA_NAME  GIS_BIN
# 1344104  Hudson Yards-Chelsea-Flatiron-Union Square  1013043
# 77082                                           NaN      NaN
# 77679                                           NaN      NaN
# 1378448                    Washington Heights South  1062989
# 1378455                    Washington Heights South  1062989
# ...                                             ...      ...
# 262615                            Rossville-Woodrow  5135616
# 262616                                          NaN      NaN
# 1133140                      New Dorp-Midland Beach  5000000
# 11227                                           NaN      NaN
# 1133139                                         NaN      NaN
#
# [294 rows x 96 columns]

# %% [markdown]
# #### Later, after we have cleaned more values, we will fill these missing values by job #

# %% [markdown]
# Remove Jobs we know to be just missing data from the list of bad jobs

# %%
not_bad_jobs = df_temp[df_temp.duplicated(subset=['Job #', 'Block', 'Lot', 'Bin #', 'Job Type'], keep=False)]['Job #'].unique()

# %%
df_temp = df_temp.loc[~df_temp['Job #'].isin(not_bad_jobs)]

# %% [markdown]
# All of these are jobs that handle multiple lots or House #s, which explains why the lat/long change
#
# Job # 122171130 and 122222638 may be exact copies of each other though

# %%
df_temp
# Out:
#              Job # Doc #        Borough House #          Street Name  Block  \
# 44473    103128679    02      MANHATTAN    2700             BROADWAY  01875
# 1442320  103128679    01      MANHATTAN    2692             BROADWAY  01875
# 1468683  103403899    02      MANHATTAN    2700             BROADWAY  01875
# 1468682  103403899    01      MANHATTAN    2692             BROADWAY  01875
# 643040   121347266    02      MANHATTAN     120     CLAREMONT AVENUE  01993
# 641244   121347266    01      MANHATTAN     132     CLAREMONT AVENUE  01993
# 840438   122171130    02      MANHATTAN     200         VESEY STREET  00016
# 840437   122171130    01      MANHATTAN     250         VESEY STREET  00016
# 855872   122222638    02      MANHATTAN     200         VESEY STREET  00016
# 855871   122222638    01      MANHATTAN     250         VESEY STREET  00016
# 1719786  301379167    01       BROOKLYN      24       FORREST STREET  03145
# 1719787  301379167    02       BROOKLYN      26       FORREST STREET  00000
# 1722327  301410667    02       BROOKLYN     150    SOUTH    1 STREET  02406
# 1722326  301410667    01       BROOKLYN     142    SOUTH    1 STREET  02406
# 714521   320783826    01       BROOKLYN     429        THROOP AVENUE  01806
# 786393   320783826    02       BROOKLYN     427        THROOP AVENUE  01806
# 180480   401856087    01         QUEENS   79-02  JUNIPER VALLEY ROAD  03069
# 180481   401856087    02         QUEENS   79-04  JUNIPER VALLEY ROAD  03069
# 272026   500592085    02  STATEN ISLAND     258        MAPLE PARKWAY  01223
# 272025   500592085    01  STATEN ISLAND     254        MAPLE PARKWAY  01223
# 272028   500592094    02  STATEN ISLAND     256        MAPLE PARKWAY  01223
# 272027   500592094    01  STATEN ISLAND     254        MAPLE PARKWAY  01223
# 272031   500592110    01  STATEN ISLAND     254        MAPLE PARKWAY  01223
# 272032   500592110    02  STATEN ISLAND     252        MAPLE PARKWAY  01223
# 272036   500592138    02  STATEN ISLAND     248        MAPLE PARKWAY  01223
# 272035   500592138    01  STATEN ISLAND     242        MAPLE PARKWAY  01223
# 272038   500592147    02  STATEN ISLAND     246        MAPLE PARKWAY  01223
# 272037   500592147    01  STATEN ISLAND     242        MAPLE PARKWAY  01223
# 272040   500592156    02  STATEN ISLAND     244        MAPLE PARKWAY  01223
# 272039   500592156    01  STATEN ISLAND     242        MAPLE PARKWAY  01223
#
#            Lot    Bin # Job Type Job Status  ... SPECIAL_ACTION_STATUS  \
# 44473    00018  1056563       NB          R  ...                     A
# 1442320  07501  1056563       NB          R  ...                     N
# 1468683  00018  1056563       A1          R  ...                     W
# 1468682  07501  1056563       A1          R  ...                     W
# 643040   00001  1083664       A2          X  ...                     N
# 641244   00002  1083664       A2          X  ...                     N
# 840438   00140  1000059       A2          X  ...                     N
# 840437   00150  1000060       A2          X  ...                     N
# 855872   00140  1000059       A2          X  ...                     N
# 855871   00150  1000060       A2          X  ...                     N
# 1719786  00106  3350285       NB          X  ...                     N
# 1719787  00000  3350285       NB          X  ...                     A
# 1722327  00010  3062961       NB          X  ...                     A
# 1722326  00142  3062961       NB          X  ...                     N
# 714521   00003  3428733       NB          X  ...                     N
# 786393   00004  3428733       NB          X  ...                     N
# 180480   00027  4464165       NB          X  ...                     N
# 180481   00227  4464165       NB          X  ...                     A
# 272026   00025  5135951       NB          X  ...                     A
# 272025   07501  5135951       NB          X  ...                     N
# 272028   00025  5135950       NB          X  ...                     A
# 272027   07501  5135950       NB          X  ...                     N
# 272031   07501  5114322       NB          X  ...                     N
# 272032   00025  5114322       NB          X  ...                     A
# 272036   00025  5135948       NB          X  ...                     A
# 272035   07501  5135948       NB          X  ...                     N
# 272038   00025  5135947       NB          X  ...                     A
# 272037   07501  5135947       NB          X  ...                     N
# 272040   00025  5135946       NB          X  ...                     A
# 272039   07501  5135946       NB          X  ...                     N
#
#         SPECIAL_ACTION_DATE BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# 44473                   NaN             R0                 0    40.798924
# 1442320                 NaN             R0                 0    40.799201
# 1468683          08/24/2015             R0                 0    40.798924
# 1468682          08/24/2015             R0                 0    40.799201
# 643040                  NaN             W6                 0    40.812475
# 641244                  NaN             W6                 0    40.812769
# 840438                  NaN             O4                 0    40.714447
# 840437                  NaN             O4                 0    40.714529
# 855872                  NaN             O4                 0    40.714447
# 855871                  NaN             O4                 0    40.714529
# 1719786                 NaN             B1                 0    40.700871
# 1719787                 NaN             B1                 0    40.700887
# 1722327                 NaN             R0                 0    40.713725
# 1722326                 NaN             R0                 0    40.713810
# 714521                  NaN             C2                 0    40.688204
# 786393                  NaN             C2                 0    40.688270
# 180480                  NaN             B1                 0    40.715790
# 180481                  NaN             B1                 0    40.715795
# 272026                  NaN             R0                 0    40.627524
# 272025                  NaN             R0                 0    40.627628
# 272028                  NaN             R0                 0    40.627576
# 272027                  NaN             R0                 0    40.627628
# 272031                  NaN             R0                 0    40.627628
# 272032                  NaN             R0                 0    40.627765
# 272036                  NaN             R0                 0    40.627798
# 272035                  NaN             R0                 0    40.627848
# 272038                  NaN             R0                 0    40.627815
# 272037                  NaN             R0                 0    40.627848
# 272040                  NaN             R0                 0    40.627831
# 272039                  NaN             R0                 0    40.627848
#
#         GIS_LONGITUDE GIS_COUNCIL_DISTRICT GIS_CENSUS_TRACT  \
# 44473      -73.967851                    7              191
# 1442320    -73.968480                    7              191
# 1468683    -73.967851                    7              191
# 1468682    -73.968480                    7              191
# 643040     -73.961931                    7              211
# 641244     -73.961714                    7              211
# 840438     -74.015493                    1            31703
# 840437     -74.015677                    1            31703
# 855872     -74.015493                    1            31703
# 855871     -74.015677                    1            31703
# 1719786    -73.935566                   34              391
# 1719787    -73.935509                   34              391
# 1722327    -73.961223                   34              551
# 1722326    -73.961457                   34              551
# 714521     -73.941968                   36              279
# 786393     -73.941982                   36              279
# 180480     -73.874130                   30            65703
# 180481     -73.874065                   30            65703
# 272026     -74.156628                   49              231
# 272025     -74.156624                   49              231
# 272028     -74.156624                   49              231
# 272027     -74.156624                   49              231
# 272031     -74.156624                   49              231
# 272032     -74.156617                   49              231
# 272036     -74.156617                   49              231
# 272035     -74.156614                   49              231
# 272038     -74.156617                   49              231
# 272037     -74.156614                   49              231
# 272040     -74.156614                   49              231
# 272039     -74.156614                   49              231
#
#                                               GIS_NTA_NAME  GIS_BIN
# 44473                                      Upper West Side  1056563
# 1442320                                    Upper West Side  1056563
# 1468683                                    Upper West Side  1056563
# 1468682                                    Upper West Side  1056563
# 643040                                 Morningside Heights  1076684
# 641244                                 Morningside Heights  1083664
# 840438                   Battery Park City-Lower Manhattan  1000059
# 840437                   Battery Park City-Lower Manhattan  1000060
# 855872                   Battery Park City-Lower Manhattan  1000059
# 855871                   Battery Park City-Lower Manhattan  1000060
# 1719786                                     Bushwick South  3350284
# 1719787                                     Bushwick South  3350285
# 1722327                              North Side-South Side  3062961
# 1722326                              North Side-South Side  3062961
# 714521                                  Stuyvesant Heights  3000000
# 786393                                  Stuyvesant Heights  3414033
# 180480                                      Middle Village  4464165
# 180481                                      Middle Village  4530840
# 272026   Mariner's Harbor-Arlington-Port Ivory-Granitev...  5135951
# 272025   Mariner's Harbor-Arlington-Port Ivory-Granitev...  5135949
# 272028   Mariner's Harbor-Arlington-Port Ivory-Granitev...  5135950
# 272027   Mariner's Harbor-Arlington-Port Ivory-Granitev...  5135949
# 272031   Mariner's Harbor-Arlington-Port Ivory-Granitev...  5135949
# 272032   Mariner's Harbor-Arlington-Port Ivory-Granitev...  5114322
# 272036   Mariner's Harbor-Arlington-Port Ivory-Granitev...  5135948
# 272035   Mariner's Harbor-Arlington-Port Ivory-Granitev...  5114349
# 272038   Mariner's Harbor-Arlington-Port Ivory-Granitev...  5135947
# 272037   Mariner's Harbor-Arlington-Port Ivory-Granitev...  5114349
# 272040   Mariner's Harbor-Arlington-Port Ivory-Granitev...  5135946
# 272039   Mariner's Harbor-Arlington-Port Ivory-Granitev...  5114349
#
# [30 rows x 96 columns]

# %%
df_temp = df_temp.loc[(df_temp['Job #'].isin(['122171130', '122222638']))]

# %% [markdown]
# Latest action date is different, so its probably differnt but very similar jobs

# %%
df_temp[df_temp.columns[0:20]]
# Out:
#             Job # Doc #    Borough House #   Street Name  Block    Lot  \
# 840438  122171130    02  MANHATTAN     200  VESEY STREET  00016  00140
# 840437  122171130    01  MANHATTAN     250  VESEY STREET  00016  00150
# 855872  122222638    02  MANHATTAN     200  VESEY STREET  00016  00140
# 855871  122222638    01  MANHATTAN     250  VESEY STREET  00016  00150
#
#           Bin # Job Type Job Status Job Status Description Latest Action Date  \
# 840438  1000059       A2          X             SIGNED OFF         09/19/2017
# 840437  1000060       A2          X             SIGNED OFF         09/19/2017
# 855872  1000059       A2          X             SIGNED OFF         12/14/2015
# 855871  1000060       A2          X             SIGNED OFF         12/14/2015
#
#        Building Type Community Board Cluster Landmarked Adult Establishment  \
# 840438        OTHERS             101       N          N                 NaN
# 840437        OTHERS             101       N          N                   N
# 855872        OTHERS             101       N          N                 NaN
# 855871        OTHERS             101       N          N                   N
#
#        Loft Board City Owned Little e
# 840438          N          Y      NaN
# 840437          N          Y        N
# 855872          N          Y      NaN
# 855871          N          Y        N

# %% [markdown]
# Check if any Job #s have non-digit values

# %%
df['Job #'] = df['Job #'].astype('str')

# %%
df.loc[(~df['Job #'].isna())
       &(~df['Job #'].str.isdigit())]['Job #']
# Out:
# Series([], Name: Job #, dtype: object)

# %% [markdown]
# All Job #s entirely composed of digits, so we cast them to ints

# %%
df['Job #'] = df['Job #'].astype('int')

# %%
df['Job #'].describe()
# Out:
# count    1.774873e+06
# mean     2.518877e+08
# std      1.355763e+08
# min      1.003210e+08
# 25%      1.212317e+08
# 50%      2.206184e+08
# 75%      4.011184e+08
# max      5.777778e+08
# Name: Job #, dtype: float64

# %% [markdown]
# ## Examining and reparing house #s

# %% [markdown]
# House #'s appear to be mostly ints
#
# However, there are legitimate house numbers with dashes so we'll have to make them strings

# %%
show_vals('House #', show_rows=10)
# Out:
# Top 10 House #:
#
# 1      17359
# 200    11853
# 100     8114
# 11      7231
# 10      7191
# 55      7166
# 40      7105
# 30      7098
# 2       6428
# 150     6380
# Name: House #, dtype: int64

# %% [markdown]
# Replace NaN values with empty strings, then convert column to string, and make everything uppercase

# %%
df['House #'].fillna('', inplace=True)
df['House #'] = df['House #'].astype('str')
df['House #'] = df['House #'].str.upper()

# %% [markdown]
# Check for numbers spelled out as words

# %%
df.loc[(~df['House #'].isna())
       &(df['House #'].str.isalpha())]['House #']
# Out:
# 15453            ONE
# 1174319         PIER
# 1181056         PIER
# 1345828          ONE
# 1345994          ONE
# 1378376          ONE
# 1400308          ONE
# 1405901          ONE
# 1513818    MANHATTAN
# Name: House #, dtype: object

# %% [markdown]
# Maybe the house # and borough were flipped in the 'manhattan' case?

# %%
# Nope:
df.loc[df['House #'].str.strip('')=='MANHATTAN'][['House #', 'Borough']]
# Out:
#            House #    Borough
# 1513818  MANHATTAN  MANHATTAN

# %% [markdown]
# Check if thses are empty strings:

# %%
df.loc[(~df['House #'].str.contains('\\d', regex=True))]['House #']
# Out:
# 15453            ONE
# 77082
# 77266
# 77677
# 77679
# 77685
# 77689
# 686310     NO NUMBER
# 1174319         PIER
# 1181056         PIER
# 1345828          ONE
# 1345994          ONE
# 1378376          ONE
# 1400308          ONE
# 1405901          ONE
# 1513818    MANHATTAN
# Name: House #, dtype: object

# %% [markdown]
# Replace spelling of numbers with their value, and remove values 'PIER',  'MANHATTAN',  'NO NUMBER'

# %%
df.loc[df['House #'].str.strip('')=='ONE', 'House #'] = '1'
df.loc[df['House #'].str.strip('')=='PIER', 'House #'] = ''
df.loc[df['House #'].str.strip('')=='MANHATTAN', 'House #'] = ''
df.loc[df['House #'].str.strip('')=='NO NUMBER', 'House #'] = ''

# %% [markdown]
# Most of these will probably be legitimate house numbers, since house numbers can have dashes

# %%
df.loc[(~df['House #'].isna())
       &(~df['House #'].str.isdigit())]['House #']
# Out:
# 1            88-36
# 2            88-36
# 5           215-02
# 6            34-74
# 15           34-74
#             ...
# 1774660    186-200
# 1774661    186-200
# 1774687    372-380
# 1774710    633-639
# 1774855      26-28
# Name: House #, Length: 332183, dtype: object

# %% [markdown]
# Check non-numeric house #'s that don't have dashes

# %%
df.loc[(~df['House #'].isna())
       &(~df['House #'].str.isdigit())
      &(~df['House #'].str.contains('-', regex=False))]['House #'][:25]
# Out:
# 37            215B
# 71          270GAR
# 76          9 WEST
# 263          1715A
# 264          1715A
# 265          1715A
# 297           327A
# 326           327A
# 522           687A
# 550          76GAR
# 556          2529A
# 604       1414 GAR
# 659       368 REAR
# 683            66A
# 731           563A
# 815           128A
# 899     536 GARAGE
# 960          563 A
# 999       1058 GAR
# 1030      1243 GAR
# 1080         40GAR
# 1084     2923 REAR
# 1103       279 GAR
# 1106        126GAR
# 1153        55 GAR
# Name: House #, dtype: object

# %% [markdown]
# We see a mix of reference to the house's garage, the rear house and single letters that likely indicate apartments in multi-occupancy venues.
#
# We will standardize the formatting, and maintain the reference to garage, rear, and appartment, since there is no apartment column for the job.
#
# First split the numbers and words with a space

# %%
df['House #'] = df['House #'].str.replace(pat='(?P<one>\\d)(?P<two>[A-Z]+)', repl='\g<one> \g<two>', regex=True)

# %% [markdown]
# Now we will fix the formatting for garage and
# remove references to north, south, east, west, since they should be in street #

# %%
df['House #'] = df['House #'].str.replace(pat='(?P<one>GAR$)', repl='GARAGE', regex=True)

# %%
df['House #'] = df['House #'].str.replace(pat='NORTH([A-Z]+)?', repl='', regex=True)
df['House #'] = df['House #'].str.replace(pat='EAST([A-Z]+)?', repl='', regex=True)
df['House #'] = df['House #'].str.replace(pat='SOUTH([A-Z]+)?', repl='', regex=True)
df['House #'] = df['House #'].str.replace(pat='WEST([A-Z]+)?', repl='', regex=True)

# %%
# Confirm that it worked correctly:
df.loc[(~df['House #'].isna())
       &(~df['House #'].str.isdigit())
       &(~df['House #'].str.contains('-', regex=False))]['House #'][:30]
# Out:
# 37            215 B
# 71       270 GARAGE
# 76               9
# 263          1715 A
# 264          1715 A
# 265          1715 A
# 297           327 A
# 326           327 A
# 522           687 A
# 550       76 GARAGE
# 556          2529 A
# 604     1414 GARAGE
# 659        368 REAR
# 683            66 A
# 731           563 A
# 815           128 A
# 899      536 GARAGE
# 960           563 A
# 999     1058 GARAGE
# 1030    1243 GARAGE
# 1080      40 GARAGE
# 1084      2923 REAR
# 1103     279 GARAGE
# 1106     126 GARAGE
# 1153      55 GARAGE
# 1154      51 GARAGE
# 1167         2769 A
# 1205           24 A
# 1344     122 CANOPY
# 1380           80 A
# Name: House #, dtype: object

# %% [markdown]
# ## Looking at Binary/Pseudo-binary columns:

# %% [markdown]
# For these columns it's clear NaN idicates 'no', since the only other option was 'X' which indicates yes

# %%
show_vals('Plumbing')
show_vals('Mechanical')
show_vals('Boiler')
show_vals('Fuel Burning')
show_vals('Fuel Storage')
show_vals('Standpipe')
show_vals('Sprinkler')
show_vals('Fire Alarm')
show_vals('Equipment')
show_vals('Fire Suppression')
show_vals('Curb Cut')
show_vals('Other')
# Out:
# Top 10 Plumbing:
#
# NaN    1219162
# X       555711
# Name: Plumbing, dtype: int64
#
# Top 10 Mechanical:
#
# NaN    1490574
# X       284299
# Name: Mechanical, dtype: int64
#
# Top 10 Boiler:
#
# NaN    1724914
# X        49959
# Name: Boiler, dtype: int64
#
# Top 10 Fuel Burning:
#
# NaN    1753422
# X        21451
# Name: Fuel Burning, dtype: int64
#
# Top 10 Fuel Storage:
#
# NaN    1760618
# X        14254
# N            1
# Name: Fuel Storage, dtype: int64
#
# Top 10 Standpipe:
#
# NaN    1760487
# X        14386
# Name: Standpipe, dtype: int64
#
# Top 10 Sprinkler:
#
# NaN    1658486
# X       116387
# Name: Sprinkler, dtype: int64
#
# Top 10 Fire Alarm:
#
# NaN    1687170
# X        87703
# Name: Fire Alarm, dtype: int64
#
# Top 10 Equipment:
#
# NaN    1468061
# X       306812
# Name: Equipment, dtype: int64
#
# Top 10 Fire Suppression:
#
# NaN    1731503
# X        43370
# Name: Fire Suppression, dtype: int64
#
# Top 10 Curb Cut:
#
# NaN    1713660
# X        61213
# Name: Curb Cut, dtype: int64
#
# Top 10 Other:
#
# X      1041766
# NaN     733107
# Name: Other, dtype: int64

# %% [markdown]
# Replace the Nan values with False and replace the 'X' values with True, and then cast the columns to be type bool

# %%
df['Plumbing'].fillna(False, inplace=True)
df['Mechanical'].fillna(False, inplace=True)
df['Boiler'].fillna(False, inplace=True)
df['Fuel Burning'].fillna(False, inplace=True)
df['Adult Establishment'].fillna(False, inplace=True)
df['Fuel Storage'].fillna(False, inplace=True)
df['Standpipe'].fillna(False, inplace=True)
df['Sprinkler'].fillna(False, inplace=True)
df['Fire Alarm'].fillna(False, inplace=True)
df['Fire Suppression'].fillna(False, inplace=True)
df['Curb Cut'].fillna(False, inplace=True)
df['Other'].fillna(False, inplace=True)

# %%
df.loc[df['Plumbing']!=False, 'Plumbing'] = True
df.loc[df['Mechanical']!=False, 'Mechanical'] = True
df.loc[df['Fuel Burning']!=False, 'Fuel Burning'] = True
df.loc[df['Adult Establishment']!=False, 'Adult Establishment'] = True
df.loc[df['Fuel Storage']!=False, 'Fuel Storage'] = True
df.loc[df['Standpipe']!=False, 'Standpipe'] = True
df.loc[df['Sprinkler']!=False, 'Sprinkler'] = True
df.loc[df['Fire Alarm']!=False, 'Fire Alarm'] = True
df.loc[df['Fire Suppression']!=False, 'Fire Suppression'] = True
df.loc[df['Curb Cut']!=False, 'Curb Cut'] = True
df.loc[df['Other']!=False, 'Other'] = True

# %%
df['Plumbing'] = df['Plumbing'].astype('bool')
df['Mechanical'] = df['Mechanical'].astype('bool')
df['Boiler'] = df['Boiler'].astype('bool')
df['Fuel Burning'] = df['Fuel Burning'].astype('bool')
df['Adult Establishment'] = df['Adult Establishment'].astype('bool')
df['Fuel Storage'] = df['Fuel Storage'].astype('bool')
df['Standpipe'] = df['Standpipe'].astype('bool')
df['Sprinkler'] = df['Sprinkler'].astype('bool')
df['Fire Alarm'] = df['Fire Alarm'].astype('bool')
df['Fire Suppression'] = df['Fire Suppression'].astype('bool')
df['Curb Cut'] = df['Curb Cut'].astype('bool')
df['Other'] = df['Other'].astype('bool')

# %%
# Notes:
# Building Type looks binary and has 2 values + maybe NAN
# Cluster looks binary and has 2 values + maybe NAN
# Landmarked looks binary and has 4 values + maybe NAN
# Adult Establishment looks binary and has 2 values + maybe NAN
# Loft Board looks binary and has 2 values + maybe NAN
# City Owned looks binary and has 4 values + maybe NAN
# Little e looks binary and has 5 values + maybe NAN
# PC Filed -- Other all look binary, and have 1-2 values + maybe NAN
#
# Take a look at Other Description for weird strings

# Professional Cert looks binary and has 5 values + maybe NAN
# Non Profit is binary

# %% [markdown]
# These columns are less clear cut since they have yes, no, and NaN values
#
# With the exception of "Landmarked" and "Little e", which both have additional values at high frequency, we can probably assume with relatively high confidence that NaN values would indicate false values for these columns, and we will map the columns to boolean values.
#
# For Landmarked and Little e, we will map NaN to 'N', and leave all the values as strings

# %%
show_vals('Landmarked')
show_vals('Loft Board')
show_vals('City Owned')
show_vals('Little e')
show_vals('PC Filed')
show_vals('eFiling Filed')
show_vals('Professional Cert')
show_vals('Non-Profit')
show_vals('Horizontal Enlargement')
show_vals('Vertical Enlargement')
# Out:
# Top 10 Landmarked:
#
# N      1461499
# Y       208863
# NaN     104119
# L          369
# C           23
# Name: Landmarked, dtype: int64
#
# Top 10 Loft Board:
#
# N      1393398
# NaN     374039
# Y         7436
# Name: Loft Board, dtype: int64
#
# Top 10 City Owned:
#
# NaN    1625471
# Y       149399
# I            1
# M            1
# N            1
# Name: City Owned, dtype: int64
#
# Top 10 Little e:
#
# N      989667
# NaN    728422
# Y       36056
# H       20723
# M           4
# X           1
# Name: Little e, dtype: int64
#
# Top 10 PC Filed:
#
# NaN    1172667
# Y       384720
# N       217486
# Name: PC Filed, dtype: int64
#
# Top 10 eFiling Filed:
#
# Y      1081518
# NaN     693353
# R            2
# Name: eFiling Filed, dtype: int64
#
# Top 10 Professional Cert:
#
# Y      859594
# N      537080
# NaN    378195
# J           2
# F           1
# R           1
# Name: Professional Cert, dtype: int64
#
# Top 10 Non-Profit:
#
# N      1594188
# Y       109138
# NaN      71547
# Name: Non-Profit, dtype: int64
#
# Top 10 Horizontal Enlargement:
#
# NaN    1729051
# Y        45815
# N            7
# Name: Horizontal Enlargement, dtype: int64
#
# Top 10 Vertical Enlargement:
#
# NaN    1742724
# Y        32140
# N            9
# Name: Vertical Enlargement, dtype: int64

# %% [markdown]
# Fill null values with False/'N'

# %%
df['Landmarked'].fillna('N', inplace=True)
df['Little e'].fillna('N', inplace=True)
df.loc[df['Little e']=='X', 'Little e'] = 'Y' # fix this one-off value for Little e

# %% [markdown]
# For the clearly binary cases, fill 'Y' values with True, and the other values with False

# %%
df.loc[df['Loft Board']=='Y', 'Loft Board'] = True
df.loc[df['City Owned']=='Y', 'City Owned'] = True
df.loc[df['PC Filed']=='Y', 'PC Filed'] = True
df.loc[df['eFiling Filed']=='Y', 'eFiling Filed'] = True
df.loc[df['Professional Cert']=='Y', 'Professional Cert'] = True
df.loc[df['Non-Profit']=='Y', 'Non-Profit'] = True
df.loc[df['Horizontal Enlargement']=='Y', 'Horizontal Enlargement'] = True
df.loc[df['Vertical Enlargement']=='Y', 'Vertical Enlargement'] = True



df.loc[df['Loft Board']!=True, 'Loft Board'] = False
df.loc[df['City Owned']!=True, 'City Owned'] = False
df.loc[df['PC Filed']!=True, 'PC Filed'] = False
df.loc[df['eFiling Filed']!=True, 'eFiling Filed'] = False
df.loc[df['Professional Cert']!=True, 'Professional Cert'] = False
df.loc[df['Non-Profit']!=True, 'Non-Profit'] = False
df.loc[df['Horizontal Enlargement']!=True, 'Horizontal Enlargement'] = False
df.loc[df['Vertical Enlargement']!=True, 'Vertical Enlargement'] = False

# %%
df['Loft Board'] = df['Loft Board'].astype('bool')
df['City Owned'] = df['City Owned'].astype('bool')
df['PC Filed'] = df['PC Filed'].astype('bool')
df['eFiling Filed'] = df['eFiling Filed'].astype('bool')
df['Professional Cert'] = df['Professional Cert'].astype('bool')
df['Non-Profit'] = df['Non-Profit'].astype('bool')
df['Horizontal Enlargement'] = df['Horizontal Enlargement'].astype('bool')
df['Vertical Enlargement'] = df['Vertical Enlargement'].astype('bool')

# %% [markdown]
# There does not appear to be anything particularly coherent about the jobs Landmarked or Little e have non-yes/no values

# %%
df.loc[~df['Landmarked'].isin(['Y', 'N'])]['Job Description'].value_counts()[:10]
# Out:
# ST BATHOLOMEW'S CHURCH COMMUNITY HOUSE     1
# FLUSHING HS CAFETERIA                      1
# FELDOR BILLARDS D/B/A FAT CAT BILLIARDS    1
# PACIFIC GRILL                              1
# NY CITY CENTER REHEARSAL SPACE             1
# NY CITY CENTER -STUDIO 5                   1
# HSA-UWC INC                                1
# FIDDLE STICKS                              1
# L'ECOLE                                    1
# HAYDEN HALL                                1
# Name: Job Description, dtype: int64

# %%
df.loc[~df['Landmarked'].isin(['Y', 'N'])][["Owner's First Name", "Owner's Last Name","Owner's Business Name", "Owner's Phone #"]]
# Out:
#         Owner's First Name Owner's Last Name         Owner's Business Name  \
# 21652               EILEEN            TORRES               BRONXWORKS, INC
# 23301           TEITELBAUM           LEOPOLD                           UTA
# 23578          CHRISTOPHER             CAREY                 HARMONIE CLUB
# 23652                DAVID           SALCFAS      ALCONQUIN HOTEL TMES SQ.
# 24258                  TOM           JAVITIS    METROPOLITAN MUSEUM OF ART
# ...                    ...               ...                           ...
# 1601736               MARC           HASKELL        FIFTH AVE BALLROOM LLC
# 1601761            HELMUNT            KROMAR          THE BANK OF NEW YORK
# 1601778               RUSS          CHINNICI  1 BLEECKER STREET ASSOCIATES
# 1601788                ANN       RENGANRDCHI                           NaN
# 1601796              STEVE            TZOLIX             35 WEST 20 STREET
#
#         Owner's Phone #
# 21652        7185083153
# 23301        7189639260
# 23578        2123557400
# 23652        2124199330
# 24258        2126502198
# ...                 ...
# 1601736      9175326400
# 1601761      2126356441
# 1601778      9177506701
# 1601788      5162985929
# 1601796             NaN
#
# [392 rows x 4 columns]

# %% [markdown]
# These have very long + high frequncy job descriptions but it's not clear why

# %%
df.loc[~df['Little e'].isin(['Y', 'N'])]['Job Description'].value_counts()[:4]
# Out:
# REMOVAL AND INSTALLATION OF INTERIOR NON BEARING PARTITIONS AND RELATED FINISHES AS PER PLANS FILED HEREWITH.FILED IN CONJUCTION WITH ALTERATION 1 NUMBER 110463356. NO CHANGE IN USE, EGRESS OR OCCUPANCY UNDER THIS APPLICATION. JOB IS REVIEWED UNDER 2008 CODE IN CONJUNCTION WITH ALT 1 APPLICATION 110463356.    103
# INSTALLATION OF SCAFFOLD AS PER DRAWINGS. SCAFFOLD SHALL COMPLY WITH CHAPTER #33 OF THE 2008 CODE. NO CHANGE IN USE, OCCUPANCY OR EGRESS UNDER THIS APPLICATION.                                                                                                                                                        64
# HVAC AND MECHANICAL MODIFICATIONS AS PER PLANS FILED  AS PER PLANS FILED. FILED IN CONJUNCTION WITH ALTERATION TYPE 1 APPLICATION 110463356.  NO CHANGE IN USE, EGRESS OR OCCUPANCY UNDER THIS APPLICATION.JOB IS REVIEWED UNDER 2008 CODE IN CONJUNCTION WITH ALT 1 APPLICATION 110463356.                             55
# PROPOSED INSTALLATION OF HEAVY DUTY SIDEWALK SHED FILED FOR REMEDIAL REPAIRS AS PER PLANS. NO CHANGE IN USE OCCUPANCY OR EGRESS UNDER THIS APPLICATION. LIVE LOAD 300 PER SQUARE FEET. SIDEWALK SHED SHALL COMPLY WITH CHAPTER # 33 OF THE 2008 CODE.                                                                   49
# Name: Job Description, dtype: int64

# %% [markdown]
# ### Sheng is supposed to look at these:

# %%
# Many of these values are the same but spelled differently
## Sheng is supposed to look at these
##show_vals('Other Description')

# %%
##df['Other Description'].fillna('', inplace=True)
##df['Other Description'] = df['Other Description'].str.upper()

# %%
##df.loc[df['Other Description'].str.contains('GEN')]['Other Description'].value_counts()[:50]

# %%
# gen_strs = df.loc[(df['Other Description'].str.contains('GEN'))
#       &(~ df['Other Description'].str.contains('EMER'))
#       &(~ df['Other Description'].str.contains('ENL'))
#       &(~ df['Other Description'].str.contains('GENERAT'))]['Other Description'].unique()

# %%
#gen_strs

# %%
# df.loc[(~df['Other Description'].str.contains('GEN'))
#       &(~ df['Other Description'].str.contains('EMER'))
#       &(~ df['Other Description'].str.contains('ENL'))
#       &(~ df['Other Description'].str.contains('GENERAT'))]['Other Description'].value_counts()[:50]

# %%
# Should remove "MR" when found
#show_vals("Applicant's First Name")

# %%
#df["Applicant's First Name"] = df["Applicant's First Name"].astype('str')

# %%
# Unclear if these are actual first names mostly (Except for WU (woody))
#df.loc[df["Applicant's First Name"].str.contains(" ")]["Applicant's First Name"].value_counts()

# %%
#df["Applicant's Last Name"] = df["Applicant's Last Name"].astype('str')

# %%
# At least one of thesse is not all caps, and clearly there are periods in some
#show_vals("Applicant's Last Name")

# %%
# Most of these are the same
#show_vals("Applicant Professional Title", show_rows=50)

# %%
##show_vals('Applicant License #', show_rows=20)

# %% [markdown]
# ## Checking Monetary Values for consistency

# %%
show_vals("Initial Cost")
show_vals("Total Estimated Fee")
# Out:
# Top 10 Initial Cost:
#
# $0.00        477561
# $10000.00     57794
# $1000.00      55261
# $3000.00      51157
# $5000.00      50529
# $20000.00     43246
# $15000.00     38850
# $25000.00     35438
# $30000.00     30253
# $50000.00     30054
# Name: Initial Cost, dtype: int64
#
# Top 10 Total Estimated Fee:
#
# $100.00    144802
# $0.00       58846
# $160.00     58050
# $130.00     55733
# $225.00     42217
# $140.00     33609
# $200.00     31413
# $191.50     26906
# $294.50     20432
# $346.00     18524
# Name: Total Estimated Fee, dtype: int64

# %%
df['Initial Cost'] = df['Initial Cost'].astype('str')
df['Total Estimated Fee'] = df['Total Estimated Fee'].astype('str')

# %% [markdown]
# Check if any values are not decimals

# %%
df.loc[~df["Initial Cost"].str.contains(".", regex=False)]["Initial Cost"].value_counts()
# Out:
# Series([], Name: Initial Cost, dtype: int64)

# %%
df.loc[~df["Total Estimated Fee"].str.contains(".", regex=False)]["Total Estimated Fee"].value_counts()
# Out:
# Series([], Name: Total Estimated Fee, dtype: int64)

# %% [markdown]
# Dollar signs should be removed and added to column name so we can treat this column as a number

# %%
df["Total Estimated Fee"] = df["Total Estimated Fee"].str.replace("$", '', regex=False)

# %%
df["Initial Cost"] = df["Initial Cost"].str.replace("$", '', regex=False)

# %% [markdown]
# However we can't convert this to integer dollars because there are decimals.

# %%
df.loc[df["Initial Cost"].str.contains("\\.[^0]", regex=True)]["Initial Cost"]
# Out:
# 42832      387329.94
# 63602      701803.69
# 65789       70656.25
# 325481      78474.75
# 673296     189851.98
# 1763826       269.23
# Name: Initial Cost, dtype: object

# %% [markdown]
# Convert to floats

# %%
df["Initial Cost"] = df["Initial Cost"].astype('float')
df['Total Estimated Fee'] = df['Total Estimated Fee'].astype('float')

# %%
show_vals("Initial Cost")
# Out:
# Top 10 Initial Cost:
#
# 0.0         477561
# 10000.0      57794
# 1000.0       55261
# 3000.0       51157
# 5000.0       50529
#              ...
# 292000.0        90
# 101500.0        90
# 875000.0        89
# 35100.0         89
# 10.0            89
# Name: Initial Cost, Length: 770, dtype: int64

# %%
df['Total Estimated Fee'].value_counts(dropna=False)
# Out:
# 100.00      144802
# 0.00         58846
# 160.00       58050
# 130.00       55733
# 225.00       42217
#              ...
# 782.62           1
# 840.83           1
# 19567.76         1
# 907.97           1
# 490.02           1
# Name: Total Estimated Fee, Length: 93203, dtype: int64

# %% [markdown]
# For unclear reasons, adding xticks makes this plot incredibly slow to display.

# %%
df["Initial Cost"].plot(kind='hist', loglog=True, title='Initial Cost Frequncy (log-log)')
# Out:
# <AxesSubplot:title={'center':'Initial Cost Frequncy (log-log)'}, ylabel='Frequency'>

# %% [markdown]
# Intial costs appear to be distributed roughly exponentially

# %%
df.loc[df["Initial Cost"]<10**8]["Initial Cost"].plot(kind='hist', logy=True, bins=50, title='Initial Cost Frequncy, values < 10^8 (log)')
# Out:
# <AxesSubplot:title={'center':'Initial Cost Frequncy, values < 10^8 (log)'}, ylabel='Frequency'>

# %% [markdown]
# Plotting total estimated fee shows it is also roughly exponential in distribution

# %%
df["Total Estimated Fee"].plot(kind='hist', loglog=True, title='Total Estimated Fee Frequncy (log-log)')
# Out:
# <AxesSubplot:title={'center':'Total Estimated Fee Frequncy (log-log)'}, ylabel='Frequency'>

# %%
df.loc[df["Total Estimated Fee"]<10**7]["Total Estimated Fee"].plot(kind='hist', logy=True, bins=50, title='Total Estimated Fee Frequncy, values < 10^7 (log)')
# Out:
# <AxesSubplot:title={'center':'Total Estimated Fee Frequncy, values < 10^7 (log)'}, ylabel='Frequency'>

# %% [markdown]
# Now that we've mapped these to numerical values, we can identifiy additional issues

# %% [markdown]
# #### Fixing Initial costs

# %%
# Not possible
df["Initial Cost"].min()
# Out:
# -33000.0

# %%
# Obviously a fill-in
df["Initial Cost"].max()
# Out:
# 999999999.0

# %%
df.loc[df['Initial Cost'] < 0]['Initial Cost']
# Out:
# 77094    -33000.0
# 270725     -100.0
# Name: Initial Cost, dtype: float64

# %% [markdown]
# It's likely that these values were mistakenly entered as negative, so we'll flip them to positive instead of setting them to zero

# %%
df.loc[df['Initial Cost'] == -33000.0, 'Initial Cost'] = 33000.0
df.loc[df['Initial Cost'] == -100.0, 'Initial Cost'] = 100.0

# %% [markdown]
# This is test data:

# %%
#the entire line is filled with fake and false information
# The street name is BIS TEST STREET, and almost every value is either the first possible value for the column type, or empty
df.loc[df['Initial Cost'] == 999999999]
# Out:
#              Job # Doc #    Borough House #     Street Name  Block    Lot  \
# 1076602  140595354    01  MANHATTAN       1  BISTEST STREET  00001  00001
#
#            Bin # Job Type Job Status  ... SPECIAL_ACTION_STATUS  \
# 1076602  1813361       A2          D  ...                     C
#
#         SPECIAL_ACTION_DATE BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# 1076602          03/18/2017             O3                 0          NaN
#
#         GIS_LONGITUDE  GIS_COUNCIL_DISTRICT  GIS_CENSUS_TRACT  GIS_NTA_NAME  \
# 1076602           NaN                   NaN               NaN           NaN
#
#         GIS_BIN
# 1076602     NaN
#
# [1 rows x 96 columns]

# %% [markdown]
# We will drop this row

# %%
df.drop(labels=df.loc[df['Initial Cost'] == 999999999].index[0], axis=0, inplace=True)

# %%
df.loc[df['Initial Cost'] == 999999999]
# Out:
# Empty DataFrame
# Columns: [Job #, Doc #, Borough, House #, Street Name, Block, Lot, Bin #, Job Type, Job Status, Job Status Description, Latest Action Date, Building Type, Community Board, Cluster, Landmarked, Adult Establishment, Loft Board, City Owned, Little e, PC Filed, eFiling Filed, Plumbing, Mechanical, Boiler, Fuel Burning, Fuel Storage, Standpipe, Sprinkler, Fire Alarm, Equipment, Fire Suppression, Curb Cut, Other, Other Description, Applicant's First Name, Applicant's Last Name, Applicant Professional Title, Applicant License #, Professional Cert, Pre-Filing Date, Paid Date, Fully Paid Date, Assigned Date, Approved Date, Fully Permitted, Initial Cost, Total Estimated Fee, Fee Status, Existing Zoning Sqft, Proposed Zoning Sqft, Horizontal Enlargement, Vertical Enlargement, Enlargement SQ Footage, Street Frontage, Existing # of Stories, Proposed # of Stories, Existing Height, Proposed Height, Existing Dwelling Units, Proposed Dwelling Units, Existing Occupancy, Proposed Occupancy, Site Fill, Zoning District 1, Zoning District 2, Zoning District 3, Special District 1, Special District 2, Owner Type, Non-Profit, Owner's First Name, Owner's Last Name, Owner's Business Name, Owner's House Number, Owner's House Street Name, Owner's House City, Owner's House State, Owner's House Zip, Owner's Phone #, Job Description, DOB Run Date, JOB_S1_NO, TOTAL_CONSTRUCTION_FLOOR_AREA, WITHDRAWAL_FLAG, SIGNOFF_DATE, SPECIAL_ACTION_STATUS, SPECIAL_ACTION_DATE, BUILDING_CLASS, JOB_NO_GOOD_COUNT, GIS_LATITUDE, GIS_LONGITUDE, GIS_COUNCIL_DISTRICT, GIS_CENSUS_TRACT, GIS_NTA_NAME, GIS_BIN]
# Index: []
#
# [0 rows x 96 columns]

# %% [markdown]
# These seem to be real probably

# %%
df.loc[df['Initial Cost']>= 9000000]["Initial Cost"]
# Out:
# 150        81900000.0
# 499        14975000.0
# 836        13982000.0
# 900        10000000.0
# 1203       14708125.0
#               ...
# 1766641    40000000.0
# 1768852    10200000.0
# 1769126    21574830.0
# 1769799    14400000.0
# 1770287    10002000.0
# Name: Initial Cost, Length: 1599, dtype: float64

# %%
df["Initial Cost"].max()
# Out:
# 966331800.0

# %%
#nothing wrong with this one anymore
df.loc[df['Initial Cost'] == 966331800]
# Out:
#             Job # Doc # Borough House #     Street Name  Block    Lot  \
# 663118  201028930    01   BRONX     470  JACKSON AVENUE  02578  00027
#
#           Bin # Job Type Job Status  ... SPECIAL_ACTION_STATUS  \
# 663118  2003910       A2          X  ...                     N
#
#        SPECIAL_ACTION_DATE BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# 663118                 NaN             W1                 0    40.811162
#
#        GIS_LONGITUDE  GIS_COUNCIL_DISTRICT  GIS_CENSUS_TRACT  \
# 663118    -73.909804                     8                35
#
#                   GIS_NTA_NAME  GIS_BIN
# 663118  Mott Haven-Port Morris  2003910
#
# [1 rows x 96 columns]

# %%
df["Initial Cost"].plot(kind='hist', logy=True, bins=50, title='Initial Cost Frequncy (log)')
# Out:
# <AxesSubplot:title={'center':'Initial Cost Frequncy (log)'}, ylabel='Frequency'>

# %% [markdown]
# #### Fixing Total Estimated Fee

# %%
df.loc[df['Total Estimated Fee'] < 0 ]
# Out:
#            Job # Doc #   Borough House #    Street Name  Block    Lot  \
# 77094  302188718    07  BROOKLYN     105  LINCOLN PLACE  00948  00072
#
#          Bin # Job Type Job Status  ... SPECIAL_ACTION_STATUS  \
# 77094  3019516       A2          P  ...                   NaN
#
#       SPECIAL_ACTION_DATE BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# 77094                 NaN             B9                 0    40.676403
#
#       GIS_LONGITUDE  GIS_COUNCIL_DISTRICT  GIS_CENSUS_TRACT  \
# 77094    -73.976292                    39               159
#
#              GIS_NTA_NAME  GIS_BIN
# 77094  Park Slope-Gowanus  3019516
#
# [1 rows x 96 columns]

# %% [markdown]
# We'll fix this as we did with negative monetary values before

# %%
df.loc[df['Total Estimated Fee'] == -85.8,  'Total Estimated Fee'] = 85.8

# %%
df['Total Estimated Fee'].max()
# Out:
# 31500000.0

# %% [markdown]
# Also seems to have real information

# %%
df.loc[df['Total Estimated Fee']==31500000.0]
# Out:
#              Job # Doc #   Borough House #  Street Name  Block    Lot  \
# 1404867  322053148    01  BROOKLYN     650  86TH STREET  06056  00015
#
#            Bin # Job Type Job Status  ... SPECIAL_ACTION_STATUS  \
# 1404867  3153881       NB          P  ...                     N
#
#         SPECIAL_ACTION_DATE BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# 1404867                 NaN             K5                 0    40.618851
#
#         GIS_LONGITUDE  GIS_COUNCIL_DISTRICT  GIS_CENSUS_TRACT   GIS_NTA_NAME  \
# 1404867    -74.021875                    43               152  Dyker Heights
#
#          GIS_BIN
# 1404867  3153881
#
# [1 rows x 96 columns]

# %% [markdown]
# ## Checking owner's information

# %%
show_vals("Owner's Business Name")
show_vals("Owner's House Number")
show_vals("Owner's House Street Name")
show_vals("Owner's House City")
show_vals("Owner's House State")
show_vals("Owner's House Zip")
# Out:
# Top 10 Owner's Business Name:
#
# NaN                                 350615
# OWNER                                11056
# NY SCHOOL CONSTRUCTION AUTHORITY      9758
# NONE                                  9558
# NYC SCA                               9228
# VORNADO OFFICE MANAGEMENT             6990
# NYCHA                                 6652
# SL GREEN REALTY CORP.                 5696
# NYC HOUSING AUTHORITY                 5696
# NEW YORK CITY HOUSING AUTHORITY       4737
# Name: Owner's Business Name, dtype: int64
#
# Top 10 Owner's House Number:
#
# NaN      1773869
# 2             19
# 30-30         18
# 555           17
# 22            16
# 1950          16
# 100           16
# 10            12
# 250           11
# 32            11
# Name: Owner's House Number, dtype: int64
#
# Top 10 Owner's House Street Name:
#
# NaN                            1773869
# 555 WEST 23RD STREET                17
# 22 CHAPEL STREET                    10
# 1559 49TH STREET                     9
# 30-30 THOMSON AVENUE                 9
# 35 N TYSON AVENUE STE#102            8
# 250 BROADWAY                         6
# 579 FIFTH AVENUE, 4TH FLOOR          6
# 1950 Coney Island Avenue             6
# 199 LEE AVENUE                       6
# Name: Owner's House Street Name, dtype: int64
#
# Top 10 Owner's House City:
#
# NaN              1773869
# BROOKLYN             309
# NEW YORK             273
# QUEENS                56
# NY                    37
# BRONX                 32
# STATEN ISLAND         19
# LIC                   18
# New York              18
# FLUSHING              15
# Name: Owner's House City, dtype: int64
#
# Top 10 Owner's House State:
#
# NaN    1773869
# NY         981
# NJ          11
# CA           3
# CT           3
# MD           1
# MA           1
# KY           1
# VA           1
# MO           1
# Name: Owner's House State, dtype: int64
#
# Top 10 Owner's House Zip:
#
# NaN      1773871
# 11201         46
# 10011         31
# 11220         30
# 10022         30
# 11219         27
# 11101         26
# 11211         25
# 10007         24
# 10019         22
# Name: Owner's House Zip, dtype: int64

# %% [markdown]
# ## Fixing owner's informations

# %%
df.loc[~df["Owner's Business Name"].isna() & df["Owner's Business Name"].str.contains("(?i)new york city")]["Owner's Business Name"].value_counts()
# Out:
# NEW YORK CITY HOUSING AUTHORITY     4737
# New York City Housing Authority      388
# NEW YORK CITY ECONOMIC DEVELOPME      99
# NEW YORK CITY SCHOOL CONSTRUCTIO      82
# FIRE DEPARTMENT OF NEW YORK CITY      70
#                                     ...
# NEW YORK CITY ECONOMIC DEVEL. CO       1
# NEW YORK CITY ECONOMIC DEVEL COR       1
# NEW YORK CITY ECONOMICAL DEV COR       1
# NEW YORK CITY PARKS DEPT.              1
# BWT, New York City DEP                 1
# Name: Owner's Business Name, Length: 230, dtype: int64

# %% [markdown]
# Normalizes a couple of duplicate names

# %%
df["Owner's Business Name"] = df["Owner's Business Name"].str.replace("NEW YORK CITY", "NYC")
df["Owner's Business Name"] = df["Owner's Business Name"].str.upper()
df["Owner's Business Name"] = df["Owner's Business Name"].str.replace(".", '', regex=False)
df["Owner's Business Name"] = df["Owner's Business Name"].str.replace(",", '', regex=False)

# %% [markdown]
# All these are the same thing. Uses clusters to fix

# %%
#may have to use fuzzy/cluster to fix this problem
df.loc[~df["Owner's Business Name"].isna() & df["Owner's Business Name"].str.contains("(?i)HOUSING AUTHORITY")]["Owner's Business Name"].value_counts()
# Out:
# NYC HOUSING AUTHORITY               11457
# NEW YORK CITY HOUSING AUTHORITY       389
# NEW YORK HOUSING AUTHORITY            140
# NY CITY HOUSING AUTHORITY              66
# NYCHA NY HOUSING AUTHORITY             64
# NYCHOUSING AUTHORITY                   30
# NY HOUSING AUTHORITY                   25
# NYC HOUSING AUTHORITY (NYCHA)          23
# NYC  HOUSING AUTHORITY                 15
# NEW YORK CTY HOUSING AUTHORITY          6
# N Y C HOUSING AUTHORITY                 6
# NYC HOUSING AUTHORITY- CAD              6
# NEW YORK HOUSING AUTHORITY- DESI        4
# NEWYORK CITY HOUSING AUTHORITY          3
# NEW YORK  CITY HOUSING AUTHORITY        3
# NYCITY HOUSING AUTHORITY                3
# NYC HOUSING HOUSING AUTHORITY           3
# NEW YORK CITY HHOUSING AUTHORITY        3
# NEW CITY HOUSING AUTHORITY              3
# NEW YOR CITY HOUSING AUTHORITY          2
# NYC-HOUSING AUTHORITY                   2
# NEW YORK CITH HOUSING AUTHORITY         2
# YC HOUSING AUTHORITY                    2
# NYC - HOUSING AUTHORITY                 2
# MYC HOUSING AUTHORITY                   2
# NYHOUSING AUTHORITY                     2
# NYC CITY HOUSING AUTHORITY              1
# NEW YROK CITY HOUSING AUTHORITY         1
# YORK CITY HOUSING AUTHORITY             1
# NEW UORK CITY HOUSING AUTHORITY         1
# NEW YORKN CITY HOUSING AUTHORITY        1
# HOUSING AUTHORITY                       1
# NEW YOURK CITY HOUSING AUTHORITY        1
# N  Y C HOUSING AUTHORITY                1
# NYC_HOUSING AUTHORITY                   1
# NEWYORK HOUSING AUTHORITY               1
# NEW YORK CIUTY HOUSING AUTHORITY        1
# NYC HOUSING AUTHORITYH                  1
# NEW TORK CITY HOUSING AUTHORITY         1
# NEW YORK CIT HOUSING AUTHORITY          1
# NYCN HOUSING AUTHORITY                  1
# HYC HOUSING AUTHORITY                   1
# NEW YORK VITY HOUSING AUTHORITY         1
# NEW YORK CIRY HOUSING AUTHORITY         1
# NEW  YORK CITY HOUSING AUTHORITY        1
# NHYC HOUSING AUTHORITY                  1
# NNYC HOUSING AUTHORITY                  1
# NTC HOUSING AUTHORITY                   1
# NYC HOUSING AUTHORITY DESIGN DEP        1
# NYCUTY HOUSING AUTHORITY                1
# NYTC HOUSING AUTHORITY                  1
# NEW YORK HOUSING AUTHORITY CAPI         1
# OR NYC HOUSING AUTHORITY                1
# Name: Owner's Business Name, dtype: int64

# %% [markdown]
# All these states are valid

# %%
df["Owner's House State"].value_counts()
# Out:
# NY    981
# NJ     11
# CA      3
# CT      3
# MD      1
# MA      1
# KY      1
# VA      1
# MO      1
# Name: Owner's House State, dtype: int64

# %% [markdown]
# Since the states can be outside NYC, these are probably fine

# %%
df["Owner's House Zip"].value_counts()
# Out:
# 11201    46
# 10011    31
# 10022    30
# 11220    30
# 11219    27
#          ..
# 10000     1
# 02895     1
# 10523     1
# 08054     1
# 11436     1
# Name: Owner's House Zip, Length: 212, dtype: int64

# %% [markdown]
# ## Looking at Phone Numbers:

# %%
show_vals("Owner's Phone #")
# Out:
# Top 10 Owner's Phone #:
#
# 7184728000    12732
# NaN           11467
# 2128947000    10345
# 2128637625     5610
# 7183924921     4411
# 2122161664     4190
# 2124072400     3922
# 7184728534     3346
# 2125295688     3313
# 5169355555     3288
# Name: Owner's Phone #, dtype: int64

# %% [markdown]
# A lot of the same phone numbers

# %%
df["Owner's Phone #"] = df["Owner's Phone #"].astype('str')

# %%
df.loc[df["Owner's Phone #"].str.contains("7184728000")][["Owner's First Name", "Owner's Last Name","Owner's Business Name", "Owner's Phone #"]]
# Out:
#         Owner's First Name Owner's Last Name          Owner's Business Name  \
# 6                   JOSEPH           SCALISI  SCHOOL CONSTRUCTION AUTHORITY
# 15                  JOSEPH           SCALISI  SCHOOL CONSTRUCTION AUTHORITY
# 34                  JOSEPH           SCALISI                         NYCSCA
# 74                 SRIDHAR      DULPETA-RAMA  SCHOOL CONSTRUCTION AUTHORITY
# 129                  EFFIE        TSITIRIDIS  SCHOOL CONSTRUCTION AUTHORITY
# ...                    ...               ...                            ...
# 1770710            MICHAEL            KALEDA                          NYCSA
# 1770851                AMY            LINDEN         NYS BOARD OF EDUCATION
# 1770852                AMY            LINDEN         NYS BOARD OF EDUCATION
# 1771916                AMY            LINDEN         NYS BOARD OF EDUCATION
# 1772725                AMY            LINDEN         NYS BOARD OF EDUCATION
#
#         Owner's Phone #
# 6            7184728000
# 15           7184728000
# 34           7184728000
# 74           7184728000
# 129          7184728000
# ...                 ...
# 1770710      7184728000
# 1770851      7184728000
# 1770852      7184728000
# 1771916      7184728000
# 1772725      7184728000
#
# [12732 rows x 4 columns]

# %% [markdown]
# All from the same business name so it makes sense

# %%
df.loc[df["Owner's Phone #"]=='nan']
# Out:
#              Job # Doc #   Borough House #       Street Name  Block    Lot  \
# 655      301925442    01  BROOKLYN     975  EAST   55 STREET  07739  00011
# 683      302095104    01  BROOKLYN    66 A  STOCKHOLM STREET  03254  00123
# 3532     301960947    01  BROOKLYN    4414         10 AVENUE  05607  00041
# 5115     200698343    01     BRONX    1200      WATERS PLACE  04226  00070
# 5173     402163494    01    QUEENS   75-01        162 STREET  06845  00001
# ...            ...   ...       ...     ...               ...    ...    ...
# 1774748  302041644    01  BROOKLYN     259         17 STREET  00867  00076
# 1774757  302041733    01  BROOKLYN     123     CALYER STREET  02572  00046
# 1774782  302041957    01  BROOKLYN      62  MANHATTAN AVENUE  03088  00035
# 1774845  302042581    01  BROOKLYN    5516          6 AVENUE  00832  00044
# 1774870  302042876    01  BROOKLYN    1658         66 STREET  05559  00033
#
#            Bin # Job Type Job Status  ... SPECIAL_ACTION_STATUS  \
# 655      3213803       A1          R  ...                     N
# 683      3389150       A1          X  ...                     N
# 3532     3136307       A1          R  ...                     N
# 5115     2087151       A1          R  ...                     N
# 5173     4148209       A1          R  ...                     N
# ...          ...      ...        ...  ...                   ...
# 1774748  3016463       A2          X  ...                     N
# 1774757  3065081       A2          P  ...                     N
# 1774782  3071408       A2          X  ...                     N
# 1774845  3015040       A2          R  ...                     N
# 1774870  3134197       A2          X  ...                     N
#
#         SPECIAL_ACTION_DATE BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# 655                     NaN             A9                 0    40.633712
# 683                     NaN             B1                 0    40.696597
# 3532                    NaN             C3                 0    40.641681
# 5115                    NaN             O5                 0    40.842733
# 5173                    NaN             B3                 0    40.726810
# ...                     ...            ...               ...          ...
# 1774748                 NaN             C0                 0    40.663293
# 1774757                 NaN             C0                 0    40.727181
# 1774782                 NaN             S9                 0    40.704416
# 1774845                 NaN             C2                 0    40.640832
# 1774870                 NaN             C3                 0    40.620486
#
#         GIS_LONGITUDE  GIS_COUNCIL_DISTRICT  GIS_CENSUS_TRACT  \
# 655        -73.923605                    46               724
# 683        -73.925621                    34               421
# 3532       -73.995968                    38               112
# 5115       -73.838373                    13               284
# 5173       -73.806883                    24              1241
# ...               ...                   ...               ...
# 1774748    -73.990585                    38               143
# 1774757    -73.956185                    33               561
# 1774782    -73.944457                    34               491
# 1774845    -74.011192                    38               100
# 1774870    -73.994067                    38               252
#
#                                     GIS_NTA_NAME  GIS_BIN
# 655                                    Flatlands  3213803
# 683                               Bushwick South  3389150
# 3532                            Sunset Park East  3136307
# 5115     Van Nest-Morris Park-Westchester Square  2087151
# 5173          Pomonok-Flushing Heights-Hillcrest  4148209
# ...                                          ...      ...
# 1774748                       Park Slope-Gowanus  3016463
# 1774757                               Greenpoint  3065081
# 1774782                        East Williamsburg  3071408
# 1774845                         Sunset Park East  3015040
# 1774870                         Bensonhurst West  3134197
#
# [11467 rows x 96 columns]

# %% [markdown]
# Nothing wrong with these jobs without an owner's phone number

# %%
df.loc[~df["Owner's Phone #"].isna() & df["Owner's Phone #"].str.contains("-")]["Owner's Phone #"].value_counts()
# Out:
# 212582-455    3
# 212490192-    2
# 71852751-1    2
# 0-            2
# 21255736--    2
# 212816-22-    1
# 21267955--    1
# 212-020844    1
# 631-323395    1
# 212808090-    1
# 2123-51347    1
# 212269689-    1
# 71835636-7    1
# 718888-600    1
# 71888422--    1
# 71839130-3    1
# 718291550-    1
# 212675200-    1
# 215-29        1
# 718767168-    1
# 149-62        1
# 157-15        1
# 146-02        1
# 163-07        1
# 243-17        1
# 718-942300    1
# 175-27        1
# 191-15        1
# 150-24        1
# 71820585-1    1
# 718343645-    1
# 212863749-    1
# 102-18        1
# 71845657-6    1
# 242-01        1
# Name: Owner's Phone #, dtype: int64

# %% [markdown]
# Phone numbers should not contain "-"

# %%
df.loc[~df["Owner's Phone #"].isna() & df["Owner's Phone #"].str.contains(" ")]["Owner's Phone #"].value_counts()
# Out:
# 212  58664    7
# 212483 077    6
# 212 929318    5
# 212 996510    4
# 718391 105    4
#              ..
# 917939  99    1
# 212    279    1
# 718  35377    1
# 718 555555    1
# 9176 96 89    1
# Name: Owner's Phone #, Length: 115, dtype: int64

# %% [markdown]
# Phone numbers should not contain empty space

# %% [markdown]
# ### Cleaning phone number

# %% [markdown]
# #### removes non-numeric characters

# %%
df["Owner's Phone #"] = df["Owner's Phone #"].str.extract('(\d+)', expand=False)
df.loc[~df["Owner's Phone #"].isna() & df["Owner's Phone #"].str.contains(" ")]["Owner's Phone #"].value_counts()
# Out:
# Series([], Name: Owner's Phone #, dtype: int64)

# %% [markdown]
# #### Turns phone numbers that start with 0, 1, and does not have 10 digits into nan

# %%
df["Owner's Phone #"] = df["Owner's Phone #"].astype('str')
df.loc[~df["Owner's Phone #"].isna() & ((df["Owner's Phone #"].str[0] == "0") | (df["Owner's Phone #"].str[0] == "1") | (df["Owner's Phone #"].apply(len) != 10)), ["Owner's Phone #"]] = np.nan

# %% [markdown]
# #### Checks to see if there are any others not of length 10

# %%
df["Owner's Phone #"] = df["Owner's Phone #"].astype('str')
df.loc[(df["Owner's Phone #"].apply(len) != 10)]["Owner's Phone #"]
# Out:
# 226        nan
# 637        nan
# 655        nan
# 683        nan
# 2026       nan
#           ...
# 1774748    nan
# 1774757    nan
# 1774782    nan
# 1774845    nan
# 1774870    nan
# Name: Owner's Phone #, Length: 15487, dtype: object

# %% [markdown]
# #### Check for non-numeric charaters

# %%
df.loc[(~df["Owner's Phone #"].str.isnumeric()) & (~(df["Owner's Phone #"]=='nan'))]["Owner's Phone #"]
# Out:
# Series([], Name: Owner's Phone #, dtype: object)

# %% [markdown]
# ## Fixing Datetime columns

# %%
datetime_column_list = ['Latest Action Date', 'DOB Run Date', 'SPECIAL_ACTION_DATE', 'SIGNOFF_DATE', 
                        'Pre-Filing Date', 'Paid Date', 'Fully Paid Date', 'Assigned Date', 'Fully Permitted', 'Approved Date']
for col in datetime_column_list:
    show_vals(col)
# Out:
# Top 10 Latest Action Date:
#
# 10/13/2017    793
# 05/18/2017    774
# 01/25/2017    744
# 02/12/2018    739
# 11/30/2016    734
# 07/11/2016    716
# 11/29/2016    700
# 04/30/2018    699
# 05/04/2017    686
# 04/20/2016    674
# Name: Latest Action Date, dtype: int64
#
# Top 10 DOB Run Date:
#
# 04/28/2021 00:00:00    1674972
# 07/09/2021 00:00:00      17059
# 09/16/2021 00:00:00       6866
# 11/16/2021 00:00:00       3592
# 08/02/2021 00:00:00       2652
# 11/03/2021 00:00:00       1699
# 11/09/2021 00:00:00       1330
# 05/25/2021 00:00:00       1253
# 07/24/2021 00:00:00       1200
# 08/31/2021 00:00:00       1137
# Name: DOB Run Date, dtype: int64
#
# Top 10 SPECIAL_ACTION_DATE:
#
# NaN           1602673
# 10/24/2012       5513
# 05/12/2017        510
# 10/23/2012        229
# 02/10/2017        224
# 08/13/2019        188
# 03/02/2015        186
# 06/27/2017        181
# 03/02/2017        172
# 11/10/2015        156
# Name: SPECIAL_ACTION_DATE, dtype: int64
#
# Top 10 SIGNOFF_DATE:
#
# NaN           711507
# 02/12/2018       603
# 01/25/2017       593
# 05/18/2017       580
# 10/13/2017       576
# 11/30/2016       572
# 07/11/2016       558
# 07/19/2012       540
# 11/29/2016       535
# 04/30/2018       526
# Name: SIGNOFF_DATE, dtype: int64
#
# Top 10 Pre-Filing Date:
#
# 06/28/2019    1717
# 12/30/2014    1466
# 06/27/2019    1388
# 06/26/2008    1006
# 06/25/2008     842
# 06/26/2019     833
# 09/30/2016     831
# 12/29/2014     808
# 02/04/2011     763
# 02/15/2008     738
# Name: Pre-Filing Date, dtype: int64
#
# Top 10 Paid Date:
#
# NaN           9068
# 06/28/2019    1700
# 12/30/2014    1484
# 06/27/2019    1319
# 06/26/2008    1259
# 02/15/2008     978
# 02/04/2011     915
# 06/30/2009     879
# 06/25/2008     866
# 09/30/2016     839
# Name: Paid Date, dtype: int64
#
# Top 10 Fully Paid Date:
#
# NaN           6578
# 06/28/2019    1702
# 12/30/2014    1515
# 06/27/2019    1310
# 06/26/2008    1222
# 02/15/2008     978
# 02/04/2011     916
# 06/30/2009     857
# 09/30/2016     844
# 12/29/2014     795
# Name: Fully Paid Date, dtype: int64
#
# Top 10 Assigned Date:
#
# NaN           578990
# 07/01/2009       575
# 01/12/2018       523
# 03/22/2018       512
# 08/09/2001       492
# 12/30/2014       487
# 10/28/2015       469
# 06/28/2019       449
# 07/18/2017       442
# 06/26/2008       438
# Name: Assigned Date, dtype: int64
#
# Top 10 Fully Permitted:
#
# NaN           465124
# 11/12/2015       487
# 05/17/2017       439
# 11/15/2016       439
# 07/25/2017       435
# 11/04/2015       429
# 08/15/2001       429
# 11/06/2013       429
# 11/09/2006       425
# 09/13/2016       422
# Name: Fully Permitted, dtype: int64
#
# Top 10 Approved Date:
#
# NaN           329873
# 06/26/2008       663
# 06/25/2008       529
# 06/27/2019       521
# 06/28/2019       514
# 05/21/2015       500
# 11/10/2005       476
# 12/03/2015       474
# 08/03/2016       446
# 10/11/2017       444
# Name: Approved Date, dtype: int64

# %% [markdown]
# Check to see if any columns have values in year-month-day format

# %%
for col in datetime_column_list:
    print(col, '\n', df.loc[df[col].str.contains('-', regex=False, na=False)][col], '\n\n')
# Out:
# Latest Action Date
#  51256    2005-11-01
# 52306    2000-10-17
# 55475    2016-07-05
# 55607    2018-08-24
# 55615    2018-08-24
#             ...
# 81303    2003-03-11
# 81304    2002-12-19
# 81305    2004-10-25
# 81306    2004-01-22
# 81307    2004-06-22
# Name: Latest Action Date, Length: 967, dtype: object
#
#
# DOB Run Date
#  51256    2018-11-02
# 52306    2018-11-02
# 55475    2018-03-01
# 55607    2018-08-25
# 55615    2018-08-25
#             ...
# 81303    2018-11-02
# 81304    2018-11-02
# 81305    2018-11-02
# 81306    2018-11-02
# 81307    2018-11-02
# Name: DOB Run Date, Length: 967, dtype: object
#
#
# SPECIAL_ACTION_DATE
#  Series([], Name: SPECIAL_ACTION_DATE, dtype: object)
#
#
# SIGNOFF_DATE
#  Series([], Name: SIGNOFF_DATE, dtype: object)
#
#
# Pre-Filing Date
#  Series([], Name: Pre-Filing Date, dtype: object)
#
#
# Paid Date
#  Series([], Name: Paid Date, dtype: object)
#
#
# Fully Paid Date
#  Series([], Name: Fully Paid Date, dtype: object)
#
#
# Assigned Date
#  Series([], Name: Assigned Date, dtype: object)
#
#
# Fully Permitted
#  Series([], Name: Fully Permitted, dtype: object)
#
#
# Approved Date
#  Series([], Name: Approved Date, dtype: object)

# %% [markdown]
# #### Fix DOB Run Date formatting issues
# DOB Run Date and Latest Action date both have values in multiple datetime formats
#
# We want all the dates to be in a standard year-month-day datetime format, so we'll seperately convert the values not in this format, and in this format to datetime objects

# %%
df.loc[~df['DOB Run Date'].str.contains('-', regex=False), 'DOB Run Date'] = pd.to_datetime(
    df.loc[~df['DOB Run Date'].str.contains('-', regex=False)]['DOB Run Date'], infer_datetime_format=True, errors='coerce')

# %% [markdown]
# This mapped most of our values to datetimes, now just need to map the rest

# %%
df['DOB Run Date'].value_counts()
# Out:
# 2021-04-28 00:00:00    1674972
# 2021-07-09 00:00:00      17059
# 2021-09-16 00:00:00       6866
# 2021-11-16 00:00:00       3592
# 2021-08-02 00:00:00       2652
#                         ...
# 2019-06-04                   1
# 2019-05-31                   1
# 2019-05-15                   1
# 2019-05-02                   1
# 2019-06-07                   1
# Name: DOB Run Date, Length: 298, dtype: int64

# %%
df.loc[:,'DOB Run Date'] = pd.to_datetime(
    df['DOB Run Date'], infer_datetime_format=True, errors='coerce')

# %%
df['DOB Run Date']
# Out:
# 0         2021-05-22
# 1         2021-06-25
# 2         2021-06-25
# 3         2021-11-11
# 4         2021-11-11
#              ...
# 1774868   2021-04-28
# 1774869   2021-04-28
# 1774870   2021-04-28
# 1774871   2021-04-28
# 1774872   2021-04-28
# Name: DOB Run Date, Length: 1774872, dtype: datetime64[ns]

# %% [markdown]
# #### Fix Latest Action Date formatting issues
#
# We'll use the same method as above

# %%
df.loc[~df['Latest Action Date'].str.contains('-', regex=False), 'Latest Action Date'] = pd.to_datetime(
    df.loc[~df['Latest Action Date'].str.contains('-', regex=False)]['Latest Action Date'], infer_datetime_format=True, errors='coerce')

# %%
df['Latest Action Date'].value_counts()
# Out:
# 2017-10-13 00:00:00    793
# 2017-05-18 00:00:00    774
# 2017-01-25 00:00:00    744
# 2018-02-12 00:00:00    739
# 2016-11-30 00:00:00    734
#                       ...
# 2002-06-11               1
# 2003-02-19               1
# 2003-03-28               1
# 2004-05-06               1
# 2007-12-15 00:00:00      1
# Name: Latest Action Date, Length: 7373, dtype: int64

# %%
df.loc[:,'Latest Action Date'] = pd.to_datetime(
    df['Latest Action Date'], infer_datetime_format=True, errors='coerce')

# %%
df['Latest Action Date']
# Out:
# 0         2021-05-21
# 1         2021-06-24
# 2         2021-06-24
# 3         2021-11-10
# 4         2021-11-10
#              ...
# 1774868   2006-02-06
# 1774869   2007-06-20
# 1774870   2006-03-14
# 1774871   2010-06-10
# 1774872   2007-03-23
# Name: Latest Action Date, Length: 1774872, dtype: datetime64[ns]

# %% [markdown]
# #### Fix the remaining Datetime columns

# %%
for col in datetime_column_list:
    if (col == 'Latest Action Date') or (col == 'DOB Run Date'):
        continue
    else:
        df.loc[:,col] = pd.to_datetime(df[col], infer_datetime_format=True, errors='coerce')

# %%
df['SPECIAL_ACTION_DATE'].value_counts(dropna=False)
# Out:
# NaT           1602674
# 2012-10-24       5513
# 2017-05-12        510
# 2012-10-23        229
# 2017-02-10        224
#                ...
# 2002-01-15          1
# 2000-06-07          1
# 2000-06-30          1
# 2000-06-22          1
# 2007-12-05          1
# Name: SPECIAL_ACTION_DATE, Length: 6374, dtype: int64

# %% [markdown]
# These should all be proper datetime64[ns] columns now:

# %%
df.select_dtypes(include='datetime')
# Out:
#         Latest Action Date Pre-Filing Date  Paid Date Fully Paid Date  \
# 0               2021-05-21      2021-04-28 2021-04-28      2021-05-04
# 1               2021-06-24      2021-04-28 2021-04-28      2021-04-28
# 2               2021-06-24      2021-04-28 2021-04-28      2021-04-28
# 3               2021-11-10      2021-04-28 2021-04-28      2021-04-28
# 4               2021-11-10      2021-04-28 2021-04-28      2021-04-28
# ...                    ...             ...        ...             ...
# 1774868         2006-02-06      2005-11-14 2005-11-14      2005-11-15
# 1774869         2007-06-20      2005-11-14 2005-11-14      2005-11-14
# 1774870         2006-03-14      2005-11-14 2005-11-14      2005-11-14
# 1774871         2010-06-10      2005-11-14 2005-11-14      2005-11-14
# 1774872         2007-03-23      2005-11-14 2005-11-17      2005-11-17
#
#         Assigned Date Approved Date Fully Permitted DOB Run Date SIGNOFF_DATE  \
# 0          2021-04-28    2021-05-04      2021-05-21   2021-05-22          NaT
# 1                 NaT           NaT             NaT   2021-06-25          NaT
# 2                 NaT           NaT             NaT   2021-06-25          NaT
# 3                 NaT           NaT             NaT   2021-11-11          NaT
# 4                 NaT           NaT             NaT   2021-11-11          NaT
# ...               ...           ...             ...          ...          ...
# 1774868    2005-11-17    2005-11-22      2005-12-01   2021-04-28   2006-02-06
# 1774869           NaT    2005-11-14      2006-01-19   2021-04-28          NaT
# 1774870           NaT    2005-11-14      2005-12-05   2021-04-28   2006-03-14
# 1774871           NaT    2005-11-14             NaT   2021-04-28          NaT
# 1774872    2005-11-17    2005-11-17      2007-01-23   2021-04-28   2007-03-23
#
#         SPECIAL_ACTION_DATE
# 0                       NaT
# 1                       NaT
# 2                       NaT
# 3                       NaT
# 4                       NaT
# ...                     ...
# 1774868                 NaT
# 1774869                 NaT
# 1774870                 NaT
# 1774871                 NaT
# 1774872                 NaT
#
# [1774872 rows x 10 columns]

# %%
for col in datetime_column_list:
    show_vals(col)
# Out:
# Top 10 Latest Action Date:
#
# 2017-10-13    793
# 2017-05-18    774
# 2017-01-25    744
# 2018-02-12    740
# 2016-11-30    735
# 2016-07-11    716
# 2016-11-29    700
# 2018-04-30    699
# 2017-05-04    686
# 2016-04-20    674
# Name: Latest Action Date, dtype: int64
#
# Top 10 DOB Run Date:
#
# 2021-04-28    1674972
# 2021-07-09      17059
# 2021-09-16       6866
# 2021-11-16       3592
# 2021-08-02       2652
# 2021-11-03       1699
# 2021-11-09       1330
# 2021-05-25       1253
# 2021-07-24       1200
# 2021-08-31       1137
# Name: DOB Run Date, dtype: int64
#
# Top 10 SPECIAL_ACTION_DATE:
#
# NaT           1602674
# 2012-10-24       5513
# 2017-05-12        510
# 2012-10-23        229
# 2017-02-10        224
# 2019-08-13        188
# 2015-03-02        186
# 2017-06-27        181
# 2017-03-02        172
# 2015-11-10        156
# Name: SPECIAL_ACTION_DATE, dtype: int64
#
# Top 10 SIGNOFF_DATE:
#
# NaT           711508
# 2018-02-12       603
# 2017-01-25       593
# 2017-05-18       580
# 2017-10-13       576
# 2016-11-30       572
# 2016-07-11       558
# 2012-07-19       540
# 2016-11-29       535
# 2018-04-30       526
# Name: SIGNOFF_DATE, dtype: int64
#
# Top 10 Pre-Filing Date:
#
# 2019-06-28    1717
# 2014-12-30    1466
# 2019-06-27    1388
# 2008-06-26    1006
# 2008-06-25     842
# 2019-06-26     833
# 2016-09-30     831
# 2014-12-29     808
# 2011-02-04     763
# 2008-02-15     738
# Name: Pre-Filing Date, dtype: int64
#
# Top 10 Paid Date:
#
# NaT           9068
# 2019-06-28    1700
# 2014-12-30    1484
# 2019-06-27    1319
# 2008-06-26    1259
# 2008-02-15     978
# 2011-02-04     915
# 2009-06-30     879
# 2008-06-25     866
# 2016-09-30     839
# Name: Paid Date, dtype: int64
#
# Top 10 Fully Paid Date:
#
# NaT           6578
# 2019-06-28    1702
# 2014-12-30    1515
# 2019-06-27    1310
# 2008-06-26    1222
# 2008-02-15     978
# 2011-02-04     916
# 2009-06-30     857
# 2016-09-30     844
# 2014-12-29     795
# Name: Fully Paid Date, dtype: int64
#
# Top 10 Assigned Date:
#
# NaT           578990
# 2009-07-01       575
# 2018-01-12       523
# 2018-03-22       512
# 2001-08-09       492
# 2014-12-30       487
# 2015-10-28       469
# 2019-06-28       449
# 2017-07-18       442
# 2008-06-26       438
# Name: Assigned Date, dtype: int64
#
# Top 10 Fully Permitted:
#
# NaT           465136
# 2015-11-12       487
# 2017-05-17       439
# 2016-11-15       439
# 2017-07-25       435
# 2001-08-15       429
# 2013-11-06       429
# 2015-11-04       429
# 2006-11-09       425
# 2016-09-13       422
# Name: Fully Permitted, dtype: int64
#
# Top 10 Approved Date:
#
# NaT           329875
# 2008-06-26       663
# 2008-06-25       529
# 2019-06-27       521
# 2019-06-28       514
# 2015-05-21       500
# 2005-11-10       476
# 2015-12-03       474
# 2016-08-03       446
# 2017-10-11       444
# Name: Approved Date, dtype: int64

# %% [markdown]
# ### Check the coherence of datetime values

# %% [markdown]
# These don't make sense, but it's not entirely clear if they should be swapped, or removed or what

# %%
df.loc[(df['Paid Date'] > df['Fully Paid Date'])
      &(~df['Paid Date'].isna() & ~df['Fully Paid Date'].isna())][['Paid Date', 'Fully Paid Date']]
# Out:
#          Paid Date Fully Paid Date
# 32504   2017-08-22      2017-07-14
# 32597   2017-08-22      2017-07-14
# 51216   2012-05-15      2012-05-10
# 54503   2003-10-22      2003-10-21
# 70688   2008-02-12      2007-04-10
# ...            ...             ...
# 1741165 2003-10-22      2003-10-21
# 1741166 2003-10-22      2003-10-21
# 1741168 2003-10-22      2003-10-21
# 1747747 2004-12-02      2004-05-26
# 1751739 2005-07-26      2004-08-11
#
# [175 rows x 2 columns]

# %% [markdown]
# Again here it's not clear how a job could be approved before being assigned, or how a job could have it's latest action date  before the Pre-filing date

# %%
df.loc[(df['Assigned Date'] > df['Approved Date'])
      &(~df['Assigned Date'].isna() & ~df['Approved Date'].isna())][['Assigned Date', 'Approved Date']]
# Out:
#         Assigned Date Approved Date
# 87         2009-04-10    2008-08-19
# 90         2021-04-29    2001-07-26
# 95         2010-06-01    2008-11-22
# 99         2017-05-16    2010-09-13
# 102        2021-01-12    2010-04-09
# ...               ...           ...
# 1774755    2007-12-12    2006-05-22
# 1774762    2017-04-10    2006-03-28
# 1774780    2007-09-06    2006-02-24
# 1774824    2020-04-23    2006-08-04
# 1774846    2006-11-15    2005-12-08
#
# [52251 rows x 2 columns]

# %%
df.loc[(df['Pre-Filing Date'] > df['Latest Action Date'])
      &(~df['Pre-Filing Date'].isna() & ~df['Latest Action Date'].isna())][['Pre-Filing Date', 'Latest Action Date']]
# Out:
#         Pre-Filing Date Latest Action Date
# 162244       2003-03-05         2003-01-14
# 1449046      2002-06-17         2002-06-14

# %% [markdown]
# ##### These are, however a small percentage of of our total jobs

# %% [markdown]
# Fraction of jobs Assigned after they were already approved out of total jobs

# %%
df.loc[df['Assigned Date'] > df['Approved Date']]['Assigned Date'].count()/df['Assigned Date'].count()
# Out:
# 0.043692437882667357

# %% [markdown]
# Fraction of jobs with Paid Dates after they were already Fully Paid out of total jobs

# %%
df.loc[df['Paid Date'] > df['Fully Paid Date']]['Paid Date'].count()/df['Paid Date'].count()
# Out:
# 9.910499693057667e-05

# %% [markdown]
# Fraction of jobs with latest action date before the prefiling date out of total jobs

# %%
df.loc[df['Pre-Filing Date'] > df['Latest Action Date']]['Pre-Filing Date'].count()/df['Pre-Filing Date'].count()
# Out:
# 1.1268418229596276e-06

# %% [markdown]
# ### Checking additional numerical columns for coherency

# %%
numerical_columns = ['Proposed Zoning Sqft',
       'Enlargement SQ Footage', 'Street Frontage', 'Existing # of Stories',
       'Proposed # of Stories', 'Existing Height', 'Proposed Height',
       'Existing Dwelling Units', 'Proposed Dwelling Units']

# %% [markdown]
# Try to convert these all to numeric values

# %%
for col in numerical_columns:
    df[col] = df[col].astype('str')

# %%
for col in numerical_columns:
    print(col)
    print(df.loc[(~df[col].str.isdigit())
      &(df[col]!='nan')][col])
    print()
# Out:
# Proposed Zoning Sqft
# Series([], Name: Proposed Zoning Sqft, dtype: object)
#
# Enlargement SQ Footage
# 329735    -9
# Name: Enlargement SQ Footage, dtype: object
#
# Street Frontage
# Series([], Name: Street Frontage, dtype: object)
#
# Existing # of Stories
# Series([], Name: Existing # of Stories, dtype: object)
#
# Proposed # of Stories
# Series([], Name: Proposed # of Stories, dtype: object)
#
# Existing Height
# Series([], Name: Existing Height, dtype: object)
#
# Proposed Height
# 148918    -12
# Name: Proposed Height, dtype: object
#
# Existing Dwelling Units
# 81471      ....4
# 472432         .
# 473098         .
# 1391906    ....1
# Name: Existing Dwelling Units, dtype: object
#
# Proposed Dwelling Units
# 81471      ....4
# 414247      NONE
# 472432         .
# 473098         .
# 1580164    ....1
# 1661125       -0
# 1744289     NON5
# Name: Proposed Dwelling Units, dtype: object

# %% [markdown]
# ### Fix these issues so we can covnert to numerical values:
#
# We're going to assume like before that these values are unintentially entered as negative when they should be postive

# %%
df['Enlargement SQ Footage'] = df['Enlargement SQ Footage'].str.replace('-', '', regex=False)
df['Proposed Height'] = df['Proposed Height'].str.replace('-', '', regex=False)

# %%
df['Existing Dwelling Units'] = df['Existing Dwelling Units'].str.replace('.', '', regex=False)
df['Existing Dwelling Units'] = df['Existing Dwelling Units'].str.replace('.', '', regex=False)

# %%
df['Proposed Dwelling Units'] = df['Proposed Dwelling Units'].str.replace('.', '', regex=False)
df['Proposed Dwelling Units'] = df['Proposed Dwelling Units'].str.replace('-', '', regex=False)
df['Proposed Dwelling Units'] = df['Proposed Dwelling Units'].str.replace('NONE', '0', regex=False)
df['Proposed Dwelling Units'] = df['Proposed Dwelling Units'].str.replace('NON5', '0', regex=False)

# %% [markdown]
# ##### Try to convert to numerical values now:

# %%
for col in numerical_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce', downcast='integer')

# %%
for col in numerical_columns:
    show_vals(col)
# Out:
# Top 10 Proposed Zoning Sqft:
#
# 0       1673007
# 1          1237
# 300         914
# 2000        374
# 240         340
# 4000        288
# 5000        288
# 3000        281
# 2400        273
# 2500        268
# Name: Proposed Zoning Sqft, dtype: int64
#
# Top 10 Enlargement SQ Footage:
#
# 0       1713528
# 200         309
# 300         265
# 600         262
# 1000        258
# 400         237
# 500         226
# 800         206
# 180         184
# 240         179
# Name: Enlargement SQ Footage, dtype: int64
#
# Top 10 Street Frontage:
#
# 0      1677539
# 25       11022
# 50        9018
# 40        8952
# 20        7187
# 60        4002
# 100       2866
# 30        2743
# 75        2146
# 80        1659
# Name: Street Frontage, dtype: int64
#
# Top 10 Existing # of Stories:
#
# 0     821455
# 2     175757
# 3     108225
# 1      99406
# 6      88726
# 4      84300
# 5      76888
# 12     27760
# 7      26001
# 8      16304
# Name: Existing # of Stories, dtype: int64
#
# Top 10 Proposed # of Stories:
#
# 0     396318
# 2     273451
# 3     185390
# 4     124845
# 6     120730
# 1     120561
# 5     109895
# 12     38990
# 7      37187
# 8      23778
# Name: Proposed # of Stories, dtype: int64
#
# Top 10 Existing Height:
#
# 0     821473
# 25     43140
# 30     40358
# 60     38804
# 40     28362
# 50     27507
# 20     26379
# 35     24752
# 55     24486
# 65     21095
# Name: Existing Height, dtype: int64
#
# Top 10 Proposed Height:
#
# 0     454072
# 25     65542
# 30     61360
# 60     52974
# 40     40521
# 50     39643
# 35     38274
# 20     32976
# 55     32631
# 24     27794
# Name: Proposed Height, dtype: int64
#
# Top 10 Existing Dwelling Units:
#
# NaN     1130762
# 1.0      118178
# 2.0       95230
# 0.0       40322
# 3.0       28818
# 4.0       20889
# 6.0       16972
# 8.0       15415
# 5.0        9777
# 10.0       9575
# Name: Existing Dwelling Units, dtype: int64
#
# Top 10 Proposed Dwelling Units:
#
# NaN     856125
# 1.0     172429
# 2.0     166602
# 3.0      57961
# 0.0      38944
# 4.0      30878
# 6.0      24269
# 8.0      23546
# 5.0      14786
# 10.0     14427
# Name: Proposed Dwelling Units, dtype: int64

# %% [markdown]
# Lets replace NaN values with 0 here and convert to ints

# %%
df['Existing Dwelling Units'].fillna(0, inplace=True)
df['Proposed Dwelling Units'].fillna(0, inplace=True)

# %%
df['Existing Dwelling Units'] = pd.to_numeric(df['Existing Dwelling Units'], errors='coerce', downcast='integer')
df['Proposed Dwelling Units'] = pd.to_numeric(df['Proposed Dwelling Units'], errors='coerce', downcast='integer')

# %%
for col in numerical_columns:
    print(col)
    print("Minimum: ", df[col].min())
    print("Maximum: ", df[col].max())
    print()
# Out:
# Proposed Zoning Sqft
# Minimum:  0
# Maximum:  29214765
#
# Enlargement SQ Footage
# Minimum:  0
# Maximum:  22304116
#
# Street Frontage
# Minimum:  0
# Maximum:  98558
#
# Existing # of Stories
# Minimum:  0
# Maximum:  999
#
# Proposed # of Stories
# Minimum:  0
# Maximum:  999
#
# Existing Height
# Minimum:  0
# Maximum:  99999
#
# Proposed Height
# Minimum:  0
# Maximum:  99999
#
# Existing Dwelling Units
# Minimum:  0
# Maximum:  52121
#
# Proposed Dwelling Units
# Minimum:  0
# Maximum:  52121

# %% [markdown]
# ##### Incorrect numerical values here. The tallest building in NYC in One World Trade Center, with 104 stories, and 1,776 ft.
#  All of these cannot be true:

# %%
df.loc[df['Existing # of Stories'] >= 105]
# Out:
#              Job # Doc #        Borough House #            Street Name  Block  \
# 66585    410138934    01         QUEENS   52-01  GRAND CENTRAL PARKWAY  02018
# 256683   500317891    01  STATEN ISLAND      77          WILBUR STREET  06668
# 267491   500518772    01  STATEN ISLAND     128        FRANKLIN AVENUE  00064
# 298171   110093906    01      MANHATTAN     216       WEST   18 STREET  00767
# 298405   110102898    01      MANHATTAN     216       WEST   18 STREET  00767
# ...            ...   ...            ...     ...                    ...    ...
# 981776   340357492    01       BROOKLYN     872                  3 AVE  00679
# 1015546  122809336    01      MANHATTAN     209         WEST 57 STREET  01029
# 1109444  140639637    01      MANHATTAN    1185            PARK AVENUE  01522
# 1137320  123114646    01      MANHATTAN     424        WEST END AVENUE  01228
# 1505238  103792692    01      MANHATTAN     360      PARK AVENUE SOUTH  00855
#
#            Lot    Bin # Job Type Job Status  ... SPECIAL_ACTION_STATUS  \
# 66585    00001  4458851       A2          X  ...                     N
# 256683   00085  5082753       DM          X  ...                     N
# 267491   00135  5148071       DM          X  ...                     N
# 298171   00054  1082391       A2          R  ...                     W
# 298405   00054  1082391       A2          X  ...                     N
# ...        ...      ...      ...        ...  ...                   ...
# 981776   00001  3336893       A2          H  ...                     W
# 1015546  00027  1024903       A2          R  ...                     N
# 1109444  00001  1048384       A3          X  ...                     N
# 1137320  00061  1032674       A3          X  ...                     N
# 1505238  00024  1016748       A1          X  ...                     N
#
#         SPECIAL_ACTION_DATE BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# 66585                   NaT             Q1                 0    40.745464
# 256683                  NaT             A3                 0    40.515355
# 267491                  NaT             N2                 0    40.642424
# 298171           2017-04-10             O6                 0    40.741366
# 298405                  NaT             O6                 0    40.741366
# ...                     ...            ...               ...          ...
# 981776           2016-03-01             E1                 0    40.657680
# 1015546                 NaT             D4                 0    40.765784
# 1109444                 NaT             D4                 0    40.784817
# 1137320                 NaT             D8                 0    40.785296
# 1505238                 NaT             O4                 0    40.741955
#
#         GIS_LONGITUDE  GIS_COUNCIL_DISTRICT  GIS_CENSUS_TRACT  \
# 66585      -73.847072                    21             38302
# 256683     -74.194042                    51               198
# 267491     -74.091954                    49                81
# 298171     -73.998614                     3                81
# 298405     -73.998614                     3                81
# ...               ...                   ...               ...
# 981776     -74.004195                    38                18
# 1015546    -73.980639                     4               137
# 1109444    -73.953800                     4             15801
# 1137320    -73.980457                     6               167
# 1505238    -73.985089                     2                56
#
#                                        GIS_NTA_NAME  GIS_BIN
# 66585                      park-cemetery-etc-Queens  4458851
# 256683   Annadale-Huguenot-Prince's Bay-Eltingville  5082753
# 267491    West New Brighton-New Brighton-St. George  5148071
# 298171   Hudson Yards-Chelsea-Flatiron-Union Square  1082391
# 298405   Hudson Yards-Chelsea-Flatiron-Union Square  1082391
# ...                                             ...      ...
# 981776                             Sunset Park West  3336893
# 1015546                       Midtown-Midtown South  1024903
# 1109444               Upper East Side-Carnegie Hill  1048384
# 1137320                             Upper West Side  1032674
# 1505238  Hudson Yards-Chelsea-Flatiron-Union Square  1016748
#
# [96 rows x 96 columns]

# %%
df.loc[df['Proposed # of Stories'] >= 105]['Proposed # of Stories']
# Out:
# 17181      135
# 53914      616
# 61690      212
# 66585      226
# 73462      275
#           ...
# 1745592    660
# 1749455    212
# 1753208    118
# 1754046    212
# 1754998    212
# Name: Proposed # of Stories, Length: 461, dtype: int16

# %%
df.loc[df['Existing Height'] > 1776]
# Out:
#              Job # Doc #    Borough House #        Street Name  Block    Lot  \
# 2439     340811508    01   BROOKLYN     922    ST MARKS AVENUE  01230  00009
# 13707    110086638    01  MANHATTAN     307   WEST   38 STREET  00762  00025
# 39367    321756694    01   BROOKLYN       1     BROOKLYN PLAZA  09999  00001
# 60031    122576328    01  MANHATTAN       1  CENTRAL PARK WEST  01113  07502
# 157268   401537477    01     QUEENS   61-62           56 DRIVE  02711  00075
# ...            ...   ...        ...     ...                ...    ...    ...
# 1369162  340724880    01   BROOKLYN     346            7TH AVE  01012  00045
# 1369168  340724915    01   BROOKLYN     346            7TH AVE  01012  00045
# 1386405  440620419    01     QUEENS   11171           179TH ST  10297  00048
# 1394603  340777234    01   BROOKLYN    1178   JEFFERSON AVENUE  03389  00014
# 1567890  104413859    01  MANHATTAN     455     MADISON AVENUE  01286  00021
#
#            Bin # Job Type Job Status  ... SPECIAL_ACTION_STATUS  \
# 2439     3031058       A2          D  ...                     N
# 13707    1013643       A2          J  ...                     N
# 39367    3856237       A2          X  ...                     N
# 60031    1027191       A2          X  ...                     N
# 157268   4432412       DM          X  ...                     N
# ...          ...      ...        ...  ...                   ...
# 1369162  3022378       A3          D  ...                     C
# 1369168  3022378       A3          D  ...                     W
# 1386405  4219592       A2          X  ...                     N
# 1394603  3077885       A3          D  ...                     C
# 1567890  1035462       A1          R  ...                     N
#
#         SPECIAL_ACTION_DATE BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# 2439                    NaT             M9                 0    40.674730
# 13707                   NaT             R0                 0    40.754946
# 39367                   NaT            NaN                 0          NaN
# 60031                   NaT             R0                 0    40.768529
# 157268                  NaT             B2                 0    40.723596
# ...                     ...            ...               ...          ...
# 1369162          2020-06-08             S5                 0    40.666440
# 1369168          2020-04-09             S5                 0    40.666440
# 1386405                 NaT             A2                 0    40.697401
# 1394603          2021-01-16             B2                 0    40.690347
# 1567890                 NaT             H1                 0    40.758114
#
#         GIS_LONGITUDE  GIS_COUNCIL_DISTRICT  GIS_CENSUS_TRACT  \
# 2439       -73.941468                    36               343
# 13707      -73.992175                     3               115
# 39367             NaN                   NaN               NaN
# 60031      -73.981588                     3               145
# 157268     -73.902894                    30               517
# ...               ...                   ...               ...
# 1369162    -73.981970                    39               151
# 1369168    -73.981970                    39               151
# 1386405    -73.772773                    27               424
# 1394603    -73.914182                    37               415
# 1567890    -73.975393                     4               102
#
#                   GIS_NTA_NAME  GIS_BIN
# 2439       Crown Heights North  3031058
# 13707                  Clinton  1013643
# 39367                      NaN      NaN
# 60031           Lincoln Square  1027191
# 157268                 Maspeth  4432410
# ...                        ...      ...
# 1369162     Park Slope-Gowanus  3022378
# 1369168     Park Slope-Gowanus  3022378
# 1386405             St. Albans  4219592
# 1394603         Bushwick South  3077885
# 1567890  Midtown-Midtown South  1035462
#
# [96 rows x 96 columns]

# %%
df.loc[df['Proposed Height'] > 1776]
# Out:
#              Job # Doc #    Borough House #       Street Name  Block    Lot  \
# 2439     340811508    01   BROOKLYN     922   ST MARKS AVENUE  01230  00009
# 12909    140928842    01  MANHATTAN       1        BOGUS LANE  00001  00001
# 13707    110086638    01  MANHATTAN     307  WEST   38 STREET  00762  00025
# 39367    321756694    01   BROOKLYN       1    BROOKLYN PLAZA  09999  00001
# 44987    140940285    01  MANHATTAN       1        BOGUS LANE  00001  00001
# ...            ...   ...        ...     ...               ...    ...    ...
# 1731553  301529665    01   BROOKLYN     630         61 STREET  05793  00020
# 1751078  301795546    01   BROOKLYN    2402          AVENUE P  06787  00001
# 1751230  301797214    01   BROOKLYN     275       PARK AVENUE  01874  00001
# 1760165  301897482    01   BROOKLYN     315         92 STREET  06086  00082
# 1760321  301899122    01   BROOKLYN     315         92 STREET  06086  00082
#
#            Bin # Job Type Job Status  ... SPECIAL_ACTION_STATUS  \
# 2439     3031058       A2          D  ...                     N
# 12909    1813360       NB          D  ...                     N
# 13707    1013643       A2          J  ...                     N
# 39367    3856237       A2          X  ...                     N
# 44987    1813360       NB          H  ...                     C
# ...          ...      ...        ...  ...                   ...
# 1731553  3143844       A1          X  ...                     N
# 1751078  3182688       A2          R  ...                     W
# 1751230  3054140       A2          X  ...                     N
# 1760165  3154757       NB          Q  ...                     W
# 1760321  3154757       A2          X  ...                     N
#
#         SPECIAL_ACTION_DATE BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# 2439                    NaT             M9                 0    40.674730
# 12909                   NaT            NaN                 0          NaN
# 13707                   NaT             R0                 0    40.754946
# 39367                   NaT            NaN                 0          NaN
# 44987            2020-11-15            NaN                 0          NaN
# ...                     ...            ...               ...          ...
# 1731553                 NaT             C3                 0    40.637080
# 1751078          2012-03-23             M9                 0    40.611381
# 1751230                 NaT             D6                 0    40.696012
# 1760165          2006-09-28             C2                 0    40.619276
# 1760321                 NaT             C2                 0    40.619276
#
#         GIS_LONGITUDE  GIS_COUNCIL_DISTRICT  GIS_CENSUS_TRACT  \
# 2439       -73.941468                    36               343
# 12909             NaN                   NaN               NaN
# 13707      -73.992175                     3               115
# 39367             NaN                   NaN               NaN
# 44987             NaN                   NaN               NaN
# ...               ...                   ...               ...
# 1731553    -74.013771                    38               118
# 1751078    -73.949627                    48               548
# 1751230    -73.967562                    35               543
# 1760165    -74.032023                    43                58
# 1760321    -74.032023                    43                58
#
#                        GIS_NTA_NAME  GIS_BIN
# 2439            Crown Heights North  3031058
# 12909                           NaN      NaN
# 13707                       Clinton  1013643
# 39367                           NaN      NaN
# 44987                           NaN      NaN
# ...                             ...      ...
# 1731553            Sunset Park East  3143844
# 1751078                     Madison  3182688
# 1751230  park-cemetery-etc-Brooklyn  3054140
# 1760165                   Bay Ridge  3154757
# 1760321                   Bay Ridge  3154757
#
# [205 rows x 96 columns]

# %% [markdown]
# The largest number of units in one building in NYC is < 1400

# %%
df.loc[df['Existing Dwelling Units'] >= 1400]['Job Description'][:35]
# Out:
# 11201            MODIFICATIONS TO EXISTING SPRINKLER SYSTEM
# 11276        MECHANICAL AND SPRINKLER WORK FOR RETAIL SHOP.
# 27445     INSTALLATION OF RRU UNITS  ON THE ROOF. INSTAL...
# 29219     APPLICATION FILED HEREWITH FOR THE CONSTRUCTIO...
# 30548     MODIFICATION TO EXISTING SPRINKLER SYSTEM AS P...
# 31968     ADDITIONS/MODIFICATIONS TO AN EXISTING FIRE AL...
# 48213     HEREWITH FILE PLANS TO COMBINE APTS. 24K AND 2...
# 55667     INSTALLATION OF  TEMPORARY PIPE SCAFFOLD AS SH...
# 67750     INSTALLATION OF DIRECT AIR COOLING UNIT AND EL...
# 301110    REMOVE EXISTING PLUMBING FIXTURES AND REPLACE ...
# 302846    INSTALLING TELECOMMUNICATIONS CABINETS MOUNTED...
# 303576    INSTALLATION OF 330 LINEAR FEET OF HEAVY DUTY ...
# 303577    INSTALLATION OF 100 LINEAR FEET OF HEAVY DUTY ...
# 303578    INSTALLATION OF 200 LINEAR FEET OF HEAVY DUTY ...
# 303697    ADDITIONS TO EXISTING MODIFIED CLASS J FIRE AL...
# 303701    INSTALLATION OF 335 LINEAR FEET OF HEAVY DUTY ...
# 303704    INSTALLATION OF 335 LINEAR FEET OF HEAVY DUTY ...
# 308428    HEREWITH PROPOSE TO INSTALL TWO ROOFTOP UNITS ...
# 317950    INSTALL SIDEWALK SHED A TOTAL OF 422 L.F AT 10...
# 320514    INSTALL SIDEWALK SHED A TOTAL OF 96 L.F AT 484...
# 320532    INSTALLING SIDEWALK SHED A TOTAL OF 96 FT LONG...
# 321679    ERECT PIPE SCAFFOLD 25 LF X 75 HIGH AT 395 SOU...
# 325116                DEMOLITION OF A RESIDENTIAL BUILDING.
# 334340    INSTALL SIDEWALK SHED A TOTAL OF 244 L.F AT 10...
# 344089    INSTALLATION OF HEAVY DUTY SIDEWALK SHED A TOT...
# 347377    ERECTION OF 344 LINEAR FEET OF HEAVY DUTY (300...
# 351490    HEREWITH PROPOSE TO CONSTRUCT NEW POURED CONCR...
# 366418                   INSTALL TWO STOREFRONT WALL PANELS
# 366664                                                  NaN
# 373869    MINOR GENERAL CONSTRUCTION TO ERECT PANEL DOOR...
# 374081    CREATING TELECOMMUNICATIONS ROOM WITH RELATED ...
# 374189    CREATING TELECCOMUNICATIONS ROOM WITH RELATED ...
# 378519    ENTRY RAMP DOWN TO BASEMENT, REPAIRS AND REFIN...
# 379551    ERECT A TOTAL OF 40 LINEAR FEET BY 8 FEET APPR...
# 388287    ERECT A TOTAL OF 40 LINEAR FEET BY 8 FEET APPR...
# Name: Job Description, dtype: object

# %% [markdown]
# #### map these clearly false numerical values to 0

# %%
df.loc[df['Existing # of Stories'] >= 105, 'Existing # of Stories'] = 0
df.loc[df['Proposed # of Stories'] >= 105, 'Proposed # of Stories'] = 0
df.loc[df['Existing Height'] >= 1776, 'Existing Height'] = 0
df.loc[df['Proposed Height'] >= 1776, 'Proposed Height'] = 0
df.loc[df['Existing Dwelling Units'] >= 1400, 'Existing Dwelling Units'] = 0
df.loc[df['Proposed Dwelling Units'] >= 1400, 'Existing Dwelling Units'] = 0

# %% [markdown]
# ## Districts

# %% [markdown]
# ### Looking at Zoning districts

# %%
#Residence (R), Commerical (C), Manufacturing (M)
show_vals("Zoning District 1")
show_vals("Zoning District 2")
# Out:
# Top 10 Zoning District 1:
#
# NaN     334788
# R6      149653
# R5       84427
# C5-3     64134
# R3-2     60428
# R7-2     59826
# R4       56798
# R6B      47886
# R8       42860
# R8B      39378
# Name: Zoning District 1, dtype: int64
#
# Top 10 Zoning District 2:
#
# NaN       1581238
# R8B         19305
# C5-2.5      14916
# R6          14544
# C5-3        10767
# R5           8202
# C6-6         7327
# R7-2         6440
# R8           5550
# C6-4.5       5046
# Name: Zoning District 2, dtype: int64

# %% [markdown]
# Some districts may contain invalid formats

# %%
#.4-4 looks weird
df["Zoning District 1"].value_counts(dropna=False)
# Out:
# NaN          334788
# R6           149653
# R5            84427
# C5-3          64134
# R3-2          60428
#               ...
# .4-4              1
# R7                1
# C1-2  R-6         1
# 15                1
# C2-3  R6          1
# Name: Zoning District 1, Length: 230, dtype: int64

# %%
#Checks for irregular values (values that do not start with (R), (C), (M))
df["Zoning District 1"] = df["Zoning District 1"].astype('str')
df.loc[(df["Zoning District 1"] != "nan") & ~df["Zoning District 1"].str.startswith(("C", "R", "M", "PARK", "BPC", "LH"))]["Zoning District 1"].value_counts()
# Out:
# HAZMAT201    36
# HAZMAT200    28
# HAZMAT199     3
# 15            1
# .4-4          1
# ____R4        1
# Name: Zoning District 1, dtype: int64

# %%
#Checks for irregular values (values that do not start with (R), (C), (M))
df["Zoning District 2"] = df["Zoning District 2"].astype('str')
df.loc[(df["Zoning District 2"] != "nan") & ~df["Zoning District 2"].str.startswith(("C", "R", "M", "PARK", "BPC", "LH"))]["Zoning District 2"].value_counts()
# Out:
# 31010    19
# 90729     7
# 00729     5
# 50623     5
# 50511     4
# 11205     4
# 01013     4
# 80917     3
# 70910     3
# 91222     2
# 31210     2
# 10509     1
# 80312     1
# 71219     1
# 81007     1
# 30819     1
# 10308     1
# 30430     1
# 31030     1
# 80430     1
# Name: Zoning District 2, dtype: int64

# %%
#turning the values above into np.nan
df.loc[(df["Zoning District 1"] != "nan") & ~df["Zoning District 1"].str.startswith(("C", "R", "M", "PARK", "BPC", "LH")), ["Zoning District 1"]] = np.nan
df.loc[(df["Zoning District 2"] != "nan") & ~df["Zoning District 2"].str.startswith(("C", "R", "M", "PARK", "BPC", "LH")), ["Zoning District 2"]] = np.nan

# %% [markdown]
# ### Looking at special districts

# %%
show_vals("Special District 1")
show_vals("Special District 2")
# Out:
# Top 10 Special District 1:
#
# NaN    1512732
# MID      84262
# LM       19170
# SRD      16578
# OP       11194
# PI        9937
# CL        9898
# DB        8219
# BR        6876
# TMU       6471
# Name: Special District 1, dtype: int64
#
# Top 10 Special District 2:
#
# NaN     1694955
# POPS      27848
# IBZ       23885
# MS4       10621
# GW         6711
# JAM        5924
# MIH        2955
# HILI       1005
# CONH        450
# BPRK        389
# Name: Special District 2, dtype: int64

# %%
#Checks to see if there are lower case values
df.loc[~df["Special District 1"].isna() & df["Special District 1"].str.islower()]
# Out:
# Empty DataFrame
# Columns: [Job #, Doc #, Borough, House #, Street Name, Block, Lot, Bin #, Job Type, Job Status, Job Status Description, Latest Action Date, Building Type, Community Board, Cluster, Landmarked, Adult Establishment, Loft Board, City Owned, Little e, PC Filed, eFiling Filed, Plumbing, Mechanical, Boiler, Fuel Burning, Fuel Storage, Standpipe, Sprinkler, Fire Alarm, Equipment, Fire Suppression, Curb Cut, Other, Other Description, Applicant's First Name, Applicant's Last Name, Applicant Professional Title, Applicant License #, Professional Cert, Pre-Filing Date, Paid Date, Fully Paid Date, Assigned Date, Approved Date, Fully Permitted, Initial Cost, Total Estimated Fee, Fee Status, Existing Zoning Sqft, Proposed Zoning Sqft, Horizontal Enlargement, Vertical Enlargement, Enlargement SQ Footage, Street Frontage, Existing # of Stories, Proposed # of Stories, Existing Height, Proposed Height, Existing Dwelling Units, Proposed Dwelling Units, Existing Occupancy, Proposed Occupancy, Site Fill, Zoning District 1, Zoning District 2, Zoning District 3, Special District 1, Special District 2, Owner Type, Non-Profit, Owner's First Name, Owner's Last Name, Owner's Business Name, Owner's House Number, Owner's House Street Name, Owner's House City, Owner's House State, Owner's House Zip, Owner's Phone #, Job Description, DOB Run Date, JOB_S1_NO, TOTAL_CONSTRUCTION_FLOOR_AREA, WITHDRAWAL_FLAG, SIGNOFF_DATE, SPECIAL_ACTION_STATUS, SPECIAL_ACTION_DATE, BUILDING_CLASS, JOB_NO_GOOD_COUNT, GIS_LATITUDE, GIS_LONGITUDE, GIS_COUNCIL_DISTRICT, GIS_CENSUS_TRACT, GIS_NTA_NAME, GIS_BIN]
# Index: []
#
# [0 rows x 96 columns]

# %% [markdown]
# ### Analysis

# %% [markdown]
# Zoning districts had some zones that were invalid such as number only values (ex.31010)  and we changed those values to nan
#
# The typical format for Zoning districts start with C, R, and N. There are also some special districts like PARK and BPC that we also checked
#
# Special Districts didn't have any noticable values that were out of place

# %% [markdown]
# ## Quick look at GIS

# %%
show_vals("GIS_LATITUDE")
show_vals("GIS_LONGITUDE")
show_vals("GIS_COUNCIL_DISTRICT")
show_vals("GIS_CENSUS_TRACT")
show_vals("GIS_NTA_NAME")
show_vals("GIS_BIN")
# Out:
# Top 10 GIS_LATITUDE:
#
# NaN          5656
# 40.748276    2409
# 40.751098    2194
# 40.758754    1542
# 40.754162    1415
# 40.703608    1404
# 40.733848    1297
# 40.764020    1291
# 40.711537    1276
# 40.740704    1198
# Name: GIS_LATITUDE, dtype: int64
#
# Top 10 GIS_LONGITUDE:
#
# NaN           5656
# -73.984690    2413
# -73.992926    2187
# -73.978692    1574
# -73.976557    1415
# -74.009691    1395
# -74.015673    1299
# -73.973189    1293
# -73.871578    1289
# -74.001844    1230
# Name: GIS_LONGITUDE, dtype: int64
#
# Top 10 GIS_COUNCIL_DISTRICT:
#
# 4     236661
# 3     150044
# 1     125003
# 2      72273
# 33     58658
# 6      54995
# 5      42078
# 39     38469
# 50     36227
# 34     35400
# Name: GIS_COUNCIL_DISTRICT, dtype: int64
#
# Top 10 GIS_CENSUS_TRACT:
#
# 7      16439
# 102    15630
# 33     14134
# 104    13873
# 92     13757
# 9      13587
# 96     13076
# 94     12487
# 137    12366
# 113    12356
# Name: GIS_CENSUS_TRACT, dtype: int64
#
# Top 10 GIS_NTA_NAME:
#
# Midtown-Midtown South                         153871
# Hudson Yards-Chelsea-Flatiron-Union Square     65690
# SoHo-TriBeCa-Civic Center-Little Italy         57634
# Turtle Bay-East Midtown                        53329
# Upper East Side-Carnegie Hill                  48410
# West Village                                   47274
# Battery Park City-Lower Manhattan              45006
# Upper West Side                                37742
# Murray Hill-Kips Bay                           29813
# Lenox Hill-Roosevelt Island                    23295
# Name: GIS_NTA_NAME, dtype: int64
#
# Top 10 GIS_BIN:
#
# NaN        22128
# 3000000    15627
# 4000000    14101
# 1000000    10230
# 2000000     5654
# 5000000     4654
# 1015862     2413
# 1014387     2193
# 1076262     1793
# 1085735     1415
# Name: GIS_BIN, dtype: int64

# %%
#Manually looking at some of these
df[["GIS_LATITUDE", "GIS_LONGITUDE", "GIS_COUNCIL_DISTRICT", "GIS_CENSUS_TRACT", "GIS_NTA_NAME", "GIS_BIN"]]
# Out:
#         GIS_LATITUDE GIS_LONGITUDE GIS_COUNCIL_DISTRICT GIS_CENSUS_TRACT  \
# 0          40.714365    -73.731171                   27              568
# 1          40.703428    -73.813796                   24              214
# 2          40.703428    -73.813796                   24              214
# 3          40.839538    -73.923177                   16              211
# 4          40.839538    -73.923177                   16              211
# ...              ...           ...                  ...              ...
# 1774868    40.593831    -73.950368                   48              592
# 1774869    40.630611    -74.027435                   43               66
# 1774870    40.620486    -73.994067                   38              252
# 1774871    40.687159    -73.955516                   36              233
# 1774872    40.722087    -73.939063                   34              449
#
#                                            GIS_NTA_NAME  GIS_BIN
# 0                                        Queens Village  4231025
# 1                               Briarwood-Jamaica Hills      NaN
# 2                               Briarwood-Jamaica Hills      NaN
# 3                                            Highbridge      NaN
# 4                                            Highbridge      NaN
# ...                                                 ...      ...
# 1774868  Sheepshead Bay-Gerritsen Beach-Manhattan Beach  3202124
# 1774869                                       Bay Ridge  3148750
# 1774870                                Bensonhurst West  3134197
# 1774871                                         Bedford  3056361
# 1774872                               East Williamsburg  3069864
#
# [1774872 rows x 6 columns]

# %%
#shouldn't be 0
df["GIS_LATITUDE"] = df["GIS_LATITUDE"].astype('float')
df["GIS_LATITUDE"].min()
# Out:
# 40.498807

# %%
df["GIS_LATITUDE"].max()
# Out:
# 40.913711

# %%
df.loc[df["GIS_LATITUDE"] == 0.0]
# Out:
# Empty DataFrame
# Columns: [Job #, Doc #, Borough, House #, Street Name, Block, Lot, Bin #, Job Type, Job Status, Job Status Description, Latest Action Date, Building Type, Community Board, Cluster, Landmarked, Adult Establishment, Loft Board, City Owned, Little e, PC Filed, eFiling Filed, Plumbing, Mechanical, Boiler, Fuel Burning, Fuel Storage, Standpipe, Sprinkler, Fire Alarm, Equipment, Fire Suppression, Curb Cut, Other, Other Description, Applicant's First Name, Applicant's Last Name, Applicant Professional Title, Applicant License #, Professional Cert, Pre-Filing Date, Paid Date, Fully Paid Date, Assigned Date, Approved Date, Fully Permitted, Initial Cost, Total Estimated Fee, Fee Status, Existing Zoning Sqft, Proposed Zoning Sqft, Horizontal Enlargement, Vertical Enlargement, Enlargement SQ Footage, Street Frontage, Existing # of Stories, Proposed # of Stories, Existing Height, Proposed Height, Existing Dwelling Units, Proposed Dwelling Units, Existing Occupancy, Proposed Occupancy, Site Fill, Zoning District 1, Zoning District 2, Zoning District 3, Special District 1, Special District 2, Owner Type, Non-Profit, Owner's First Name, Owner's Last Name, Owner's Business Name, Owner's House Number, Owner's House Street Name, Owner's House City, Owner's House State, Owner's House Zip, Owner's Phone #, Job Description, DOB Run Date, JOB_S1_NO, TOTAL_CONSTRUCTION_FLOOR_AREA, WITHDRAWAL_FLAG, SIGNOFF_DATE, SPECIAL_ACTION_STATUS, SPECIAL_ACTION_DATE, BUILDING_CLASS, JOB_NO_GOOD_COUNT, GIS_LATITUDE, GIS_LONGITUDE, GIS_COUNCIL_DISTRICT, GIS_CENSUS_TRACT, GIS_NTA_NAME, GIS_BIN]
# Index: []
#
# [0 rows x 96 columns]

# %% [markdown]
# #### Removed the the rows above because its obviously a filler job

# %%
df = df.drop(df[df["GIS_LATITUDE"] == 0.0].index)

# %%
df["GIS_LATITUDE"].min()
# Out:
# 40.498807

# %% [markdown]
# #### The min and max makes sense as the values range from Staten Island to the Bronx

# %%
df["GIS_LONGITUDE"] = df["GIS_LONGITUDE"].astype('float')
df["GIS_LONGITUDE"].min()
# Out:
# -74.254897

# %%
df["GIS_LONGITUDE"].max()
# Out:
# -73.700376

# %%
df.loc[df["GIS_LONGITUDE"] == -73.700376]
# Out:
#             Job # Doc # Borough House #      Street Name  Block    Lot  \
# 483592  420236097    01  QUEENS  270-03  HILLSIDE AVENUE  08781  00101
#
#           Bin # Job Type Job Status  ... SPECIAL_ACTION_STATUS  \
# 483592  4179641       A2          X  ...                     N
#
#        SPECIAL_ACTION_DATE BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# 483592                 NaT             K4                 0    40.739112
#
#        GIS_LONGITUDE  GIS_COUNCIL_DISTRICT  GIS_CENSUS_TRACT  \
# 483592    -73.700376                    23            157901
#
#                                GIS_NTA_NAME  GIS_BIN
# 483592  Glen Oaks-Floral Park-New Hyde Park  4179641
#
# [1 rows x 96 columns]

# %% [markdown]
# #### These longitudes and latitudes range from Queens to Staten Island which is also consistent with our dataset

# %%
df["GIS_COUNCIL_DISTRICT"] = df["GIS_COUNCIL_DISTRICT"].astype('float')
df["GIS_COUNCIL_DISTRICT"].min()
# Out:
# 1.0

# %%
df["GIS_COUNCIL_DISTRICT"].max()
# Out:
# 51.0

# %% [markdown]
# #### 1-51 are all valid districts

# %%
df["GIS_CENSUS_TRACT"] = df["GIS_CENSUS_TRACT"].astype('float')
df["GIS_CENSUS_TRACT"].min()
# Out:
# 1.0

# %%
df["GIS_CENSUS_TRACT"].max()
# Out:
# 157903.0

# %%
df.loc[df["GIS_CENSUS_TRACT"] == 157903]
# Out:
#              Job # Doc # Borough House #            Street Name  Block    Lot  \
# 88       402661106    01  QUEENS   86-31             256 STREET  08815  00022
# 569      440670891    01  QUEENS  260-05  EAST WILLISTON AVENUE  08790  00067
# 1170     440663480    01  QUEENS    8439             259 STREET  08789  00016
# 1842     440673745    01  QUEENS    8437             259 STREET  08789  00017
# 2940     440672880    01  QUEENS   84-47             266 STREET  08811  00008
# ...            ...   ...     ...     ...                    ...    ...    ...
# 1405459  421785955    01  QUEENS  261-06     EAST WILLISTON AVE  08804  00041
# 1406616  421960863    01  QUEENS   84-40             260 STREET  08789  00055
# 1406735  440665264    01  QUEENS   87-57               257TH ST  08825  00009
# 1407398  440666753    01  QUEENS  259-01                 87 AVE  08818  00006
# 1407782  421788088    01  QUEENS  259-01                 87 AVE  08818  00006
#
#            Bin # Job Type Job Status  ... SPECIAL_ACTION_STATUS  \
# 88       4180389       A2          P  ...                     W
# 569      4179917       A3          J  ...                     N
# 1170     4179857       A2          X  ...                     N
# 1842     4179858       A2          X  ...                     N
# 2940     4180318       A2          X  ...                     N
# ...          ...      ...        ...  ...                   ...
# 1405459  4180164       A3          R  ...                     N
# 1406616  4179887       A1          P  ...                     N
# 1406735  4180612       A2          R  ...                     N
# 1407398  4457139       A3          R  ...                     N
# 1407782  4457139       A1          J  ...                     N
#
#         SPECIAL_ACTION_DATE BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# 88               2021-04-30             A5                 0    40.732155
# 569                     NaT             A2                 0    40.735538
# 1170                    NaT             A5                 0    40.735991
# 1842                    NaT             A5                 0    40.736016
# 2940                    NaT             A1                 0    40.737270
# ...                     ...            ...               ...          ...
# 1405459                 NaT             O5                 0    40.735922
# 1406616                 NaT             A0                 0    40.736250
# 1406735                 NaT             A1                 0    40.729650
# 1407398                 NaT             B3                 0    40.731562
# 1407782                 NaT             B3                 0    40.731562
#
#         GIS_LONGITUDE  GIS_COUNCIL_DISTRICT  GIS_CENSUS_TRACT  \
# 88         -73.710287                  23.0          157903.0
# 569        -73.707479                  23.0          157903.0
# 1170       -73.708784                  23.0          157903.0
# 1842       -73.708794                  23.0          157903.0
# 2940       -73.702358                  23.0          157903.0
# ...               ...                   ...               ...
# 1405459    -73.706622                  23.0          157903.0
# 1406616    -73.707927                  23.0          157903.0
# 1406735    -73.708360                  23.0          157903.0
# 1407398    -73.707006                  23.0          157903.0
# 1407782    -73.707006                  23.0          157903.0
#
#                                 GIS_NTA_NAME  GIS_BIN
# 88       Glen Oaks-Floral Park-New Hyde Park  4180389
# 569      Glen Oaks-Floral Park-New Hyde Park  4179917
# 1170     Glen Oaks-Floral Park-New Hyde Park  4179857
# 1842     Glen Oaks-Floral Park-New Hyde Park  4179858
# 2940     Glen Oaks-Floral Park-New Hyde Park  4180318
# ...                                      ...      ...
# 1405459  Glen Oaks-Floral Park-New Hyde Park  4180164
# 1406616  Glen Oaks-Floral Park-New Hyde Park  4179887
# 1406735  Glen Oaks-Floral Park-New Hyde Park  4180612
# 1407398  Glen Oaks-Floral Park-New Hyde Park  4457139
# 1407782  Glen Oaks-Floral Park-New Hyde Park  4457139
#
# [798 rows x 96 columns]

# %% [markdown]
# #### No irregulars for census tract

# %%
df["GIS_BIN"] = df["GIS_BIN"].astype('float')
df["GIS_BIN"].min()
# Out:
# 1000000.0

# %%
df["GIS_BIN"] = df["GIS_BIN"].astype('float')
df["GIS_BIN"].max()
# Out:
# 5799501.0

# %%
df.loc[df["GIS_BIN"] == 1000000]
# Out:
#              Job # Doc #    Borough House #        Street Name  Block    Lot  \
# 29       121203722    02  MANHATTAN      96       SOUTH STREET     73     11
# 150      121187189    01  MANHATTAN     614  WEST 131ST STREET  01997  00001
# 220      121204106    01  MANHATTAN     140   WEST 24TH STREET  00799  00063
# 221      121204106    02  MANHATTAN     140   WEST 24TH STREET  00799  00063
# 241      123392300    01  MANHATTAN     614  WEST 131ST STREET  01997  00001
# ...            ...   ...        ...     ...                ...    ...    ...
# 1634700  110284139    01  MANHATTAN     130     LIBERTY STREET  00054  00001
# 1634778  110284889    01  MANHATTAN      10   WEST   48 STREET  01263  07501
# 1674194  120448122    01  MANHATTAN    3243           BROADWAY  01997  00030
# 1679202  120478107    01  MANHATTAN     142   WEST 24TH STREET  00799  00064
# 1686605  100714719    01  MANHATTAN     220   WEST   58 STREET  01029  00043
#
#            Bin # Job Type Job Status  ... SPECIAL_ACTION_STATUS  \
# 29       1090738       NB          R  ...                     N
# 150      1090647       A1          R  ...                     N
# 220      1090646       NB          R  ...                     N
# 221      1090646       NB          R  ...                     N
# 241      1090647       A2          R  ...                     N
# ...          ...      ...        ...  ...                   ...
# 1634700  1001059       A2          X  ...                     N
# 1634778  1090672       A2          R  ...                     W
# 1674194  1090647       A3          R  ...                     W
# 1679202  1090646       A2          R  ...                     N
# 1686605  1024906       A2          X  ...                     N
#
#         SPECIAL_ACTION_DATE BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# 29                      NaT             K2                 0    40.706381
# 150                     NaT             W6                 0    40.817876
# 220                     NaT             H2                 0    40.744080
# 221                     NaT             H2                 0    40.744080
# 241                     NaT             W6                 0    40.817876
# ...                     ...            ...               ...          ...
# 1634700                 NaT             O2                 0    40.710283
# 1634778          2019-10-09             K2                 0    40.757492
# 1674194          2020-03-16             W6                 0    40.817011
# 1679202                 NaT             H2                 0    40.744099
# 1686605                 NaT             D8                 0    40.766555
#
#         GIS_LONGITUDE  GIS_COUNCIL_DISTRICT  GIS_CENSUS_TRACT  \
# 29         -74.002882                   1.0            1501.0
# 150        -73.957730                   7.0             219.0
# 220        -73.993558                   3.0              91.0
# 221        -73.993558                   3.0              91.0
# 241        -73.957730                   7.0             219.0
# ...               ...                   ...               ...
# 1634700    -74.012989                   1.0              13.0
# 1634778    -73.978624                   4.0              96.0
# 1674194    -73.957344                   7.0             219.0
# 1679202    -73.993602                   3.0              91.0
# 1686605    -73.980419                   4.0             137.0
#
#                                        GIS_NTA_NAME    GIS_BIN
# 29                Battery Park City-Lower Manhattan  1000000.0
# 150                                  Manhattanville  1000000.0
# 220      Hudson Yards-Chelsea-Flatiron-Union Square  1000000.0
# 221      Hudson Yards-Chelsea-Flatiron-Union Square  1000000.0
# 241                                  Manhattanville  1000000.0
# ...                                             ...        ...
# 1634700           Battery Park City-Lower Manhattan  1000000.0
# 1634778                       Midtown-Midtown South  1000000.0
# 1674194                              Manhattanville  1000000.0
# 1679202  Hudson Yards-Chelsea-Flatiron-Union Square  1000000.0
# 1686605                       Midtown-Midtown South  1000000.0
#
# [10230 rows x 96 columns]

# %%
df.loc[df["GIS_BIN"] == 5799501]
# Out:
#              Job # Doc #        Borough House #       Street Name  Block  \
# 263816   500476399    01  STATEN ISLAND       1     RICHMOND TERR  00002
# 263817   500476399    02  STATEN ISLAND       1     RICHMOND TERR  00002
# 263818   500476399    03  STATEN ISLAND       1     RICHMOND TERR  00002
# 263819   500476399    04  STATEN ISLAND       1     RICHMOND TERR  00002
# 265089   500490346    01  STATEN ISLAND       1     RICHMOND TERR  00185
# 267004   500513107    01  STATEN ISLAND       1     RICHMOND TERR  00002
# 268049   500524907    01  STATEN ISLAND       1     RICHMOND TERR  00002
# 268456   500530124    01  STATEN ISLAND       1     RICHMOND TERR  00185
# 268818   500553108    01  STATEN ISLAND       1     RICHMOND TERR  00185
# 268869   500553787    01  STATEN ISLAND       1     RICHMOND TERR  00185
# 269964   500569556    01  STATEN ISLAND       1     RICHMOND TERR  00185
# 269965   500569565    01  STATEN ISLAND       1     RICHMOND TERR  00185
# 270972   500580659    01  STATEN ISLAND       1     RICHMOND TERR  00002
# 271136   500582513    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 271196   500583111    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 271366   500585002    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 271430   500585725    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 271583   500587297    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 272769   500599765    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 272843   500600655    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 273896   500621080    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 274437   500626487    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 274765   500630837    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 274766   500630846    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 276471   500648819    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 277084   500655105    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 277313   500657586    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 277314   500657595    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 279095   500684912    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 279096   500684912    02  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 281050   500706097    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 281051   500706104    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 282127   500734921    01  STATEN ISLAND       1     RICHMOND TERR  00002
# 284979   500774682    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 285261   500777536    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 293245   500863416    01  STATEN ISLAND       1  RICHMOND TERRACE  00185
# 293246   500863416    02  STATEN ISLAND       1  RICHMOND TERRACE  00185
# 293247   500863416    03  STATEN ISLAND       1  RICHMOND TERRACE  00185
# 293248   500863416    04  STATEN ISLAND       1  RICHMOND TERRACE  00185
# 293249   500863416    05  STATEN ISLAND       1  RICHMOND TERRACE  00185
# 293250   500863416    06  STATEN ISLAND       1  RICHMOND TERRACE  00185
# 293639   500867387    01  STATEN ISLAND       1  RICHMOND TERRACE  00185
# 293845   500869606    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 294099   500902062    01  STATEN ISLAND       1  RICHMOND TERRACE  00185
# 294280   500903953    01  STATEN ISLAND       1  RICHMOND TERRACE  00185
# 294281   500903953    02  STATEN ISLAND       1  RICHMOND TERRACE  00185
# 294282   500903953    03  STATEN ISLAND       1  RICHMOND TERRACE  00185
# 294283   500903962    01  STATEN ISLAND       1  RICHMOND TERRACE  00185
# 480878   520043881    01  STATEN ISLAND       1  RICHMOND TERRACE  00185
# 495237   520049787    01  STATEN ISLAND       1  RICHMOND TERRACE  00185
# 508899   520055403    01  STATEN ISLAND       1  RICHMOND TERRACE  00185
# 544306   520069078    01  STATEN ISLAND       1  RICHMOND TERRACE  00185
# 688682   520127381    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 711065   520145726    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 723440   520149713    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 762631   520183621    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 1002355  520226121    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 1002426  520226121    02  STATEN ISLAND       1  RICHMOND TERRACE  00002
# 1020686  520296581    01  STATEN ISLAND       1  RICHMOND TERRACE  00002
#
#            Lot    Bin # Job Type Job Status  ... SPECIAL_ACTION_STATUS  \
# 263816   00001  5141706       A1          R  ...                   NaN
# 263817   00001  5141706       A1          J  ...                   NaN
# 263818   00001  5141706       A1          J  ...                   NaN
# 263819   00001  5141706       A1          R  ...                   NaN
# 265089   00203  5141706       A2          X  ...                     N
# 267004   00001  5141706       A2          X  ...                     N
# 268049   00001  5141706       A2          X  ...                     N
# 268456   00203  5141706       A3          X  ...                     N
# 268818   00203  5141706       A2          X  ...                     N
# 268869   00203  5141706       A2          X  ...                     N
# 269964   00203  5141706       A2          X  ...                     N
# 269965   00203  5141706       A2          X  ...                     N
# 270972   00001  5141706       A2          X  ...                     N
# 271136   00001  5141706       A2          X  ...                     N
# 271196   00001  5141706       A2          X  ...                     N
# 271366   00001  5141706       A2          X  ...                     N
# 271430   00001  5141706       A2          X  ...                     N
# 271583   00001  5141706       A2          X  ...                     N
# 272769   00001  5141706       A3          P  ...                     W
# 272843   00001  5141706       A2          X  ...                     N
# 273896   00001  5141706       A2          X  ...                     N
# 274437   00001  5141706       A2          X  ...                     N
# 274765   00001  5141706       A2          X  ...                     N
# 274766   00001  5141706       A2          X  ...                     N
# 276471   00001  5141706       A2          X  ...                     N
# 277084   00001  5141706       A2          X  ...                     N
# 277313   00001  5141706       A2          X  ...                     N
# 277314   00001  5141706       A2          X  ...                     N
# 279095   00001  5141706       A2          X  ...                     N
# 279096   00001  5141706       A2          X  ...                     A
# 281050   00001  5141706       A2          X  ...                     N
# 281051   00001  5141706       A2          R  ...                     W
# 282127   00001  5141706       PA          U  ...                   NaN
# 284979   00001  5141706       A2          X  ...                     N
# 285261   00001  5141706       A2          X  ...                     N
# 293245   00203  5141706       A2          R  ...                     C
# 293246   00203  5141706       A2          J  ...                     C
# 293247   00203  5141706       A2          R  ...                     C
# 293248   00203  5141706       A2          R  ...                     C
# 293249   00203  5141706       A2          R  ...                     C
# 293250   00203  5141706       A2          R  ...                     C
# 293639   00203  5141706       A2          R  ...                     N
# 293845   00001  5141706       A2          R  ...                     N
# 294099   00203  5141706       A2          P  ...                     W
# 294280   00203  5141706       A2          Q  ...                     N
# 294281   00203  5141706       A2          R  ...                     A
# 294282   00203  5141706       A2          R  ...                     A
# 294283   00203  5141706       A2          R  ...                     N
# 480878   00203  5141706       A2          R  ...                     N
# 495237   00203  5141706       A2          X  ...                     N
# 508899   00203  5141706       A2          R  ...                     N
# 544306   00203  5141706       A2          X  ...                     N
# 688682   00001  5141706       A2          J  ...                     W
# 711065   00001  5141706       A2          P  ...                     W
# 723440   00001  5141706       A2          X  ...                     N
# 762631   00001  5141706       A2          X  ...                     N
# 1002355  00001  5141706       A2          P  ...                     N
# 1002426  00001  5141706       A2          P  ...                     N
# 1020686  00001  5141706       A2          X  ...                     N
#
#         SPECIAL_ACTION_DATE BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE  \
# 263816                  NaT             T9                 0    40.643845
# 263817                  NaT             T9                 0    40.643845
# 263818                  NaT             T9                 0    40.643845
# 263819                  NaT             T9                 0    40.643845
# 265089                  NaT             T9                 0    40.643845
# 267004                  NaT             T9                 0    40.643845
# 268049                  NaT             T9                 0    40.643845
# 268456                  NaT             T9                 0    40.643845
# 268818                  NaT             T9                 0    40.643845
# 268869                  NaT             T9                 0    40.643845
# 269964                  NaT             T9                 0    40.643845
# 269965                  NaT             T9                 0    40.643845
# 270972                  NaT             T9                 0    40.643845
# 271136                  NaT             T9                 0    40.643845
# 271196                  NaT             T9                 0    40.643845
# 271366                  NaT             T9                 0    40.643845
# 271430                  NaT             T9                 0    40.643845
# 271583                  NaT             T9                 0    40.643845
# 272769           2017-03-20             T9                 0    40.643845
# 272843                  NaT             T9                 0    40.643845
# 273896                  NaT             T9                 0    40.643845
# 274437                  NaT             T9                 0    40.643845
# 274765                  NaT             T9                 0    40.643845
# 274766                  NaT             T9                 0    40.643845
# 276471                  NaT             T9                 0    40.643845
# 277084                  NaT             T9                 0    40.643845
# 277313                  NaT             T9                 0    40.643845
# 277314                  NaT             T9                 0    40.643845
# 279095                  NaT             T9                 0    40.643845
# 279096                  NaT             T9                 0    40.643845
# 281050                  NaT             T9                 0    40.643845
# 281051           2018-11-30             T9                 0    40.643845
# 282127                  NaT             T9                 0    40.643845
# 284979                  NaT             T9                 0    40.643845
# 285261                  NaT             T9                 0    40.643845
# 293245           2019-01-22             T9                 0    40.643845
# 293246           2019-01-22             T9                 0    40.643845
# 293247           2019-01-22             T9                 0    40.643845
# 293248           2019-01-22             T9                 0    40.643845
# 293249           2019-01-22             T9                 0    40.643845
# 293250           2019-01-22             T9                 0    40.643845
# 293639                  NaT             T9                 0    40.643845
# 293845                  NaT             T9                 0    40.643845
# 294099           2017-03-20             T9                 0    40.643845
# 294280                  NaT             T9                 0    40.643845
# 294281                  NaT             T9                 0    40.643845
# 294282                  NaT             T9                 0    40.643845
# 294283                  NaT             T9                 0    40.643845
# 480878                  NaT             T9                 0    40.643845
# 495237                  NaT             T9                 0    40.643845
# 508899                  NaT             T9                 0    40.643845
# 544306                  NaT             T9                 0    40.643845
# 688682           2016-04-20             T9                 0    40.643845
# 711065           2016-09-13             T9                 0    40.643845
# 723440                  NaT             T9                 0    40.643845
# 762631                  NaT             T9                 0    40.643845
# 1002355                 NaT             T9                 0    40.643845
# 1002426                 NaT             T9                 0    40.643845
# 1020686                 NaT             T9                 0    40.643845
#
#         GIS_LONGITUDE  GIS_COUNCIL_DISTRICT  GIS_CENSUS_TRACT  \
# 263816     -74.073387                  49.0               3.0
# 263817     -74.073387                  49.0               3.0
# 263818     -74.073387                  49.0               3.0
# 263819     -74.073387                  49.0               3.0
# 265089     -74.073387                  49.0               3.0
# 267004     -74.073387                  49.0               3.0
# 268049     -74.073387                  49.0               3.0
# 268456     -74.073387                  49.0               3.0
# 268818     -74.073387                  49.0               3.0
# 268869     -74.073387                  49.0               3.0
# 269964     -74.073387                  49.0               3.0
# 269965     -74.073387                  49.0               3.0
# 270972     -74.073387                  49.0               3.0
# 271136     -74.073387                  49.0               3.0
# 271196     -74.073387                  49.0               3.0
# 271366     -74.073387                  49.0               3.0
# 271430     -74.073387                  49.0               3.0
# 271583     -74.073387                  49.0               3.0
# 272769     -74.073387                  49.0               3.0
# 272843     -74.073387                  49.0               3.0
# 273896     -74.073387                  49.0               3.0
# 274437     -74.073387                  49.0               3.0
# 274765     -74.073387                  49.0               3.0
# 274766     -74.073387                  49.0               3.0
# 276471     -74.073387                  49.0               3.0
# 277084     -74.073387                  49.0               3.0
# 277313     -74.073387                  49.0               3.0
# 277314     -74.073387                  49.0               3.0
# 279095     -74.073387                  49.0               3.0
# 279096     -74.073387                  49.0               3.0
# 281050     -74.073387                  49.0               3.0
# 281051     -74.073387                  49.0               3.0
# 282127     -74.073387                  49.0               3.0
# 284979     -74.073387                  49.0               3.0
# 285261     -74.073387                  49.0               3.0
# 293245     -74.073387                  49.0               3.0
# 293246     -74.073387                  49.0               3.0
# 293247     -74.073387                  49.0               3.0
# 293248     -74.073387                  49.0               3.0
# 293249     -74.073387                  49.0               3.0
# 293250     -74.073387                  49.0               3.0
# 293639     -74.073387                  49.0               3.0
# 293845     -74.073387                  49.0               3.0
# 294099     -74.073387                  49.0               3.0
# 294280     -74.073387                  49.0               3.0
# 294281     -74.073387                  49.0               3.0
# 294282     -74.073387                  49.0               3.0
# 294283     -74.073387                  49.0               3.0
# 480878     -74.073387                  49.0               3.0
# 495237     -74.073387                  49.0               3.0
# 508899     -74.073387                  49.0               3.0
# 544306     -74.073387                  49.0               3.0
# 688682     -74.073387                  49.0               3.0
# 711065     -74.073387                  49.0               3.0
# 723440     -74.073387                  49.0               3.0
# 762631     -74.073387                  49.0               3.0
# 1002355    -74.073387                  49.0               3.0
# 1002426    -74.073387                  49.0               3.0
# 1020686    -74.073387                  49.0               3.0
#
#                                       GIS_NTA_NAME    GIS_BIN
# 263816   West New Brighton-New Brighton-St. George  5799501.0
# 263817   West New Brighton-New Brighton-St. George  5799501.0
# 263818   West New Brighton-New Brighton-St. George  5799501.0
# 263819   West New Brighton-New Brighton-St. George  5799501.0
# 265089   West New Brighton-New Brighton-St. George  5799501.0
# 267004   West New Brighton-New Brighton-St. George  5799501.0
# 268049   West New Brighton-New Brighton-St. George  5799501.0
# 268456   West New Brighton-New Brighton-St. George  5799501.0
# 268818   West New Brighton-New Brighton-St. George  5799501.0
# 268869   West New Brighton-New Brighton-St. George  5799501.0
# 269964   West New Brighton-New Brighton-St. George  5799501.0
# 269965   West New Brighton-New Brighton-St. George  5799501.0
# 270972   West New Brighton-New Brighton-St. George  5799501.0
# 271136   West New Brighton-New Brighton-St. George  5799501.0
# 271196   West New Brighton-New Brighton-St. George  5799501.0
# 271366   West New Brighton-New Brighton-St. George  5799501.0
# 271430   West New Brighton-New Brighton-St. George  5799501.0
# 271583   West New Brighton-New Brighton-St. George  5799501.0
# 272769   West New Brighton-New Brighton-St. George  5799501.0
# 272843   West New Brighton-New Brighton-St. George  5799501.0
# 273896   West New Brighton-New Brighton-St. George  5799501.0
# 274437   West New Brighton-New Brighton-St. George  5799501.0
# 274765   West New Brighton-New Brighton-St. George  5799501.0
# 274766   West New Brighton-New Brighton-St. George  5799501.0
# 276471   West New Brighton-New Brighton-St. George  5799501.0
# 277084   West New Brighton-New Brighton-St. George  5799501.0
# 277313   West New Brighton-New Brighton-St. George  5799501.0
# 277314   West New Brighton-New Brighton-St. George  5799501.0
# 279095   West New Brighton-New Brighton-St. George  5799501.0
# 279096   West New Brighton-New Brighton-St. George  5799501.0
# 281050   West New Brighton-New Brighton-St. George  5799501.0
# 281051   West New Brighton-New Brighton-St. George  5799501.0
# 282127   West New Brighton-New Brighton-St. George  5799501.0
# 284979   West New Brighton-New Brighton-St. George  5799501.0
# 285261   West New Brighton-New Brighton-St. George  5799501.0
# 293245   West New Brighton-New Brighton-St. George  5799501.0
# 293246   West New Brighton-New Brighton-St. George  5799501.0
# 293247   West New Brighton-New Brighton-St. George  5799501.0
# 293248   West New Brighton-New Brighton-St. George  5799501.0
# 293249   West New Brighton-New Brighton-St. George  5799501.0
# 293250   West New Brighton-New Brighton-St. George  5799501.0
# 293639   West New Brighton-New Brighton-St. George  5799501.0
# 293845   West New Brighton-New Brighton-St. George  5799501.0
# 294099   West New Brighton-New Brighton-St. George  5799501.0
# 294280   West New Brighton-New Brighton-St. George  5799501.0
# 294281   West New Brighton-New Brighton-St. George  5799501.0
# 294282   West New Brighton-New Brighton-St. George  5799501.0
# 294283   West New Brighton-New Brighton-St. George  5799501.0
# 480878   West New Brighton-New Brighton-St. George  5799501.0
# 495237   West New Brighton-New Brighton-St. George  5799501.0
# 508899   West New Brighton-New Brighton-St. George  5799501.0
# 544306   West New Brighton-New Brighton-St. George  5799501.0
# 688682   West New Brighton-New Brighton-St. George  5799501.0
# 711065   West New Brighton-New Brighton-St. George  5799501.0
# 723440   West New Brighton-New Brighton-St. George  5799501.0
# 762631   West New Brighton-New Brighton-St. George  5799501.0
# 1002355  West New Brighton-New Brighton-St. George  5799501.0
# 1002426  West New Brighton-New Brighton-St. George  5799501.0
# 1020686  West New Brighton-New Brighton-St. George  5799501.0
#
# [59 rows x 96 columns]

# %% [markdown]
# #### Nothing wrong with GIS BIN either
