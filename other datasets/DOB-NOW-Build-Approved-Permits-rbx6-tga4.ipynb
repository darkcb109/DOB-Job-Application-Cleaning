# %%
import openclean
import glob
import pandas as pd
import numpy as np

# %%
# https://data.cityofnewyork.us/Housing-Development/Housing-New-York-Units-by-Building/hg8x-zxpr
# https://data.cityofnewyork.us/Housing-Development/DOB-NOW-Build-Approved-Permits/rbx6-tga4
# https://data.cityofnewyork.us/Housing-Development/Buildings-Selected-for-the-Alternative-Enforcement/hcir-3275

# %% [markdown]
# # Data Downloading
#
# Download the data using openClean

# %%
import gzip
import humanfriendly
import os

from openclean.data.source.socrata import Socrata

dataset = Socrata().dataset('rbx6-tga4')
datafile = './rbx6-tga4.tsv.gz'

if not os.path.isfile(datafile):
    with gzip.open(datafile, 'wb') as f:
        print('Downloading ...\n')
        dataset.write(f)


fsize = humanfriendly.format_size(os.stat(datafile).st_size)
print("Using '{}' in file {} of size {}".format(dataset.name, datafile, fsize))
# Out:
# Using 'DOB NOW: Build – Approved Permits' in file ./rbx6-tga4.tsv.gz of size 23.89 MB

# %% [markdown]
# # Data Loading
#
# Load the data into pandas and openClean dataset object

# %%
import pandas as pd
from openclean.pipeline import stream

df  = pd.read_csv(datafile, dtype='object', sep='\t')
ds = stream(datafile)

# %%
np.__version__
# Out:
# '1.18.5'

# %%
pd.__version__
# Out:
# '1.2.4'

# %%
import glob

# %%
glob.glob("*")
# Out:
# ['Buildings-Selected-for-the-Alternative-Enforcement-hcir-3275.ipynb',
#  'DOB-NOW-Build-Approved-Permits-rbx6-tga4.ipynb',
#  'hcir-3275.tsv.gz',
#  'hcir-3275_cleaned_data.csv',
#  'hg8x-zxpr.tsv.gz',
#  'hg8x-zxpr_cleaned_data.csv',
#  'Housing-New-York-Units-by-Building-hg8x-zxpr.ipynb',
#  'ic3t-wcy2.tsv.gz',
#  'rbx6-tga4.tsv.gz',
#  'rbx6-tga4_cleaned_data.csv',
#  'Untitled.ipynb']

# %% [markdown]
# ### Get some basic info about the dataset columns

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241445 entries, 0 to 241444
# Data columns (total 35 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Job Filing Number                     241445 non-null  object
#  1   Filing Reason                         241445 non-null  object
#  2   House No                              241445 non-null  object
#  3   Street Name                           241445 non-null  object
#  4   Borough                               241445 non-null  object
#  5   LOT                                   241297 non-null  object
#  6   Bin                                   241445 non-null  object
#  7   Block                                 241445 non-null  object
#  8   C B NO                                241308 non-null  object
#  9   Apt/Condo No(s)                       1645 non-null    object
#  10  Work on Floor                         240701 non-null  object
#  11  Work Type                             241445 non-null  object
#  12  Permittee's License Type              241445 non-null  object
#  13  Applicant License #                   241445 non-null  object
#  14  Applicant First Name                  241445 non-null  object
#  15  Applicant Middle Name                 103 non-null     object
#  16  Applicant Last Name                   241444 non-null  object
#  17  Applicant Business Name               241130 non-null  object
#  18  Applicant Business Address            214797 non-null  object
#  19  Filing Representative First Name      134218 non-null  object
#  20  Filing Representative Middle Initial  0 non-null       object
#  21  Filing Representative Last Name       134215 non-null  object
#  22  Filing Representative Business Name   132887 non-null  object
#  23  Work Permit                           241445 non-null  object
#  24  Approved Date                         241415 non-null  object
#  25  Issued Date                           241445 non-null  object
#  26  Expired Date                          241414 non-null  object
#  27  Job Description                       241444 non-null  object
#  28  Estimated Job Costs                   241444 non-null  object
#  29  Owner Business Name                   226579 non-null  object
#  30  Owner Name                            241441 non-null  object
#  31  Owner Street Address                  0 non-null       object
#  32  Owner City                            0 non-null       object
#  33  Owner State                           0 non-null       object
#  34  Owner Zip Code                        0 non-null       object
# dtypes: object(35)
# memory usage: 64.5+ MB
# <ipython-input-100-6ac79f7ef903>:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   df.info(verbose=True, null_counts=True)

# %% [markdown]
# If any rows are complete duplicates, drop them

# %%
df = df.drop_duplicates()

# %% [markdown]
# Take an a look at some of the rows to get an idea of what the datset looks like

# %%
df
# Out:
#        Job Filing Number                   Filing Reason House No  \
# 0           M00531234-I1                  Initial Permit       26
# 1           X00496654-I1                  Initial Permit     1051
# 2           B00579209-I1                  Initial Permit     1010
# 3           M00514656-I1                  Initial Permit       33
# 4           M00431823-I1                  Initial Permit      301
# ...                  ...                             ...      ...
# 241440      B00269752-I1  Renewal Permit Without Changes        1
# 241441      B00239369-I1                  Initial Permit      388
# 241442      M00083385-I1  Renewal Permit Without Changes       25
# 241443      M00052214-I1                  Initial Permit     1526
# 241444      B00275776-I1                  Initial Permit      211
#
#                 Street Name    Borough   LOT      Bin Block C B NO  \
# 0            SHERMAN AVENUE  MANHATTAN    98  1064238  2175    112
# 1        WESTCHESTER AVENUE      BRONX    64  2005808  2727    202
# 2            PACIFIC STREET   BROOKLYN    32  3428849  1133    308
# 3          WEST  125 STREET  MANHATTAN    21  1053501  1723    110
# 4            EAST 73 STREET  MANHATTAN     1  1044897  1448    108
# ...                     ...        ...   ...      ...   ...    ...
# 241440          MAIN STREET   BROOKLYN  7501  3346104    27    302
# 241441   CHRISTOPHER AVENUE   BROOKLYN   128  3084828  3811    316
# 241442        MURRAY STREET  MANHATTAN  7505  1001451   134    101
# 241443             1 AVENUE  MANHATTAN    48  1050355  1559    108
# 241444  MCGUINESS BOULEVARD   BROOKLYN  7501  3379800  2576    301
#
#        Apt/Condo No(s)  ...             Issued Date            Expired Date  \
# 0                  NaN  ...  06/23/2021 12:00:00 AM  06/23/2022 12:00:00 AM
# 1                  NaN  ...  05/06/2021 12:00:00 AM  12/31/2021 12:00:00 AM
# 2                  NaN  ...  08/19/2021 12:00:00 AM  07/20/2022 12:00:00 AM
# 3                  NaN  ...  05/06/2021 12:00:00 AM  04/01/2022 12:00:00 AM
# 4                  NaN  ...  06/04/2021 12:00:00 AM  03/11/2022 05:00:00 AM
# ...                ...  ...                     ...                     ...
# 241440             NaN  ...  07/10/2020 12:00:00 AM  02/23/2021 12:00:00 AM
# 241441             NaN  ...  12/23/2020 12:00:00 AM  07/20/2021 12:00:00 AM
# 241442             NaN  ...  01/21/2020 12:00:00 AM  11/03/2020 12:00:00 AM
# 241443             NaN  ...  07/06/2018 12:00:00 AM  09/30/2018 12:00:00 AM
# 241444             NaN  ...  12/12/2019 12:00:00 AM  12/12/2020 05:00:00 AM
#
#                        Job Description Estimated Job Costs  \
# 0        Installation of a temporarily                5000
# 1       INSTALL EXTERIOR ILLUMINATED W                1850
# 2       INSTALLATION OF SCAFFOLD FOR W                1000
# 3       Installation of temporary side                   1
# 4       Filing as per plans for the in                5000
# ...                                ...                 ...
# 241440  PAA being filed to reflect cha               26000
# 241441  INSTALLATION OF SPRINKLER SYST                1000
# 241442  INSTALLATION OF TEMPORARY (60'                1000
# 241443  installation of construction f                1000
# 241444  Install temporary construction                1000
#
#                Owner Business Name                Owner Name  \
# 0                               PR             SHLOIME GROSS
# 1            EIB WESTCHESTER 1 LLC              FRANK SCAFFA
# 2        TWIN GROUP ASSOCIATES INC         SOLOMON SCHWIMMER
# 3        CGM MANAGEMENT GROUP, INC           CARMINE MOLISSE
# 4       BROADWAY MERCER ASSOCIATES          CYNTHIA GONZALEZ
# ...                            ...                       ...
# 241440                         NaN  MARY FRANCES SHAUGHNESSY
# 241441                          PR               CHAIM SOBEL
# 241442      PHOENIX SUTTON STR INC              PIOTR SIWIEC
# 241443         NORDEST SERVICE LLC             JACK CALIENDO
# 241444          STELLAR MANAGEMENT             LYLE KAMESAKI
#
#        Owner Street Address Owner City Owner State Owner Zip Code
# 0                       NaN        NaN         NaN            NaN
# 1                       NaN        NaN         NaN            NaN
# 2                       NaN        NaN         NaN            NaN
# 3                       NaN        NaN         NaN            NaN
# 4                       NaN        NaN         NaN            NaN
# ...                     ...        ...         ...            ...
# 241440                  NaN        NaN         NaN            NaN
# 241441                  NaN        NaN         NaN            NaN
# 241442                  NaN        NaN         NaN            NaN
# 241443                  NaN        NaN         NaN            NaN
# 241444                  NaN        NaN         NaN            NaN
#
# [241160 rows x 35 columns]

# %% [markdown]
# ## Describe columns in groups so they fit on screen

# %%
df[df.columns[:20]].describe()
# Out:
#        Job Filing Number   Filing Reason House No Street Name    Borough  \
# count             241160          241160   241160      241160     241160
# unique            154749               4    13571        5601          5
# top         M00013853-I1  Initial Permit        1    BROADWAY  MANHATTAN
# freq                  51          168465     2202        6896     104056
#
#            LOT      Bin   Block  C B NO Apt/Condo No(s) Work on Floor  \
# count   241012   241160  241160  241023            1642        240439
# unique     761    59990   10146      70              91          7464
# top          1  1000855      16     105             OSP    Open Space
# freq     30378      322     577   25925            1188         32033
#
#             Work Type Permittee's License Type Applicant License #  \
# count          241160                   241160              241160
# unique             17                        8                9098
# top     Sidewalk Shed                       GC              032158
# freq            47166                   165325                3949
#
#        Applicant First Name Applicant Middle Name Applicant Last Name  \
# count                241160                   103              241159
# unique                 3394                     1                6287
# top                 MICHAEL                   GIL               SINGH
# freq                   7870                   103               19677
#
#         Applicant Business Name Applicant Business Address  \
# count                    240845                     214540
# unique                     9407                       9235
# top     EVEREST SCAFFOLDING INC           49-30 31ST PLACE
# freq                       4054                       2727
#
#        Filing Representative First Name
# count                            134035
# unique                             1527
# top                                 ELY
# freq                              12742

# %%
# Notes:
# Building Type looks binary and has 2 values + maybe NAN
# Cluster looks binary and has 2 values + maybe NAN
# Landmarked looks binary and has 4 values + maybe NAN
# Adult Establishment looks binary and has 2 values + maybe NAN
# Loft Board looks binary and has 2 values + maybe NAN
# City Owned looks binary and has 4 values + maybe NAN
# Little e looks binary and has 5 values + maybe NAN

# %%
df[df.columns[20:40]].describe()
# Out:
#        Filing Representative Middle Initial Filing Representative Last Name  \
# count                                     0                          134032
# unique                                    0                            2039
# top                                     NaN                       SEPULVEDA
# freq                                    NaN                           12808
#
#        Filing Representative Business Name      Work Permit  \
# count                               132705           241160
# unique                                2280           158655
# top                AE DESIGN SOLUTION INC.  M00013853-I1-SH
# freq                                 12741               21
#
#                  Approved Date             Issued Date  \
# count                   241130                  241160
# unique                    5396                    1254
# top     01/21/2020 12:00:00 AM  11/15/2021 12:00:00 AM
# freq                       515                     713
#
#                   Expired Date                 Job Description  \
# count                   241129                          241159
# unique                    2883                           50530
# top     08/06/2020 12:00:00 AM  INSTALLATION OF HEAVY DUTY SID
# freq                      6213                            8995
#
#        Estimated Job Costs Owner Business Name    Owner Name  \
# count               241159              226308        241156
# unique               17891               17520         32773
# top                   1000                  PR  CHIRAG PATEL
# freq                 23230               42463          4396
#
#        Owner Street Address Owner City Owner State Owner Zip Code
# count                     0          0           0              0
# unique                    0          0           0              0
# top                     NaN        NaN         NaN            NaN
# freq                    NaN        NaN         NaN            NaN

# %%
df.columns
# Out:
# Index(['Job Filing Number', 'Filing Reason', 'House No', 'Street Name',
#        'Borough', 'LOT', 'Bin', 'Block', 'C B NO', 'Apt/Condo No(s)',
#        'Work on Floor', 'Work Type', 'Permittee's License Type',
#        'Applicant License #', 'Applicant First Name', 'Applicant Middle Name',
#        'Applicant Last Name', 'Applicant Business Name',
#        'Applicant Business Address', 'Filing Representative First Name',
#        'Filing Representative Middle Initial',
#        'Filing Representative Last Name',
#        'Filing Representative Business Name', 'Work Permit', 'Approved Date',
#        'Issued Date', 'Expired Date', 'Job Description', 'Estimated Job Costs',
#        'Owner Business Name', 'Owner Name', 'Owner Street Address',
#        'Owner City', 'Owner State', 'Owner Zip Code'],
#       dtype='object')

# %% [markdown]
# ### Examining Applicant License #

# %% [markdown]
# Some repition in the Applicant License #, but nothing major. We will check some of the repeated Applicant License # to be sure they actually refer to the same jobs

# %%
df['Applicant License #'].value_counts(dropna=False)
# Out:
# 032158    3949
# 607447    3503
# 610440    3321
# 617232    2374
# 606141    2361
#           ...
# 617407       1
# 616825       1
# 614721       1
# 622626       1
# 619370       1
# Name: Applicant License #, Length: 9098, dtype: int64

# %% [markdown]
# Nothing weird looking here

# %%
df['Applicant License #'].min()
# Out:
# '000002'

# %%
df['Applicant License #'].max()
# Out:
# '999999'

# %%
df.loc[df['Applicant License #'].str.startswith('0')]
# Out:
#        Job Filing Number                   Filing Reason House No  \
# 1           X00496654-I1                  Initial Permit     1051
# 4           M00431823-I1                  Initial Permit      301
# 5           B00583762-I1                  Initial Permit      350
# 6           B00516232-I1                  Initial Permit      102
# 7           B00472417-I1     Renewal Permit with Changes     1329
# ...                  ...                             ...      ...
# 241434      M00154809-I1                  Initial Permit      212
# 241436      Q00099914-I1                  Initial Permit   259-73
# 241438      Q00001038-I1                  Initial Permit    66-20
# 241440      B00269752-I1  Renewal Permit Without Changes        1
# 241441      B00239369-I1                  Initial Permit      388
#
#                Street Name    Borough   LOT      Bin  Block C B NO  \
# 1       WESTCHESTER AVENUE      BRONX    64  2005808   2727    202
# 4           EAST 73 STREET  MANHATTAN     1  1044897   1448    108
# 5            IRVING AVENUE   BROOKLYN    25  3076848   3362    304
# 6           PILLING STREET   BROOKLYN    29  3080348   3457    304
# 7        WILLOUGHBY AVENUE   BROOKLYN    35  3072801   3200    304
# ...                    ...        ...   ...      ...    ...    ...
# 241434      WEST 22 STREET  MANHATTAN    46  1014076    771    104
# 241436            148 ROAD     QUEENS     7  4290971  13687    413
# 241438    QUEENS BOULEVARD     QUEENS    19  4056084   2420    402
# 241440         MAIN STREET   BROOKLYN  7501  3346104     27    302
# 241441  CHRISTOPHER AVENUE   BROOKLYN   128  3084828   3811    316
#
#        Apt/Condo No(s)  ...             Issued Date            Expired Date  \
# 1                  NaN  ...  05/06/2021 12:00:00 AM  12/31/2021 12:00:00 AM
# 4                  NaN  ...  06/04/2021 12:00:00 AM  03/11/2022 05:00:00 AM
# 5                  NaN  ...  09/23/2021 12:00:00 AM  11/01/2021 04:00:00 AM
# 6                  NaN  ...  05/06/2021 12:00:00 AM  03/31/2022 12:00:00 AM
# 7                  NaN  ...  06/23/2021 12:00:00 AM  04/19/2022 12:00:00 AM
# ...                ...  ...                     ...                     ...
# 241434             NaN  ...  04/26/2019 12:00:00 AM  09/30/2020 01:00:00 AM
# 241436             NaN  ...  01/31/2019 12:00:00 AM  05/06/2019 12:00:00 AM
# 241438             NaN  ...  11/14/2017 12:00:00 AM  09/17/2018 12:00:00 AM
# 241440             NaN  ...  07/10/2020 12:00:00 AM  02/23/2021 12:00:00 AM
# 241441             NaN  ...  12/23/2020 12:00:00 AM  07/20/2021 12:00:00 AM
#
#                        Job Description Estimated Job Costs  \
# 1       INSTALL EXTERIOR ILLUMINATED W                1850
# 4       Filing as per plans for the in                5000
# 5       NON ILLUMINATED NON ADVERTISIN                4500
# 6       INSTALLATION OF TEMPORARY HEAV                1000
# 7       MODIFICATION OF PLUMBING AND S               68750
# ...                                ...                 ...
# 241434  INSTALLATION OF TEMPORARY CONS               10000
# 241436  PROPOSED TEMPORARY CONSTRUCTIO                1000
# 241438  NON ILLUMINATED NON ADVERTISIN                1200
# 241440  PAA being filed to reflect cha               26000
# 241441  INSTALLATION OF SPRINKLER SYST                1000
#
#                Owner Business Name                Owner Name  \
# 1            EIB WESTCHESTER 1 LLC              FRANK SCAFFA
# 4       BROADWAY MERCER ASSOCIATES          CYNTHIA GONZALEZ
# 5                              NaN               YASER OBYAH
# 6         EVEREST SCAFFOLDING INC.        CHRISTOPHER DOWNES
# 7          FM CONSOLIDATED HOLDING               TERESA CHUI
# ...                            ...                       ...
# 241434                          PR         STANLEY WASSERMAN
# 241436                         NaN           ANTHONY FINDLAY
# 241438           ROGOSIN INSTITUTE                AMMAR ALOW
# 241440                         NaN  MARY FRANCES SHAUGHNESSY
# 241441                          PR               CHAIM SOBEL
#
#        Owner Street Address Owner City Owner State Owner Zip Code
# 1                       NaN        NaN         NaN            NaN
# 4                       NaN        NaN         NaN            NaN
# 5                       NaN        NaN         NaN            NaN
# 6                       NaN        NaN         NaN            NaN
# 7                       NaN        NaN         NaN            NaN
# ...                     ...        ...         ...            ...
# 241434                  NaN        NaN         NaN            NaN
# 241436                  NaN        NaN         NaN            NaN
# 241438                  NaN        NaN         NaN            NaN
# 241440                  NaN        NaN         NaN            NaN
# 241441                  NaN        NaN         NaN            NaN
#
# [120465 rows x 35 columns]

# %% [markdown]
# Fraction of Rows with unique job numbers

# %%
df['Applicant License #'].nunique()/df['Applicant License #'].count()
# Out:
# 0.03772599104329076

# %% [markdown]
# Group by Job # and check if latitude and longitude are the same all the same for the job, which would indicate different instances of the Job # all refer to the same Job.

# %%
group = df[['Applicant License #', 'Job Filing Number']].groupby('Applicant License #')

# %% [markdown]
# This will take a little while to run

# %%
tranformed = group.aggregate(lambda x: x.unique().shape[0])

# %% [markdown]
# Jobs with multiple latitude and longitudes:

# %%
potential_bad_jobs = list(tranformed)

# %% [markdown]
# Separate these into a temporary dataframe to play around with:

# %%
df_temp = df.loc[df['Applicant License #'].isin(potential_bad_jobs)].copy()

# %%
df_temp = df_temp.sort_values(['Job Filing Number', 'Applicant License #'])

# %% [markdown]
# Most of these are just missing lat and long values.
#
# The others look to be Jobs that manage multiple houses/lots in a small area, so are probably correct

# %%
df_temp[df_temp.duplicated(subset=['Job Filing Number', 'Applicant License #'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [Job Filing Number, Filing Reason, House No, Street Name, Borough, LOT, Bin, Block, C B NO, Apt/Condo No(s), Work on Floor, Work Type, Permittee's License Type, Applicant License #, Applicant First Name, Applicant Middle Name, Applicant Last Name, Applicant Business Name, Applicant Business Address, Filing Representative First Name, Filing Representative Middle Initial, Filing Representative Last Name, Filing Representative Business Name, Work Permit, Approved Date, Issued Date, Expired Date, Job Description, Estimated Job Costs, Owner Business Name, Owner Name, Owner Street Address, Owner City, Owner State, Owner Zip Code]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# #### Later, after we have cleaned more values, we will fill these missing values by job #

# %% [markdown]
# Remove Jobs we know to be just missing data from the list of bad jobs

# %%
df_temp
# Out:
# Empty DataFrame
# Columns: [Job Filing Number, Filing Reason, House No, Street Name, Borough, LOT, Bin, Block, C B NO, Apt/Condo No(s), Work on Floor, Work Type, Permittee's License Type, Applicant License #, Applicant First Name, Applicant Middle Name, Applicant Last Name, Applicant Business Name, Applicant Business Address, Filing Representative First Name, Filing Representative Middle Initial, Filing Representative Last Name, Filing Representative Business Name, Work Permit, Approved Date, Issued Date, Expired Date, Job Description, Estimated Job Costs, Owner Business Name, Owner Name, Owner Street Address, Owner City, Owner State, Owner Zip Code]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# Latest action date is different, so its probably differnt but very similar jobs

# %% [markdown]
# Check if any Job #s have non-digit values

# %%
df['Applicant License #'] = df['Applicant License #'].astype('str')

# %%
df.loc[(~df['Applicant License #'].isna())
       &(~df['Applicant License #'].str.isdigit())]['Applicant License #']
# Out:
# Series([], Name: Applicant License #, dtype: object)

# %% [markdown]
# All Job #s entirely composed of digits, so we cast them to ints

# %%
df['Applicant License #'] = df['Applicant License #'].astype('str')

# %%
df['Applicant License #'].describe()
# Out:
# count     241160
# unique      9098
# top       032158
# freq        3949
# Name: Applicant License #, dtype: object

# %% [markdown]
# ## Examining and reparing Job Filing Number

# %% [markdown]
# Job Filing Number appear to be mostly ints
#
# However, there are legitimate house numbers with dashes so we'll have to make them strings

# %%
def show_vals(column_name, show_rows=10, df=df):
    print("Top {} {}:\n".format(show_rows, column_name))
    print(df[column_name].value_counts(dropna=False)[:show_rows])
    print()

# %%
show_vals('Job Filing Number', show_rows=10)
# Out:
# Top 10 Job Filing Number:
#
# M00013853-I1    51
# M00008120-I1    48
# M00042797-I1    48
# M00130581-I1    42
# X00073703-I1    39
# M00003926-I1    36
# M00000925-I1    36
# M00259999-I1    36
# M00165956-I1    36
# M00033650-I1    36
# Name: Job Filing Number, dtype: int64

# %% [markdown]
# Replace NaN values with empty strings, then convert column to string, and make everything uppercase

# %%
df['Job Filing Number'].fillna('', inplace=True)
df['Job Filing Number'] = df['Job Filing Number'].astype('str')
df['Job Filing Number'] = df['Job Filing Number'].str.upper()

# %% [markdown]
# Check for numbers spelled out as words

# %%
df.loc[(~df['Job Filing Number'].isna())
       &(df['Job Filing Number'].str.isalpha())]['Job Filing Number']
# Out:
# Series([], Name: Job Filing Number, dtype: object)

# %% [markdown]
# Check if thses are empty strings:

# %%
df.loc[(~df['Job Filing Number'].str.contains('\\d', regex=True))]['Job Filing Number']
# Out:
# 148257    PERMIT IS NO
# 178649    PERMIT IS NO
# 181411    PERMIT IS NO
# Name: Job Filing Number, dtype: object

# %% [markdown]
# Replace spelling of numbers with their value, and remove values 'PIER',  'MANHATTAN',  'NO NUMBER'

# %%
df.loc[df['Job Filing Number'].str.strip('')=='PERMIT IS NO', 'Job Filing Number'] = ''

# %% [markdown]
# Most of these will probably be legitimate house numbers, since house numbers can have dashes

# %%
df.loc[(~df['Job Filing Number'].isna())
       &(~df['Job Filing Number'].str.isdigit())]['Job Filing Number']
# Out:
# 0         M00531234-I1
# 1         X00496654-I1
# 2         B00579209-I1
# 3         M00514656-I1
# 4         M00431823-I1
#               ...
# 241440    B00269752-I1
# 241441    B00239369-I1
# 241442    M00083385-I1
# 241443    M00052214-I1
# 241444    B00275776-I1
# Name: Job Filing Number, Length: 241160, dtype: object

# %% [markdown]
# Check non-numeric house #'s that don't have dashes

# %%
df.loc[(~df['Job Filing Number'].isna())
       &(~df['Job Filing Number'].str.isdigit())
      &(~df['Job Filing Number'].str.contains('-', regex=False))]['Job Filing Number'][:25]
# Out:
# 148257
# 178649
# 181411
# Name: Job Filing Number, dtype: object

# %% [markdown]
# We see a mix of reference to the house's garage, the rear house and single letters that likely indicate apartments in multi-occupancy venues.
#
# We will standardize the formatting, and maintain the reference to garage, rear, and appartment, since there is no apartment column for the job.
#
# First split the numbers and words with a space

# %%
df['Job Filing Number'] = df['Job Filing Number'].str.replace(pat='(?P<one>\\d)(?P<two>[A-Z]+)', repl='\g<one> \g<two>', regex=True)

# %% [markdown]
# Now we will fix the formatting for garage and
# remove references to north, south, east, west, since they should be in street #

# %%
df['Job Filing Number'] = df['Job Filing Number'].str.replace(pat='(?P<one>GAR$)', repl='GARAGE', regex=True)

# %%
df['Job Filing Number'] = df['Job Filing Number'].str.replace(pat='NORTH([A-Z]+)?', repl='', regex=True)
df['Job Filing Number'] = df['Job Filing Number'].str.replace(pat='EAST([A-Z]+)?', repl='', regex=True)
df['Job Filing Number'] = df['Job Filing Number'].str.replace(pat='SOUTH([A-Z]+)?', repl='', regex=True)
df['Job Filing Number'] = df['Job Filing Number'].str.replace(pat='WEST([A-Z]+)?', repl='', regex=True)
df['Job Filing Number'] = df['Job Filing Number'].str.replace('PERMIT IS NO', repl='', regex=True)

# %%
# Confirm that it worked correctly:
df.loc[(~df['Job Filing Number'].isna())
       &(~df['Job Filing Number'].str.isdigit())
       &(~df['Job Filing Number'].str.contains('-', regex=False))]['Job Filing Number'][:30]
# Out:
# 148257
# 178649
# 181411
# Name: Job Filing Number, dtype: object

# %% [markdown]
# ## Examining and reparing House No

# %%
show_vals('House No', show_rows=10)
# Out:
# Top 10 House No:
#
# 1      2202
# 200    1306
# 10     1259
# 150    1042
# 55     1027
# 50     1020
# 100     960
# 40      871
# 60      861
# 30      853
# Name: House No, dtype: int64

# %% [markdown]
# Replace NaN values with empty strings, then convert column to string, and make everything uppercase

# %%
df['House No'].fillna('', inplace=True)
df['House No'] = df['House No'].astype('str')
df['House No'] = df['House No'].str.upper()

# %% [markdown]
# Check for numbers spelled out as words

# %%
df.loc[(~df['House No'].isna())
       &(df['House No'].str.isalpha())]['House No']
# Out:
# 13451     ONE
# 25394     ONE
# 25682     ONE
# 27946     ONE
# 30149     ONE
# 57475       I
# 58527     ONE
# 64326     ONE
# 78698     ONE
# 78809     ONE
# 79113     ONE
# 80899     ONE
# 80957     ONE
# 81001     ONE
# 102699    ONE
# 157256    ONE
# 160480    ONE
# 184336    ONE
# 195205    ONE
# 198739    ONE
# 201748      I
# 207613    ONE
# 215704    ONE
# 230633    ONE
# Name: House No, dtype: object

# %% [markdown]
# Check if thses are empty strings:

# %%
df.loc[(~df['House No'].str.contains('\\d', regex=True))]['House No']
# Out:
# 13451     ONE
# 25394     ONE
# 25682     ONE
# 27946     ONE
# 30149     ONE
# 57475       I
# 58527     ONE
# 64326     ONE
# 78698     ONE
# 78809     ONE
# 79113     ONE
# 80899     ONE
# 80957     ONE
# 81001     ONE
# 102699    ONE
# 157256    ONE
# 160480    ONE
# 184336    ONE
# 195205    ONE
# 198739    ONE
# 201748      I
# 207613    ONE
# 215704    ONE
# 230633    ONE
# Name: House No, dtype: object

# %% [markdown]
# Replace spelling of numbers with their value, and remove values 'PIER',  'MANHATTAN',  'NO NUMBER'

# %%
df.loc[df['House No'].str.strip('')=='ONE', 'House No'] = ''
df.loc[df['House No'].str.strip('')=='I', 'House No'] = ''

# %% [markdown]
# Most of these will probably be legitimate house numbers, since house numbers can have dashes

# %%
df.loc[(~df['House No'].isna())
       &(~df['House No'].str.isdigit())]['House No']
# Out:
# 12         57-28
# 30        112-27
# 35         99-06
# 42        133-43
# 43         82-08
#            ...
# 241425     34-19
# 241426     74-16
# 241432    161-01
# 241436    259-73
# 241438     66-20
# Name: House No, Length: 40083, dtype: object

# %% [markdown]
# Check non-numeric house #'s that don't have dashes

# %%
df.loc[(~df['House No'].isna())
       &(~df['House No'].str.isdigit())
      &(~df['House No'].str.contains('-', regex=False))]['House No'][:25]
# Out:
# 344          60B
# 971        111 A
# 1180       37GAR
# 1212        318A
# 1361       37GAR
# 1718       37GAR
# 1985        256A
# 2058        687A
# 2219    1668 GAR
# 2417        872A
# 2659    1568 AIR
# 3108     260 GAR
# 3307        500A
# 3360    435 REAR
# 3517        410A
# 3565    435 REAR
# 3645      126GAR
# 4881     108 1/2
# 5045     649 GAR
# 5129    435 REAR
# 5141        140B
# 5196       127 A
# 5605     108 1/2
# 5656        687A
# 5772        546A
# Name: House No, dtype: object

# %% [markdown]
# We see a mix of reference to the house's garage, the rear house and single letters that likely indicate apartments in multi-occupancy venues.
#
# We will standardize the formatting, and maintain the reference to garage, rear, and appartment, since there is no apartment column for the job.
#
# First split the numbers and words with a space

# %%
df['House No'] = df['House No'].str.replace(pat='(?P<one>\\d)(?P<two>[A-Z]+)', repl='\g<one> \g<two>', regex=True)

# %% [markdown]
# Now we will fix the formatting for garage and
# remove references to north, south, east, west, since they should be in street #

# %%
df['House No'] = df['House No'].str.replace(pat='(?P<one>GAR$)', repl='GARAGE', regex=True)

# %%
df['House No'] = df['House No'].str.replace(pat='NORTH([A-Z]+)?', repl='', regex=True)
df['House No'] = df['House No'].str.replace(pat='EAST([A-Z]+)?', repl='', regex=True)
df['House No'] = df['House No'].str.replace(pat='SOUTH([A-Z]+)?', repl='', regex=True)
df['House No'] = df['House No'].str.replace(pat='WEST([A-Z]+)?', repl='', regex=True)
df['House No'] = df['House No'].str.replace('PERMIT IS NO', repl='', regex=True)

# %%
# Confirm that it worked correctly:
df.loc[(~df['House No'].isna())
       &(~df['House No'].str.isdigit())
       &(~df['House No'].str.contains('-', regex=False))]['Job Filing Number'][:30]
# Out:
# 344     M00502410-I1
# 971     M00586909-I1
# 1180    S00481244-I1
# 1212    B00552927-I1
# 1361    S00481244-I1
# 1718    S00481244-I1
# 1985    B00466719-I1
# 2058    B00345683-I1
# 2219    B00510739-I1
# 2417    B00285820-I1
# 2659    M00342682-I1
# 3108    S00308390-I1
# 3307    B00315901-I1
# 3360    M71340105-I1
# 3517    B00502812-I1
# 3565    M00370497-I1
# 3645    S00510751-I1
# 4881    M00367069-I1
# 5045    B00455946-I1
# 5129    M00370497-I1
# 5141    B00480587-I1
# 5196    B00519943-I1
# 5605    M00367093-I1
# 5656    B00500777-I1
# 5772    M00510354-I1
# 5775    Q00418044-I1
# 5931    X00067946-I1
# 5987    B00498189-I1
# 6071    S00078639-I1
# 6103    S00515398-I1
# Name: Job Filing Number, dtype: object

# %% [markdown]
# ## Checking owner's information

# %%
def show_vals(column_name, show_rows=10, df=df):
    print("Top {} {}:\n".format(show_rows, column_name))
    print(df[column_name].value_counts(dropna=False))
    print()

# %%
show_vals("Owner Business Name")
show_vals("Owner Street Address")
show_vals("Owner City")
show_vals("Owner State")
show_vals("Owner Zip Code")
# Out:
# Top 10 Owner Business Name:
#
# PR                                 42463
# NaN                                14852
# NYCHA                               5896
# SPRING SCAFFOLDING LLC              3496
# ROCK GROUP NY CORP                  3215
#                                    ...
# TANO GROUP ARCHITECT                   1
# ALPHA DESIGN NY INC                    1
# AB MARBEC REALTY CORP.                 1
# KINGSLAND REALTY ASSOCIATES LLC        1
# UNKNOWN                                1
# Name: Owner Business Name, Length: 17521, dtype: int64
#
# Top 10 Owner Street Address:
#
# NaN    241160
# Name: Owner Street Address, dtype: int64
#
# Top 10 Owner City:
#
# NaN    241160
# Name: Owner City, dtype: int64
#
# Top 10 Owner State:
#
# NaN    241160
# Name: Owner State, dtype: int64
#
# Top 10 Owner Zip Code:
#
# NaN    241160
# Name: Owner Zip Code, dtype: int64

# %% [markdown]
# ## Fixing owner's informations

# %%
df.loc[~df["Owner Business Name"].isna() & df["Owner Business Name"].str.contains("(?i)new york city")]["Owner Business Name"].value_counts()
# Out:
# NEW YORK CITY HOUSING AUTHORITY        841
# NEW YORK CITY ECONOMIC DEVELOPMENT     195
# NEW YORK CITY DEPARTMENT OF ENVIRON     41
# NEW YORK CITY DEPT. OF ENVIRONMENTA     20
# NEW YORK CITY DEPARTMENT OF DESIGN       7
# THE HOTEL @ NEW YORK CITY                5
# NEW YORK CITY TRANSIT                    5
# Name: Owner Business Name, dtype: int64

# %% [markdown]
# Normalizes a couple of duplicate names

# %%
df["Owner Business Name"] = df["Owner Business Name"].str.replace("NEW YORK CITY", "NYC")
df["Owner Business Name"] = df["Owner Business Name"].str.upper()
df["Owner Business Name"] = df["Owner Business Name"].str.replace(".", '', regex=False)
df["Owner Business Name"] = df["Owner Business Name"].str.replace(",", '', regex=False)

# %% [markdown]
# All these are the same thing. Uses clusters to fix

# %%
#may have to use fuzzy/cluster to fix this problem
df.loc[~df["Owner Business Name"].isna() & df["Owner Business Name"].str.contains("(?i)HOUSING AUTHORITY")]["Owner Business Name"].value_counts()
# Out:
# NYC HOUSING AUTHORITY    851
# Name: Owner Business Name, dtype: int64

# %% [markdown]
# All these states are valid

# %%
df["Owner State"].value_counts()
# Out:
# Series([], Name: Owner State, dtype: int64)

# %% [markdown]
# Since the states can be outside NYC, these are probably fine

# %%
df["Owner Zip Code"].value_counts()
# Out:
# Series([], Name: Owner Zip Code, dtype: int64)

# %% [markdown]
# ## Looking at Phone Numbers:

# %%
show_vals("Owner Street Address")
# Out:
# Top 10 Owner Street Address:
#
# NaN    241160
# Name: Owner Street Address, dtype: int64

# %%
show_vals("Owner City")
# Out:
# Top 10 Owner City:
#
# NaN    241160
# Name: Owner City, dtype: int64

# %% [markdown]
# A lot of the nan numbers

# %% [markdown]
# # Data Profilling for datetime columns
#
#
# Find format problems and outliers in all datetime columns
#
# Using openclean's sklearn modules to detect problems and outliers

# %%
from openclean.profiling.anomalies.sklearn import DBSCANOutliers

def findDateOutliers(column_name, eps_setting = 0.05):
    datetime_data = ds.distinct(column_name)
    print("Column: ",column_name)
    
    for rank, val in enumerate(datetime_data.most_common(10)):        
        st, freq = val
        print('{:<3} {:>8}  {:>10}'.format('{}.'.format(rank + 1), st, '{:,}'.format(freq)))

    print('\nTotal number of distinct values in {} is {}'.format(column_name, len(datetime_data)))
    print(DBSCANOutliers().find(datetime_data))
    print(DBSCANOutliers(eps = eps_setting).find(datetime_data))
    print('\n==================================')

# %%
date_cols = []

print("Datetime Data columns:\n")
for col in ds.columns:
    if 'Date' in col or 'DATE' in col:
        print(col)
        date_cols.append(col)

print("----------------------------\n")        
        
for col in date_cols:
    findDateOutliers(col, 0.02)
# Out:
# Datetime Data columns:
#
# Approved Date
# Issued Date
# Expired Date
# ----------------------------
#
# Column:  Approved Date
# 1.  01/21/2020 12:00:00 AM         515
# 2.  02/18/2020 12:00:00 AM         515
# 3.  05/27/2021 12:00:00 AM         495
# 4.  02/25/2020 12:00:00 AM         494
# 5.  07/09/2021 12:00:00 AM         491
# 6.  11/08/2019 12:00:00 AM         482
# 7.  04/13/2021 12:00:00 AM         461
# 8.  04/21/2021 12:00:00 AM         460
# 9.  01/24/2020 12:00:00 AM         460
# 10. 03/03/2020 12:00:00 AM         457
#
# Total number of distinct values in Approved Date is 5397
# ['']
# ['', '01/21/2020 12:00:00 AM', '12/01/2021 12:00:00 AM', '08/27/2019 12:00:00 AM', '01/24/2020 12:00:00 AM', '10/21/2020 12:00:00 AM', '02/25/2020 12:00:00 AM', '01/10/2020 12:00:00 AM', '10/20/2020 12:00:00 AM', '08/07/2019 12:00:00 AM', '10/01/2020 12:00:00 AM', '05/27/2021 12:00:00 AM', '10/12/2021 12:00:00 AM', '01/12/2021 12:00:00 AM', '04/21/2021 12:00:00 AM', '02/18/2020 12:00:00 AM', '05/03/2018 12:00:00 AM', '10/22/2020 12:00:00 AM', '10/01/2021 12:00:00 AM', '08/23/2019 12:00:00 AM', '02/12/2020 12:00:00 AM', '11/22/2021 12:00:00 AM', '03/27/2018 12:00:00 AM', '03/03/2020 12:00:00 AM', '11/08/2019 12:00:00 AM', '11/22/2020 12:00:00 AM', '02/21/2021 12:00:00 AM', '08/15/2019 12:00:00 AM', '07/09/2021 12:00:00 AM', '12/21/2020 12:00:00 AM', '12/02/2021 12:00:00 AM', '11/12/2019 12:00:00 AM']
#
# ==================================
# Column:  Issued Date
# 1.  11/15/2021 12:00:00 AM         715
# 2.  11/04/2021 12:00:00 AM         681
# 3.  05/10/2021 12:00:00 AM         671
# 4.  09/29/2021 12:00:00 AM         663
# 5.  04/15/2021 12:00:00 AM         658
# 6.  05/13/2021 12:00:00 AM         658
# 7.  11/03/2021 12:00:00 AM         657
# 8.  10/07/2021 12:00:00 AM         654
# 9.  10/20/2021 12:00:00 AM         647
# 10. 10/08/2021 12:00:00 AM         632
#
# Total number of distinct values in Issued Date is 1254
# []
# ['11/20/2020 12:00:00 AM', '02/01/2020 12:00:00 AM', '09/14/2021 12:00:00 AM', '10/12/2021 12:00:00 AM', '06/23/2016 08:15:04 AM', '05/13/2021 12:00:00 AM', '11/12/2021 12:00:00 AM', '11/02/2020 12:00:00 AM', '11/10/2021 12:00:00 AM', '05/10/2021 12:00:00 AM', '10/21/2021 12:00:00 AM', '02/22/2020 12:00:00 AM', '11/02/2021 12:00:00 AM', '10/07/2021 12:00:00 AM', '07/26/2018 12:00:00 AM', '04/15/2021 12:00:00 AM', '09/15/2021 12:00:00 AM', '09/24/2018 12:00:00 AM', '10/01/2021 12:00:00 AM', '11/03/2021 12:00:00 AM', '12/02/2020 12:00:00 AM', '11/20/2021 12:00:00 AM', '10/22/2021 12:00:00 AM', '11/04/2021 12:00:00 AM', '09/29/2021 12:00:00 AM', '10/20/2021 12:00:00 AM', '11/01/2021 12:00:00 AM', '11/15/2021 12:00:00 AM']
#
# ==================================
# Column:  Expired Date
# 1.  08/06/2020 12:00:00 AM       6,246
# 2.  12/31/2021 05:00:00 AM       5,618
# 3.  01/31/2021 12:00:00 AM       3,708
# 4.  12/31/2020 12:00:00 AM       3,572
# 5.  01/01/2022 05:00:00 AM       2,874
# 6.  04/01/2022 12:00:00 AM       2,068
# 7.  11/30/2020 12:00:00 AM       1,734
# 8.  10/31/2020 01:00:00 AM       1,691
# 9.  04/01/2021 12:00:00 AM       1,672
# 10. 03/31/2022 12:00:00 AM       1,632
#
# Total number of distinct values in Expired Date is 2884
# ['']
# ['', '07/19/2022 12:00:00 AM', '11/30/2020 12:00:00 AM', '05/01/2021 12:00:00 AM', '04/01/2018 12:00:00 AM', '01/01/2020 12:00:00 AM', '08/23/2019 04:00:00 AM', '01/01/2021 12:00:00 AM', '09/30/2020 12:00:00 AM', '12/31/2019 12:00:00 AM', '10/31/2020 01:00:00 AM', '08/06/2020 12:00:00 AM', '02/02/2022 12:00:00 AM', '01/31/2021 12:00:00 AM', '04/01/2021 12:00:00 AM', '09/30/2021 04:00:00 AM', '07/01/2021 04:00:00 AM', '08/03/2019 04:00:00 AM', '03/31/2022 12:00:00 AM', '12/31/2020 12:00:00 AM', '01/01/2022 05:00:00 AM', '04/01/2022 04:00:00 AM', '12/31/2021 05:00:00 AM', '06/30/2019 04:00:00 AM', '04/01/2022 12:00:00 AM', '09/30/2020 01:00:00 AM', '07/25/2019 12:00:00 AM', '12/31/2021 12:00:00 AM', '02/28/2022 12:00:00 AM', '08/27/2019 04:00:00 AM']
#
# ==================================

# %% [markdown]
# ## Fixing Datetime columns format

# %%
datetime_column_list = date_cols
for col in datetime_column_list:
    show_vals(col)
# Out:
# Top 10 Approved Date:
#
# 01/21/2020 12:00:00 AM    515
# 02/18/2020 12:00:00 AM    512
# 02/25/2020 12:00:00 AM    494
# 05/27/2021 12:00:00 AM    494
# 07/09/2021 12:00:00 AM    491
#                          ...
# 01/25/2019 09:10:00 AM      1
# 08/22/2019 11:37:00 AM      1
# 07/16/2018 10:06:00 AM      1
# 11/13/2018 07:07:00 PM      1
# 11/09/2020 09:48:00 AM      1
# Name: Approved Date, Length: 5397, dtype: int64
#
# Top 10 Issued Date:
#
# 11/15/2021 12:00:00 AM    713
# 11/04/2021 12:00:00 AM    679
# 05/10/2021 12:00:00 AM    671
# 09/29/2021 12:00:00 AM    662
# 05/13/2021 12:00:00 AM    658
#                          ...
# 10/17/2020 12:00:00 AM      1
# 11/03/2020 12:00:00 AM      1
# 07/27/2019 12:00:00 AM      1
# 11/28/2016 12:00:00 AM      1
# 02/19/2018 12:00:00 AM      1
# Name: Issued Date, Length: 1254, dtype: int64
#
# Top 10 Expired Date:
#
# 08/06/2020 12:00:00 AM    6213
# 12/31/2021 05:00:00 AM    5618
# 01/31/2021 12:00:00 AM    3708
# 12/31/2020 12:00:00 AM    3567
# 01/01/2022 05:00:00 AM    2874
#                           ...
# 02/05/2018 12:00:00 AM       1
# 05/25/2020 04:00:00 AM       1
# 02/17/2020 05:00:00 AM       1
# 12/04/2022 12:00:00 AM       1
# 11/25/2019 05:00:00 AM       1
# Name: Expired Date, Length: 2884, dtype: int64

# %% [markdown]
# Check to see if any columns have values in year-month-day format

# %%
for col in datetime_column_list:
    print(col, '\n', df.loc[df[col].str.contains('-', regex=False, na=False)][col], '\n\n')
# Out:
# Approved Date
#  Series([], Name: Approved Date, dtype: object)
#
#
# Issued Date
#  Series([], Name: Issued Date, dtype: object)
#
#
# Expired Date
#  Series([], Name: Expired Date, dtype: object)

# %% [markdown]
# ### Check the coherence of datetime values

# %% [markdown]
# These don't make sense, but it's not entirely clear if they should be swapped, or removed or what

# %%
df.loc[(df['Approved Date'] < df['Expired Date'])
      &(~df['Approved Date'].isna() & ~df['Expired Date'].isna())][['Approved Date', 'Expired Date']]
# Out:
#                  Approved Date            Expired Date
# 0       06/23/2021 12:00:00 AM  06/23/2022 12:00:00 AM
# 1       05/06/2021 12:00:00 AM  12/31/2021 12:00:00 AM
# 5       09/20/2021 12:00:00 AM  11/01/2021 04:00:00 AM
# 7       02/24/2021 12:00:00 AM  04/19/2022 12:00:00 AM
# 11      08/10/2020 12:00:00 AM  12/26/2021 12:00:00 AM
# ...                        ...                     ...
# 241439  10/03/2018 12:00:00 AM  10/03/2019 12:00:00 AM
# 241441  06/29/2020 12:00:00 AM  07/20/2021 12:00:00 AM
# 241442  10/03/2018 12:00:00 AM  11/03/2020 12:00:00 AM
# 241443  07/06/2018 12:00:00 AM  09/30/2018 12:00:00 AM
# 241444  12/12/2019 12:00:00 AM  12/12/2020 05:00:00 AM
#
# [137171 rows x 2 columns]

# %%
df.loc[(df['Approved Date'] > df['Expired Date'])
      &(~df['Approved Date'].isna() & ~df['Approved Date'].isna())][['Approved Date', 'Expired Date']]
# Out:
#                  Approved Date            Expired Date
# 2       08/19/2021 12:00:00 AM  07/20/2022 12:00:00 AM
# 3       05/06/2021 12:00:00 AM  04/01/2022 12:00:00 AM
# 4       12/14/2020 12:00:00 AM  03/11/2022 05:00:00 AM
# 6       05/06/2021 12:00:00 AM  03/31/2022 12:00:00 AM
# 8       05/18/2020 12:00:00 AM  02/25/2021 12:00:00 AM
# ...                        ...                     ...
# 241428  09/05/2019 12:00:00 AM  08/18/2020 12:00:00 AM
# 241436  12/18/2018 12:00:00 AM  05/06/2019 12:00:00 AM
# 241437  09/27/2019 12:00:00 AM  02/28/2021 12:00:00 AM
# 241438  11/14/2017 12:00:00 AM  09/17/2018 12:00:00 AM
# 241440  03/04/2020 12:00:00 AM  02/23/2021 12:00:00 AM
#
# [103888 rows x 2 columns]

# %% [markdown]
# Again here it's not clear how a job could be approved before being assigned, or how a job could have it's latest action date  before the Pre-filing date

# %%
df.loc[(df['Issued Date'] > df['Approved Date'])
      &(~df['Issued Date'].isna() & ~df['Approved Date'].isna())][['Issued Date', 'Approved Date']]
# Out:
#                    Issued Date           Approved Date
# 5       09/23/2021 12:00:00 AM  09/20/2021 12:00:00 AM
# 7       06/23/2021 12:00:00 AM  02/24/2021 12:00:00 AM
# 12      05/06/2021 12:00:00 AM  01/07/2020 12:00:00 AM
# 14      11/16/2020 12:00:00 AM  11/13/2020 12:00:00 AM
# 17      08/19/2021 12:00:00 AM  06/29/2018 12:00:00 AM
# ...                        ...                     ...
# 241434  04/26/2019 12:00:00 AM  04/24/2019 12:00:00 AM
# 241435  11/07/2018 12:00:00 AM  08/25/2018 12:00:00 AM
# 241437  09/30/2020 12:00:00 AM  09/27/2019 12:00:00 AM
# 241440  07/10/2020 12:00:00 AM  03/04/2020 12:00:00 AM
# 241441  12/23/2020 12:00:00 AM  06/29/2020 12:00:00 AM
#
# [147145 rows x 2 columns]

# %% [markdown]
# # Data Profilling for City and Other Description
#
# Find format problems and outliers in City and Description columns
#
# Using openclean's sklearn modules to detect problems and outliers

# %%
from openclean.profiling.anomalies.sklearn import DBSCANOutliers

# Print the ten most frequent values for the 'Vehicle Expiration Date' column.
def findDateOutliers(column_name, eps_setting = 0.05):
    applicant_data = ds.distinct(column_name)
    print("Column: ",column_name)
    
    for rank, val in enumerate(applicant_data.most_common(10)):        
        st, freq = val
        print('{:<3} {:>8}  {:>10}'.format('{}.'.format(rank + 1), st, '{:,}'.format(freq)))

    print('\nTotal number of distinct values in {} is {}'.format(column_name, len(applicant_data)))
    print(DBSCANOutliers(eps = eps_setting).find(applicant_data))
    print('\n==================================')

# %%
date_cols = ["Borough", "Street Name"]

# %%
print("----------------------------\n")        
        
for col in date_cols:
    findDateOutliers(col, 0.1)
# Out:
# ----------------------------
#
# Column:  Borough
# 1.  MANHATTAN     104,181
# 2.  BROOKLYN      62,626
# 3.    QUEENS      41,561
# 4.     BRONX      22,068
# 5.  STATEN ISLAND      11,009
#
# Total number of distinct values in Borough is 5
# ['BROOKLYN', 'BRONX', 'MANHATTAN', 'STATEN ISLAND', 'QUEENS']
#
# ==================================
# Column:  Street Name
# 1.  BROADWAY       6,902
# 2.  PARK AVENUE       4,056
# 3.  5 AVENUE       3,543
# 4.  MADISON AVENUE       2,942
# 5.  3 AVENUE       2,083
# 6.  LEXINGTON AVENUE       1,984
# 7.  FIFTH AVENUE       1,649
# 8.  7 AVENUE       1,465
# 9.  AVENUE OF THE AMERICAS       1,343
# 10. 6 AVENUE       1,333
#
# Total number of distinct values in Street Name is 5601
# ['CPW', 'BRIGHTON 10 LANE', 'PIER   57', 'BRIGHTON   10 LANE', 'PPW', 'LITTLE WEST   12 STREET', 'BEACH 115 ST', 'B  116 STREET', 'BRIGHTON 1 PLACE', 'BOWERY', 'AVENUE OF THE AMERICAS', 'HHP', 'BRIGHTON 5 PLACE', 'MADISON AVENUE', 'FDR', 'BRIGHTON 2 PLACE', 'BAYSIDE', '111 ROAD', 'PARK AVENUE', 'PIER   76', 'INTERNATIONAL AIRPORT CENTER BL', 'RIVERSIDE DRIVE', 'ESPLANADE', 'BOULEVARD', 'METROTECH', 'BROADWAY', 'BRIGHTON    1 PLACE', 'BR 6 STREET', 'BQE', '5 AVENUE', 'LEXINGTON AVENUE']
#
# ==================================

# %%
from openclean.function.eval.base import Col, Eval
from openclean.function.eval.logic import And
from openclean.function.value.phonetic import Soundex, soundex

# %%
upper = ds\
    .select('Borough')\
    .update('Borough', str.upper)

# %%
from openclean.data.refdata import RefStore

refdata = RefStore()
city_df = refdata\
    .load('encyclopaedia_britannica:us_cities', auto_download=True)\
    .df()

# %%
city_list = city_df['city']
print(city_list)
# Out:
# 0          Demopolis
# 1          Sylacauga
# 2               Troy
# 3             Dothan
# 4           Prichard
#             ...
# 1956          Powell
# 1957        Riverton
# 1958        Sheridan
# 1959    Rock Springs
# 1960         Buffalo
# Name: city, Length: 1961, dtype: object

# %% [markdown]
# # An example of using soundex in openclean
#
# However, using soundex for each of the city is too slow, the code below take nearly 4 mins for one sningle city.\
# So we should use clustering first and then use hard code to clean the remianing city name that is not in the city_list.

# %%
brooklyn = ds\
    .select('Borough')\
    .update('Borough', str.upper)\
    .filter(And(Eval('Borough', Soundex()) == soundex('BROOKLYN'), Col('Borough') != 'BROOKLYN'))\
    .distinct()

print('RANK\tCOUNT\tNAME')
for i, entry in enumerate(brooklyn.most_common()):
    key, count = entry
    print('{}.\t{}\t{}'.format(i + 1, count, key))
# Out:
# RANK	COUNT	NAME

# %% [markdown]
# # Data Cleaning for Applicant columns
#
# * how to deal with empty values has not decided yet

# %% [markdown]
# # Check State Column

# %%
state_col = 'Owner State'
findDateOutliers(state_col, 0.1)
# Out:
# Column:  Owner State
# 1.               241,445
#
# Total number of distinct values in Owner State is 1
# ['']
#
# ==================================

# %% [markdown]
# # Apply similar operation on Owner's Business Name

# %%
bn_col = "Owner Business Name"
findDateOutliers(bn_col)
# Out:
# Column:  Owner Business Name
# 1.        PR      42,491
# 2.                10,551
# 3.     NYCHA       5,929
# 4.       N/A       3,635
# 5.  SPRING SCAFFOLDING LLC       3,499
# 6.  ROCK GROUP NY CORP       3,223
# 7.  OWNERS REP       2,369
# 8.  PHOENIX SUTTON STR INC       2,237
# 9.  TRI BOROUGH SCAFFOLDING       1,939
# 10. SAFWAY ATLANTIC LLC       1,861
#
# Total number of distinct values in Owner Business Name is 17524
# ['', '887, LLC', 'H & J REPAIRA & AUTOBODY INC', '91 HB LLC', 'ABL478 LLC', 'E. C. SOLDINI & SONS LLC', '20E49LIMONCELLO LLC', '4840BROAWAY INC', '17-18 MANAGEMENT CO. LLC', 'LIBERTY 1 CONSTRUCTION', '84-70 129TH ST OWNERS CORP', 'G. BAUER INC.', 'NIKA93LLC', 'SHG 3606 LLC', 'ERIN CONSTRUCTION & DEV. CO. INC.', '680 FIFTH AVENUE ASSOCIATES, L.P.', '21-23-25 WEST 8TH STREET LLC', 'P&P CONST. & PAINT. CORP', 'KYLE 132-19 LLC', '1872 WASHINGTON LLC', 'N/A', '335-7 LLC', '143-51 ROOSEVELT AVE. CO.', '20/20 CONVENIENT', 'CONNORS & CONNORS', '63 E 8 BAGEL CORP', '118 & 120 HUDSON STREET, LLC.', '73-47 190 STREET LLC', '#55', '135 JK REALTY GROUP', 'HaaGen-Dazs', '3D CONSTRUCTION', '373/375 REALTY LLC.,', '51 Hamilton PL Realty Corp', 'UPTOWN VEG 2', '156-46 89TH LLC', '209-15 116TH RD QUEENS NY', '703 E187TH REALTY CORP', '500-512 SEVENTH AVENUE, L.P.', 'RIGGS PLUMBING & HEATING @58, INC.', '223 E 25TH ST LLC', 'A. RUTH & SONS', '4 NAILS & BEAUTY', '718-650-9553', 'MP 830 THIRD AVENUE, LLC', '7014502380', 'KTSA-59EAST80THLLC', '1818-1838 AMSTERDAM AVENUE LLC', '55 97 PL LLC', '743 40LLC', '30 VERNON,LLC', 'SRD150LLC', '230-79 EQUITY INC.', '98 woodhaven properties LLC', '1 JRL LLC', 'JMW 88 LLC', 'Our Lady of Miracles, R.C.', '210-220 E. 22ND STREET SSGA OWNER,', '2301 7TH AVE H.D.F.C.', '156-158 SKILLMAN CORP', 'U & L TECH NY INC', '16 EAST 84, LLC', '1542 NY LLC', 'SDF-A', '590 MADISON AVE., LLC', 'BH BIL & CO LLC', 'Team Work Foundation1', 'SANCHO98LLC', '9 ST LUKES PLACE LLC', 'PROLOGIS, INC.', 'JSS & YC LLC', 'A.R. WALKER & CO. INC.', 'LTCELECTRIC, INC.', '117-119 LEASING CORP.', '786 CORONA CORP.', '39 EAST 52 ST', 'MAUTNER-GLICK CORP', 'BSD 685 NEW YORK PROP. CO LLC', 'NALPAK1196 COMPANY', '77 WALLABOUT, LLC', '323W88 LLC', 'LEFFERTS192', 'H&Z BUILDING CORP.', '580 LLC', '936 ST. MARKS, LLC', 'FRICK AND FRACK 2 LLC', '1772 ATLANTIC AVE MANAGEMENT INC.17', '196PORTRICHMOND LLC.', 'E. 103 ST & LEX AVE REALTY', 'SITE 2 DSA OWNER LLC', 'NYCH+H/BELLEVUE', 'CS 393 LLC', 'SILKALY M. WOLCHOK LP-1', '92-98 LLC', 'I.M.HOME IMPROVEMANT', 'B &amp; G FOODS, INC', 'Z-A 7 LLC', 'R FLUSHING 1 INC', 'LLNY5', '1450-1456 OWNERS CORP.', 'S &amp; S ROOFING, INC.', 'KING 888 INC', 'DOORTODOORREALTY', 'C.H 41 LLC', 'JKD & ESD, LLC', 'MMM', 'LIN 5929 LLC', 'QAZ2', '225-8TH AVE. APT. CORP.', '122 EAST 42ND ST., LLC.', '2 DOGZ 2 GO', '77 79 ATL AVE LLC', '2150 HYLAN BLVD ASSOCIATES CORPN.', 'G.&M. PARTNERS, LLC', '288 BALCOM AVE BRONX NY 10465', 'P.G.S. NY INC.', '984 BERGENLLC', 'FEIL - BLS LLC', '1669-79 LLC', '28 E. 4TH ST. HOUSING CORP.', 'BAY SIDE FUEL OIL DEPOT CORP 1100 GRAND', '888 BROADWAY', '301 AVE U LLC', 'J.L. HVAC INC.', 'FLUSHING 162 REALITY', '166 E. 96 ST. OWNERS CORP.', '38 REALTY INC.', 'S.R.K. CONSTRUCTION INC.', '1290 MADISON', '-- YEAR --', '111 CPN LLC', '595 BAY LLC', '203 & 205 PROPERTY CO LLC', '4444 PPPP CORP', 'NORTHWIND-GROUP', 'KRIM & KRIM, P.C.', 'STEEL EAST 60 LLC', '212 8650600', 'AT&T', '1825 ATLANTIC AVENUE, L.P.', 'OREN & IVY LLC', '221 W 116, LLC', '39K ORGANIC DELI & KIMCHI', '42 W. 17TH ST. HOUSING CORP.', '56 E 66TH STREET LLC', 'BURHAN1 MANAGEMENT', '3801 YKY LLC', 'M-H REALTY CO. #6, LLC', '405 WEST 238 ST LLC', '1318-1324 FRANKLIN LP', 'SYDANPOWERSOLUTIONS.COM', '817 INC', 'B K MOOKIM  LLC.', '149 NY LLC', 'ABBASS SHAH', 'A&T FISH & CHIPS LLC', '286 E 149TH ST REALTY CORP.', '&#9679;&#9679;-&#9679;&#9679;&#9679', 'L & M HOMES LLC', 'G&G TUB & TILE', '169-12 FOCH BLVD LLC', '363 E. 76TH STREET CORP', '266 W 77 ST CORP', 'E & S AND SONS CORP', 'BELMONT AVE.2321CORP.', 'Methodist Home for Nursing and Rehabilitation', 'F AND T GROUP', 'D.H.E. COMPANY, INC.', '424 E 82nd St llc', 'M & Y REALTY', 'WOODHAVEN 77, LLC', 'J & F N DELI & GRILL INC.', 'NY 29 WEST LLC', '40-16 NATIONAL ASSOCIATES', 'S & A STEEL FABS INC.', '888 DIMSUM INC.', 'TCA 1978 LLC', '5 EAST 3RD STREET#7 LLC', '2835 W 15 ST., LLC', '4SE CORP', 'JDKH, INC.', '741 VAN DUZER ST LLC', '986771023', '33-01Hunterspoint Ave Associates, LLC', '147-32 JAMAIC ...
#
# ==================================

# %% [markdown]
# # Using clustering for Business Name takes too much time, we can only clean those empty data for now

# %%
df[bn_col] = df[bn_col].replace(['N/A', '', 'NA','NONE'], [None,None,None,None])

# %% [markdown]
# # Data Profilling for applicant columns
#
# Find format problems and outliers in all applicant columns
#
# Using openclean's sklearn modules to detect problems and outliers

# %%
from openclean.profiling.anomalies.sklearn import DBSCANOutliers

# Print the ten most frequent values for the 'Vehicle Expiration Date' column.
def findDateOutliers(column_name, eps_setting = 0.05):
    applicant_data = ds.distinct(column_name)
    print("Column: ",column_name)
    
    for rank, val in enumerate(applicant_data.most_common(10)):        
        st, freq = val
        print('{:<3} {:>8}  {:>10}'.format('{}.'.format(rank + 1), st, '{:,}'.format(freq)))

    print('\nTotal number of distinct values in {} is {}'.format(column_name, len(applicant_data)))
    print(DBSCANOutliers(eps = eps_setting).find(applicant_data))
    print('\n==================================')

# %%
date_cols = []

print("Applicant Data columns:\n")
for col in ds.columns:
    if 'Applicant' in col:
        print(col)
        date_cols.append(col)
# Out:
# Applicant Data columns:
#
# Applicant License #
# Applicant First Name
# Applicant Middle Name
# Applicant Last Name
# Applicant Business Name
# Applicant Business Address

# %%
date_cols = []

print("Applicant Data columns:\n")
for col in ds.columns:
    if 'Applicant' in col:
        print(col)
        date_cols.append(col)

print("----------------------------\n")        
        
for col in date_cols:
    findDateOutliers(col, 0.1)
# Out:
# Applicant Data columns:
#
# Applicant License #
# Applicant First Name
# Applicant Middle Name
# Applicant Last Name
# Applicant Business Name
# Applicant Business Address
# ----------------------------
#
# Column:  Applicant License #
# 1.    032158       3,950
# 2.    607447       3,506
# 3.    610440       3,329
# 4.    617232       2,374
# 5.    606141       2,371
# 6.    609527       2,225
# 7.    616234       2,103
# 8.    018914       2,008
# 9.    608211       1,989
# 10.   620254       1,786
#
# Total number of distinct values in Applicant License # is 9098
# ['609527', '607447', '555555', '606141', '616836', '602375', '032158', '999999', '610440', '618253']
#
# ==================================
# Column:  Applicant First Name
# 1.   MICHAEL       7,879
# 2.   WILLIAM       6,720
# 3.    JOSEPH       6,034
# 4.  CHRISTOPHER       5,212
# 5.      JOHN       5,202
# 6.    ROBERT       4,519
# 7.  SIMRANPAL       3,326
# 8.    THOMAS       3,102
# 9.     JAMES       2,907
# 10.    FRANK       2,777
#
# Total number of distinct values in Applicant First Name is 3394
# ['UNG-JIB', 'ROBERT', 'CARMINE            A', 'HYUN  JUNG', 'JOSEPH', 'SHOW-LAIN', 'GAGANDEEP', 'CHRISTOPHER', 'MICHAEL', 'SIMRANPAL', 'STEVE LIANG FU', 'GRID-DAS', 'CONSTANTINE (GUS)', 'SHIH-CHIEH', 'WILLIAM', 'ZE-ZHEN', 'CHUN-HSIUNG', 'LASANTHA PANTHIYE', 'BUILD002', 'ALLEN/ALEYDA/DARLENE', 'MICHAEL KRAIWOOT', 'MIERANDJANSHARMA', 'NICK XIAN DENG', "RAYMOND ''COLIN''", 'ANTHONY', 'JONATHAN', 'FRANCISCO ALEXANDER', 'A K', 'JOHN', '900 3RD AVENUE', 'SENIA DE DIOS', 'SIN FANG FANNY', 'PHILIP', 'SH ISHI', 'MOHAMMAD  A.', 'M A', 'MOHAMMED  S.', 'JOSEPH-MARCO', 'MAHAMEDSHEHJAD', 'GEORGE', 'YUNG-HO', 'YU MING YE', 'YOSSEL LICHTMAN', 'MOHAMMAD M.', 'CHRISTOPHER H.', 'MAO  J', 'PO SHENG']
#
# ==================================
# Column:  Applicant Middle Name
# 1.               241,342
# 2.       GIL         103
#
# Total number of distinct values in Applicant Middle Name is 2
# ['', 'GIL']
#
# ==================================
# Column:  Applicant Last Name
# 1.     SINGH      19,694
# 2.      KAUR       4,598
# 3.    DOWNES       3,950
# 4.    LAFFEY       3,506
# 5.       HSU       2,398
# 6.     LYNCH       2,259
# 7.    SIWIEC       2,225
# 8.     ADLER       2,104
# 9.    LEVINE       2,028
# 10.     SUSI       2,008
#
# Total number of distinct values in Applicant Last Name is 6288
# ['', 'SISCA III', 'DEL MONACO JR', 'BUILD002', 'L DE LA LUZ GONZALEZ', 'AKRAM  GONDAL', 'MEYERS/AUSTIN/RAPOSO', 'DE LA ROSA', 'BARBARIA JR.', 'KAUR', 'VITTORIA  JR.', 'MOSSO COSS', 'URBINATI, JR.', 'ST. ONGE-CASAVANT', 'CONTO, JR.', 'DE ROSS             III', 'ALDEN JR.', 'TOMAI, JR.', 'VOLPE JR.', 'ROSA , JR.', 'ALMOG - ARAZI', 'ALCANTARA LIRIANO', 'PULETTI, JR.', 'DE LA CRUZ', 'SINGH']
#
# ==================================
# Column:  Applicant Business Name
# 1.  EVEREST SCAFFOLDING INC       4,055
# 2.  ROCK GROUP NY CORP       3,530
# 3.  SPRING SCAFFOLDING LLC       3,503
# 4.  CORE SCAFFOLD SYSTEMS INC       2,319
# 5.  PHOENIX SUTTON STR INC       2,235
# 6.  SILVERCUP SCFFLDNG I LLC       2,104
# 7.  ARSENAL SCAFFOLD INC       2,010
# 8.  SAFWAY ATLANTIC, LLC       1,988
# 9.  NATIONAL MAINTENANCE, INC       1,594
# 10. PLATINUM SERVICES NY LLC       1,591
#
# Total number of distinct values in Applicant Business Name is 9409
# ['', 'WS2K CORP', 'N/A', '335-7 LLC', 'ALMUNIR.CORP', 'EVEREST SCAFFOLDING INC', 'PLATINUM SERVICES NY LLC', 'SAFWAY ATLANTIC, LLC', 'SILVERCUP SCFFLDNG I LLC', 'L.S. SIGN CO. INC', 'JASCO, INC', 'BOLSTER.US,INC', 'PHOENIX SUTTON STR INC', 'R.W. DAKE & CO.,INC', 'DESIGN 2020 LLC', '387 PAS GC LLC', 'PAR PLUMBING CO., INC', 'A.G.M. P & H INC', 'EASTERN 2000 INC', 'ZHONGSHUN', 'ROMA SCAFFOLDING INC', 'GUNGHO', 'TRI BOROUGH SCAFFOLDING', 'CMC1 CORP', 'QAZ4', 'L.S. SIGN CO., INC', 'E.Y.M.S. INC', '1625 DB INC', 'PAUL SIGNS, INC', 'BEACH HOUSE 60, LLC', 'CORE SCAFFOLD SYSTEMS INC', 'MOROZOV', 'ARSENAL SCAFFOLD INC', '212 HVAC LLC', 'C.R.C. PLBG. & HTG. CORP', 'R.G.M. SIGNS INC', 'K.M.D. MCHNCL 1443 LLC', 'SPRING SCAFFOLDING LLC', '957 GREEN AVE LLC', 'H.I.I. CORP', 'ROCK GROUP NY CORP', '3T GC LLC', '5D ARCHITECTURE & ENGINEERING PLLC.', 'SIGNSTAR NYC', 'GAGAN G.C. INC', 'ART + 1, INC', 'VERITAS ENGINEERING & INSPECTION, P', 'B & B 21 MANAGEMENT INC', 'ACTIVE SIGNS INC', 'H20 LLC', 'QAZ3', '128 AC INC', 'TEST', 'L1C CORP', 'L&J PLG & HTG CO OF NY IN', 'ARTIFACT', 'OCGP.LLC', 'T.R.R.C.,INC', 'MICHAEL R. LISOWSKI ARCHITECTURE, L', 'PIPESTYLISTS, INC', 'G05 INC', '2MO LLC', 'KINGS GROUP NY CORP', 'JJS BUILDERS', 'NATIONAL MAINTENANCE, INC', 'NORTH SHORE NEON SIGN CO', 'M.R.S., INC', 'K.O.S. PLUMBING&HEATING,I', 'TRI BOROUGH SCAFFOLDING.&', 'BUILD4NY, LLC', '7 & 9 ALBAN LLC', 'I.C.P CORP', '2260 MAG CORP', 'H2L LLC', '99 MCDOUGAL LLC', '(718)541-0701 MANAGEMENT', 'L.E.C.INC', '718-HOME LLC', 'G.B. & SON, INC', 'CS BRIDGE CORP', 'GEM-QUALITY CORP', 'MADISON 30 31 OWNER LLC', 'G.A.M.C.N.Y. LLC', 'METROPOLITAN MECHANICAL CONTRACTORS', 'ALEKS & F., INC', '226 LLC', 'SD 2 INC', 'VISION 21 INC', 'E-Z FLOW P & H INC', 'NYEG.CORP', 'Z-CAR-D CORP', 'GOGOLEYED,LLC', '154-21 CORP', "WATSON'S PLBG, HTG, & BDG", 'M.R.S.INC', 'WRECK IT NYC 11 INC', 'R.U.B.G.A LLC', 'NAVILLUS', 'RIGGS PLMBG & HTG & 58TH']
#
# ==================================
# Column:  Applicant Business Address
# 1.                26,648
# 2.  49-30 31ST PLACE       2,728
# 3.  1150 LONGWOOD AVE       2,673
# 4.  101 PARK AVENUE LOWER LOBBY       1,737
# 5.  119 MT. VERNON STE 2E       1,619
# 6.  53-28 11TH STREET 2ND FL       1,601
# 7.  700 COMMERCIAL AVENUE       1,580
# 8.  128 SUTTON STREET       1,554
# 9.  41-33 38TH STREET       1,453
# 10. 23-41 BORDEN AVENUE       1,357
#
# Total number of distinct values in Applicant Business Address is 9236
# ['', '177-48 106RD', 'ARTIMUS CONSTRUCTION INC', '8 OAK STREET TREE DR STE 2', '802 71ST', '1444 150TH STREET UNIT 575068', '54 W 74 ST #611', 'QAZ', 'STAR UNIVERSE RENOVATION CORP', '36TH ROAD', '280 BWY', 'QAZ4', 'BROOKLYN CONSTRUCTION MANAGEMENT', '157 28 ST', '90', 'SUITE 207', '47-27 195ST', 'RASHINDER', '82-17 153RD AVE., SUITE #206', '49-30 31ST PLACE', '6618 20TH AVE #40442', '147 28 ST', '44-03 28 AVE.', 'LEONE ENTERPRISES', '9-11 N WEST ST', 'JA LLC', '1301 70 ST', '50 LEFFERTS AVE......APT2J', '77 ALLEN STREET.....2B', '3 BAYSIDE', '388 E 198 ST', '40 GATON', '1813 58 ST', '41-43 43RD', '8319 20TH AVE.....STE 200', '1279 E 102 ST']
#
# ==================================

# %% [markdown]
# # Analysis
#
# the above results show the problems for the data cleaning task:
#
# ### For name data
#
# in "Applicant's First Name", "Applicant's Last Name", "Applicant Professional Title", there are many outliers which are illegal input, and there are many similar values. We need first converts evident outliers to legal values, then use kNN clusterer to standardize similar values.
#
#
# ### Applicant License #
#
# Applicant License # is made of 6 digits, there are outliers that do not satisfy the 6-digit format. We can not use kNN clusterer to standardize because many License # are similar.

# %% [markdown]
# # Data Cleaning for Applicant columns
#
# * how to deal with empty values has not decided yet

# %%
# mapping list to replace outliers
outlier1 = ['', 'MR. ROSS ADAM C', 'MICHAEL', 'N. J.', 'WILLIAM 11', 'JOSEP;H``', 'DAID/11/2007', 'CHUNG   LUN', '718 9215010', 'ANTHONY', 'HSIA0-NAN', 'JOSEPH', '``````````', 'ROBERT  `', 'RAJENDRA9956700', '2', 'G.B.M.', 'EUGENE......JR', '6312100', 'CLAUDE,JR.', 'THOMAS``', 'ALAN  L', 'Nab53', 'MR. Y. B', 'J.J', 'PH8ILIP', 'I. M', 'RICHARD', 'ALBERTA S 111 D', 'P ;', 'GENECG.C. ENG &', 'J.J.', '2126202794', 'SHAW  HWA', 'HARRY         H', 'MR DOU8GLAS', '`1D', 'PAUL', 'K. T.', 'JOHN', '...NORMAN', 'EVAN   D', '7184361278BERNA', 'S.D. DON', 'KY00 SUK', 'JJ', 'YURI.`', 'MAD/Y/ARNI', 'ES ON SCH B', 'EUGENE.......JR', 'NEAL', 'F._ERIC', 'RYAN,  JR', 'AASDFASDFASDF', 'LA0-TECH', 'RODNEY   __', 'DAVID', 'G. L.', 'JAMES', 'LESLI8E', '7186054055', 'GEORGE', 'G.B.M', 'DAVID    JON', 'CHUNG---YAO', 'PETER', 'YUBUN(JACK)', 'GLEN A. L.', '1P', 'JUDE.....N.O', 'LEONARD--', 'WILLIAM', 'ANTHONY,111', 'WU(WOODY)', 'GAD/HON-AN', 'GLEN  A.L.', 'J.B. Jr.', 'LORENZO..A', 'J J', '..RAMSEY', 'HUI LI I', 'ANTONIO9', 'ROBERT', '0.BERT', 'DUMMY 2', '...JOSEPH', 'RUSSELL 111', 'THOMAS', 'H./E./CAMELLE', 'LALAL', 'M.E. P.E', 'R0OBIN VINCENT', '--young', 'AKM', 'LE1', 'IK.T.', 'LEO, JR.', 'J. Butch A. Jr.', 'WU (WOODY0', 'PAUL   N', 'CHRISTOPHER']
mapping1 = [None, 'ROSS ADAM C', 'MICHAEL', 'N. J.', 'WILLIAM', 'JOSEPH', None, 'CHUNG LUN', None, 'ANTHONY', 'HSIA0 NAN', 'JOSEPH', None, 'ROBERT', 'RAJENDRA', None, 'G.B.M.', 'EUGENEJR', None, 'CLAUDE JR.', 'THOMAS', 'ALAN  L', 'Nab', 'MR. Y. B', 'J.J', 'PHILIP', 'I. M', 'RICHARD', 'ALBERTA', None, 'GENECG.C. ENG', 'J.J.', None, 'SHAW HWA', 'HARRYH', 'MR DOUGLAS', None, 'PAUL', 'K. T.', 'JOHN', 'NORMAN', 'EVAND', 'BERNA', 'S.D. DON', 'KY00 SUK', 'JJ', 'YURI.`', 'MADYARNI', 'ES ON SCH B', 'EUGENEJR', 'NEAL', 'FERIC', 'RYAN,  JR', 'AASDFASDFASDF', 'LA0 TECH', 'RODNEY', 'DAVID', 'G. L.', 'JAMES', 'LESLIE', None, 'GEORGE', 'G.B.M', 'DAVID JON', 'CHUNG YAO', 'PETER', 'YUBUN(JACK)', 'GLEN A. L.', None, 'JUDE N.O', 'LEONARD--', 'WILLIAM', 'ANTHONY,111', 'WU(WOODY)', 'GAD HON-AN', 'GLEN A.L.', 'J.B. Jr.', 'LORENZOA', 'J J', 'RAMSEY', 'HUI LI I', 'ANTONIO9', 'ROBERT', '0.BERT', 'DUMMY', 'JOSEPH', 'RUSSELL', 'THOMAS', 'H.E.CAMELLE', 'LALAL', 'M.E. P.E', 'R0OBIN VINCENT', 'young', 'AKM', 'LE1', 'IK.T.', 'LEO, JR.', 'J. Butch A. Jr.', 'WU (WOODY0', 'PAUL   N', 'CHRISTOPHER']

outlier2 = ['SHARMA #0', "0'CONNOR", 'RUSHTON    UEL', 'UDDIN   Z', 'HINKLEY 1', 'O&#039;CONNOR, P.E.', '.OOK', 'SAMUELS111', 'O&#039;CONNOR', 'CALIENDO', 'SMITH   JR.', 'LO  BUE', '7AN', '+-+ETTIERI', 'SMITH, 111', 'KAMEN   1', '.EE', 'MASS, 1', '.EI', 'Zagaroli 3rd', 'RINI   II', 'KAMEN   R', 'RYAN 11', 'SPI8EZIA L S', 'MUFTIC..A.I.A', 'COSTELLO9 RA A I A', 'CALVANICO', 'LLC.', 'POEPPEL, P.E.', 'HAMA07', 'HINLEY,1', '1212', "O  ' CONNELL", 'HURT,JR.,', 'WESOLOWSKI', 'CHEN', '`ING, R.A', 'MARTARELLA 111', 'Gandhi, Ph.D., P.E.', '90I', 'ENNIS 2', 'COSTELLO R A A I A', '3UI', 'N/A', 'HURT,  JR', 'LEHR,1', 'KOHLER, 111', 'GERAZOUNIS', 'Alexander,1', 'LUBOW, R.A. LEED AP', 'RINI,111', '08CZAK', '````````````````````', 'CHAO  R.A.', 'Geier 11', '08NGEL', '08SOLOWSKI', 'I11', 'HINKLEY, 1', 'RUDIKOFF, P.E.', "O'CONNOR", 'SHAH   EZ', 'MIELE, JR., P.E.', 'RITTENHOUSE 111', 'AMADI   ISIOFIA', 'HINKLEY,1', 'RENFORE````````', "O'HARA,JR.", '73020012', 'PHAGOO   I', 'BRAY.....,', 'LLL', 'BHATHIA,1', 'GANDHI, PH. D., P.E', 'KO K', 'VASSALOTTI 11', 'HURT, JR .', '0018LKLE', 'RINI -111', 'PARIHAR', 'EE', 'L00802', 'ELISE.111', 'KING , R.A', 'CHRYSLER  P E', 'LEHR 1', 'Walters   Jr.', 'LEE', 'RINI  III', 'D&#039;ANGELO', '0UDOLPH III', 'VIEHE-NAESS 111', ',MO', '08E', '47DIKOFF', 'Yu,', '420865380', 'COPELAND', 'ZWIEFEL 3RD', 'PETERSEN', 'King, R.A.,', 'RINI, III', '7APA', 'CHEN   S', 'Hurt  Jr.', 'KATZ', 'NIZAMBAD.(P.E.)', '901BEN', '4153LOO', 'SYED-NAQVI', 'RYAN , JR.', 'K O K O R I S', 'ELISEO111', 'O&#039;CONNELL', 'ZEID61', '---Lewis', '00CHELI', 'MOHAMMAD       +++++', 'METZLER  P E', 'BAILEY', 'GANDHI, PH. D., P.E.', 'TIEMANN.111', 'SMITH.111', 'DI GER0NIMO', 'GANDHI, PH,D., P.E', 'III', 'J C', 'MAGAMI-QAIM-MAGAMI', '+M', 'LO G1UDICE', 'HOQUE', 'RUDIKOFF', 'Y10007OR', 'SMITH,111', 'KING R A FAIA', 'RYAN III, AIA', '08AN', 'STARK 1', 'MASS', 'VICTORI0, R.A', 'RIZVI   A', '21029677', "3'CONNOR", 'Wong /  Lai', 'KAPLAN 3', 'GRAICHEN.JR./DAWN/DI', 'GROSSMAN ,PE,F.A.C.I']
mapping2 = ['SHARMA ', "CONNOR", 'RUSHTON UEL', 'UDDIN Z', 'HINKLEY ', 'CONNOR P.E.', None, 'SAMUELS', 'CONNOR', 'CALIENDO', 'SMITH JR.', 'LO BUE', None, 'ETTIERI', 'SMITH', 'KAMEN', '.EE', 'MASS', '.EI', 'Zagaroli', 'RINI', 'KAMEN R', 'RYAN', 'SPIEZIA L S', 'MUFTIC.A.I.A', 'COSTELLO9 RA A I A', 'CALVANICO', 'LLC.', 'POEPPEL P.E.', 'HAMA', 'HINLEY', None, "CONNELL", 'HURT JR.', 'WESOLOWSKI', 'CHEN', 'ING R.A', 'MARTARELLA', 'Gandhi', None, 'ENNIS ', 'COSTELLO R A A I A', None, None, 'HUR  JR', 'LEHR', 'KOHLER 111', 'GERAZOUNIS', 'Alexander', 'LUBOW R.A. LEED AP', 'RINI',None, None, 'CHAO R.A.', 'Geier', None, 'SOLOWSKI', None, 'HINKLEY', 'RUDIKOFF, P.E.', "CONNOR", 'SHAH EZ', 'MIELE JR. P.E.', 'RITTENHOUSE', 'AMADI   ISIOFIA', 'HINKLEY', 'RENFORE', "O'HARA,JR.", None, 'PHAGOO I', 'BRAY,', 'LLL', 'BHATHIA', 'GANDHI', 'KO K', 'VASSALOTTI', 'HURT JR.',None, 'RINI', 'PARIHAR', 'EE', None, 'ELISE', 'KING R.A', 'CHRYSLER  P E', 'LEHR', 'Walters Jr.', 'LEE', 'RINI  III', 'ANGELO', '0UDOLPH III', 'VIEHE-NAESS', 'MO', '08E', None, 'Yu,', None, 'COPELAND', 'ZWIEFEL 3RD', 'PETERSEN', 'King, R.A.,', 'RINI, III', '7APA', 'CHEN   S', 'Hurt  Jr.', 'KATZ', 'NIZAMBAD.(P.E.)', None, None, None, 'RYAN JR.', 'KOKORIS', 'ELISE', 'CONNELL', None, 'Lewis', 'CHELI', 'MOHAMMAD', 'METZLER  P E', 'BAILEY', 'GANDHI', 'TIEMANN', 'SMITH', 'DI GER0NIMO', 'GANDHI', 'III', 'J C', 'MAGAMI QAIM MAGAMI', None, 'LO G1UDICE', 'HOQUE', 'RUDIKOFF', None, 'SMITH', 'KING R A FAIA', 'RYAN III AIA', None, 'STARK', 'MASS', 'VICTORI0 R.A', 'RIZVIA', None, "CONNOR", 'Wong Lai', 'KAPLAN', 'GRAICHEN.JR. DAWN DI', 'GROSSMAN']

outlier3 = ['', '....DEMO', '050069', 'DEM. CONTR.,', 'XXXXX', 'G/C 10114H9', 'CGWC10114H99', '00', 'X S000155', '082-36-1245', 'G.G', 'LESSEE', '......GC', "'", '..OWNER', 'GC 2293', '--', 'XXXXXX', 'LS 31,721', '...GC', 'gen.cont.', 'G.C TK#4592', 'PE', 'RLA - 818', '.....OWNER', 'RLA 16077', 'G C', 'X 4129892', 'G. C.', 'R.L.A', 'GC 1028350', 'WC10114H99', 'LEESEE', 'GEN.CONT.', 'SIGN..HANGER', 'DEMO 20451', 'D8615', '.X', 'P.L.L.C', '..DEMO', 'G .C', 'L A', 'G.C NY11101', '32820', '....OWNER', 'GC(DEMO)', 'C0NTRACTOR', 'EXPEDITORC99792', 'X 1341946', 'TRACK# 1390', 'EXPED.R4466', 'PLLC 9599691', 'G.C 1110101', '029649', '(CHECK)', 'DEM. CONTR,', 'EXPEDIT(H66172)', '.........
mapping5 = [None, '0000GC', '083278', 'DD5615', '0000PB', '00ASB4', 'B81923', '099998', '000000', '065569', '01827O', '0R9526', 'LP0256',None, '001964',None, '001609', '000PW1', '00DEMO', '006886', '000000', '020929', 'LP0258', '000TOR', '0D8615', '0SWITA', '000818', 'O02200', None, '000196', '001075', '0000NT', '000215', '000000', '000000', None, '000455', '022377', 'DD8615', '050579', '000226', None, 'DD6815', 'X02689']

outlier6 = ['','77 ALLEN STREET.....2B', '50 LEFFERTS AVE......APT2J', '90' ]
mapping6 = [None, '77 ALLEN STREET 2B', '50 LEFFERTS AVE APT2J', None]


outliers = [outlier1, outlier2, outlier3, outlier4, outlier5, outlier6]
mappings = [mapping1, mapping2, mapping3, mapping4, mapping5, mapping6]

# %% [markdown]
# # Remove evident outliers using hard coded mapping

# %%
i = 0
for col in date_cols:
    df[col] = df[col].replace(outliers[i], mappings[i])
    i += 1

# %% [markdown]
# # Convert similar values to suggested value using kNN clustering

# %%
# Cluster string using kNN clusterer (with the default n-gram setting)
# using the Levenshtein distance as the similarity measure.

from openclean.cluster.knn import knn_clusters
from openclean.function.similarity.base import SimilarityConstraint
from openclean.function.similarity.text import LevenshteinDistance
from openclean.function.value.threshold import GreaterThan

def getClusters(col, minsize = 2):
    dba = ds.select(col).distinct()
    clusters = knn_clusters(
        values=dba,
        sim=SimilarityConstraint(func=LevenshteinDistance(), pred=GreaterThan(0.75)),
        minsize=minsize
    )
    return clusters

def print_cluster(cnumber, cluster):
    print('Cluster {} (of size {})\n'.format(cnumber + 1, len(cluster)))
    for val, count in cluster.items():
        print('{} ({})'.format(val, count))
    print('\nSuggested value: {}\n\n'.format(cluster.suggestion()))

def updateUsingClusters(col, clusters, isPrint = False):
    
    orignal_list = []
    suggestion_list = []
    clusters.sort(key=lambda c: len(c), reverse=True)
       
    for i, cluster in enumerate(clusters):        
        suggestion = cluster.suggestion()
        orignal_list = []
        suggestion_list = []
        if isPrint and i < 5:
            print_cluster(i, cluster)
        
        for val, count in cluster.items(): 
            orignal_list.append(val)
            suggestion_list.append(suggestion)
            
    df[col] = df[col].replace(orignal_list, suggestion_list)

# %%
for col in date_cols[:3]:
    print("kNN cluster for ", col)
    col_clusters = getClusters(col)
    print("updating column ", col)
    print("----------------------\nTop 5 Cluster:\n----------------------")
    updateUsingClusters(col, col_clusters, True)
    print("================")
# Out:
# kNN cluster for  Applicant License #
# updating column  Applicant License #
# ----------------------
# Top 5 Cluster:
# ----------------------
# ================
# kNN cluster for  Applicant First Name
# updating column  Applicant First Name
# ----------------------
# Top 5 Cluster:
# ----------------------
# Cluster 1 (of size 10)
#
# MOHAMMAD (330)
# MOHAMMAD M (4)
# MOHAMMAD I (5)
# MOHAMMAD O (3)
# MUHAMMAD U (3)
# MOHAMMAD M. (2)
# MOHAMMAD J (5)
# MUHAMMAD A (2)
# MOHAMMED A (6)
# MOHAMMAD S (8)
#
# Suggested value: MOHAMMAD
#
#
# Cluster 2 (of size 10)
#
# HARVINDER (82)
# DARVINDER (6)
# PARVINDER (17)
# TARVINDER (4)
# RAVINDER (2)
# DEVINDER (32)
# KULVINDER (6)
# DAVINDER (4)
# ARVINDER (1)
# DALVINDER (576)
#
# Suggested value: DALVINDER
#
#
# Cluster 3 (of size 10)
#
# DALVINDER (576)
# HARVINDER (82)
# PARVINDER (17)
# TARVINDER (4)
# GURVINDER (25)
# RAVINDER (2)
# DEVINDER (32)
# DAVINDER (4)
# ARVINDER (1)
# DARVINDER (6)
#
# Suggested value: DALVINDER
#
#
# Cluster 4 (of size 9)
#
# DALVINDER (576)
# DARVINDER (6)
# PARVINDER (17)
# TARVINDER (4)
# GURVINDER (25)
# RAVINDER (2)
# DAVINDER (4)
# ARVINDER (1)
# HARVINDER (82)
#
# Suggested value: DALVINDER
#
#
# Cluster 5 (of size 8)
#
# CHRISTINE (185)
# CHRISTIAN (33)
# CHRISTA (2)
# CHRISTIE (1)
# CRISTINA (28)
# KRISTINA (31)
# CRISTINE (3)
# CHRISTINA (1)
#
# Suggested value: CHRISTINE
#
#
# ================
# kNN cluster for  Applicant Middle Name
# updating column  Applicant Middle Name
# ----------------------
# Top 5 Cluster:
# ----------------------
# ================

# %% [markdown]
# # Save cleaned data

# %%
outputpath = datafile[2:11]+'_cleaned_data.csv'
df.to_csv(outputpath,sep=',',index=False,header=True)

# %% [markdown]
# # Precision and Recall

# %%
df2  = pd.read_csv(datafile, dtype='object', sep='\t')
df2 = df2.drop_duplicates()

sample_size = 100

df_sample_data =  df2.sample(sample_size).copy()

# %%
cleaned_columns = ['Job Filing Number','House No',"Owner Business Name", "Approved Date","Issued Date",
                   'Expired Date',"Borough", "Street Name","Applicant First Name","Applicant Middle Name",
                   "Applicant Last Name","Applicant Business Name","Applicant Business Address"
]

# %%
df_sample_data = df_sample_data[cleaned_columns]

# %%
def precision(tp, fp):
    return tp/(tp+fp)

def recall(tp, fn):
    return tp/(tp+fn)

# %%
print('sample size: ',sample_size)
print('total size: ',sample_size * len(cleaned_columns))
print('======================\n\n')

same = 0

for col in cleaned_columns:
    print("column: ", col)
    print("Original,\t Cleaned\n")
    for i in range(sample_size):
        if df[col].iloc[i]== df2[col].iloc[i]:
            same += 1
        else:
            print(df[col].iloc[i], '\t', df2[col].iloc[i], '\t*')
    
    print('.......', same, ' same records ......\n')
    same = 0
    
    print('======================\n\n')
# Out:
# sample size:  100
# total size:  1300
# ======================
#
#
# column:  Job Filing Number
# Original,	 Cleaned
#
# ....... 100  same records ......
#
# ======================
#
#
# column:  House No
# Original,	 Cleaned
#
# ....... 100  same records ......
#
# ======================
#
#
# column:  Owner Business Name
# Original,	 Cleaned
#
# CGM MANAGEMENT GROUP INC 	 CGM MANAGEMENT GROUP, INC 	*
# nan 	 nan 	*
# EVEREST SCAFFOLDING INC 	 EVEREST SCAFFOLDING INC. 	*
# H&Z BUILDING CORP 	 H&Z BUILDING CORP. 	*
# JSK CONSTRUCTION CORP 	 J.S.K. CONSTRUCTION CORP 	*
# EVEREST SCAFFOLDING INC 	 EVEREST SCAFFOLDING INC. 	*
# SILVERSTEIN PROPERTIES INC 	 SILVERSTEIN PROPERTIES INC. 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# EVEREST SCAFFOLDING INC 	 EVEREST SCAFFOLDING INC. 	*
# 133-43 35 AVE LLC 	 133-43 35 AVE LLC. 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# HOMEMADE TAQUERIA 14TH AVE 	 HOMEMADE TAQUERIA 14TH AVE. 	*
# BROADWAY BRETTON INC 	 BROADWAY BRETTON INC. 	*
# nan 	 nan 	*
# FM RING ASSOCIATES INC 	 F.M. RING ASSOCIATES, INC. 	*
# nan 	 nan 	*
# SILVERSTEIN PROPERTIES INC 	 SILVERSTEIN PROPERTIES INC. 	*
# ....... 79  same records ......
#
# ======================
#
#
# column:  Approved Date
# Original,	 Cleaned
#
# ....... 100  same records ......
#
# ======================
#
#
# column:  Issued Date
# Original,	 Cleaned
#
# ....... 100  same records ......
#
# ======================
#
#
# column:  Expired Date
# Original,	 Cleaned
#
# ....... 100  same records ......
#
# ======================
#
#
# column:  Borough
# Original,	 Cleaned
#
# ....... 100  same records ......
#
# ======================
#
#
# column:  Street Name
# Original,	 Cleaned
#
# ....... 100  same records ......
#
# ======================
#
#
# column:  Applicant First Name
# Original,	 Cleaned
#
# ....... 100  same records ......
#
# ======================
#
#
# column:  Applicant Middle Name
# Original,	 Cleaned
#
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# ....... 0  same records ......
#
# ======================
#
#
# column:  Applicant Last Name
# Original,	 Cleaned
#
# ....... 100  same records ......
#
# ======================
#
#
# column:  Applicant Business Name
# Original,	 Cleaned
#
# ....... 100  same records ......
#
# ======================
#
#
# column:  Applicant Business Address
# Original,	 Cleaned
#
# ....... 100  same records ......
#
# ======================

# %%
print('sample size: ',sample_size)
print('total size: ',sample_size * len(cleaned_columns))
print('======================\n\n')

same = 0

for col in cleaned_columns:
    print("column: ", col)
    print("Original,\t Cleaned\n")
    for i in range(sample_size):
        if df[col].iloc[i]== df2[col].iloc[i]:
            print(df[col].iloc[i], '\t', df2[col].iloc[i], '\t')
        else:
            print(df[col].iloc[i], '\t', df2[col].iloc[i], '\t*')

    print('======================\n\n')
# Out:
# sample size:  100
# total size:  1300
# ======================
#
#
# column:  Job Filing Number
# Original,	 Cleaned
#
# M00531234-I1 	 M00531234-I1
# X00496654-I1 	 X00496654-I1
# B00579209-I1 	 B00579209-I1
# M00514656-I1 	 M00514656-I1
# M00431823-I1 	 M00431823-I1
# B00583762-I1 	 B00583762-I1
# B00516232-I1 	 B00516232-I1
# B00472417-I1 	 B00472417-I1
# B29303378-I1 	 B29303378-I1
# M00379533-I1 	 M00379533-I1
# B00369280-I1 	 B00369280-I1
# B00378717-I1 	 B00378717-I1
# Q00284352-I1 	 Q00284352-I1
# B00513806-I1 	 B00513806-I1
# S00426773-I1 	 S00426773-I1
# S00253862-I1 	 S00253862-I1
# X00434717-I1 	 X00434717-I1
# B00055891-I1 	 B00055891-I1
# B00491585-I1 	 B00491585-I1
# M00514118-I1 	 M00514118-I1
# B00283296-I1 	 B00283296-I1
# B00516235-I1 	 B00516235-I1
# B00500645-I1 	 B00500645-I1
# M00308545-I1 	 M00308545-I1
# M00431432-I1 	 M00431432-I1
# M00492347-I1 	 M00492347-I1
# X00468553-I1 	 X00468553-I1
# M00489394-I1 	 M00489394-I1
# M00406969-I1 	 M00406969-I1
# M00510532-I1 	 M00510532-I1
# Q00513093-I1 	 Q00513093-I1
# X00294312-I1 	 X00294312-I1
# M00340646-I1 	 M00340646-I1
# B00504274-I1 	 B00504274-I1
# B00508946-I1 	 B00508946-I1
# Q00509417-I1 	 Q00509417-I1
# M00296154-I1 	 M00296154-I1
# B00569487-I1 	 B00569487-I1
# M00503100-I1 	 M00503100-I1
# M00502169-I1 	 M00502169-I1
# M00516217-I1 	 M00516217-I1
# B00428043-I1 	 B00428043-I1
# Q00534245-I1 	 Q00534245-I1
# Q00504804-I1 	 Q00504804-I1
# M00449689-S2 	 M00449689-S2
# S00336724-I1 	 S00336724-I1
# 1117 	 1117
# 66 	 66
# 221 	 221
# 40-40 	 40-40
# 112 	 112
# 87-49 	 87-49
# 14 	 14
# 72-31 	 72-31
# 113 	 113
# 224 	 224
# 253 	 253
# 2 	 2
# 30-50 	 30-50
# 30 	 30
# 6602 	 6602
# 2350 	 2350
# 240 	 240
# 720 	 720
# 132-20 	 132-20
# 155-21 	 155-21
# 337 	 337
# 40 	 40
# 187-19 	 187-19
# 80 	 80
# 597 	 597
# 351 	 351
# 23 	 23
# 144 	 144
# 97-25 	 97-25
# 104-19 	 104-19
# 101 	 101
# 140 	 140
# 2894 	 2894
# 606 	 606
# 345 	 345
# 923 	 923
# 517 	 517
# 350 	 350
# 120 	 120
# 394 	 394
# 602 	 602
# 625 	 625
# 33 	 33
# 1217 	 1217
# 2212 	 2212
# 748 	 748
# 1295 	 1295
# 178 	 178
# ======================
#
#
# column:  Owner Business Name
# Original,	 Cleaned
#
# PR 	 PR
# EIB WESTCHESTER 1 LLC 	 EIB WESTCHESTER 1 LLC
# TWIN GROUP ASSOCIATES INC 	 TWIN GROUP ASSOCIATES INC
# CGM MANAGEMENT GROUP INC 	 CGM MANAGEMENT GROUP, INC 	*
# BROADWAY MERCER ASSOCIATES 	 BROADWAY MERCER ASSOCIATES
# nan 	 nan 	*
# EVEREST SCAFFOLDING INC 	 EVEREST SCAFFOLDING INC. 	*
# FM CONSOLIDATED HOLDING 	 FM CONSOLIDATED HOLDING
# DRY CLEANING EQUIPMENT 	 DRY CLEANING EQUIPMENT
# RESTORING COMMUNITIES HDFC 	 RESTORING COMMUNITIES HDFC
# ASP 	 ASP
# H&Z BUILDING CORP 	 H&Z BUILDING CORP. 	*
# GO HPS LLC 	 GO HPS LLC
# CONSOLIDATED SCAFFOLD & BRIDGE CORP 	 CONSOLIDATED SCAFFOLD & BRIDGE CORP
# CAPODANNO PROPERTIES 	 CAPODANNO PROPERTIES
# ASHLAND BUILDING LLC 	 ASHLAND BUILDING LLC
# CONSOLIDATED SCAFFOLD & BRIDGE CORP 	 CONSOLIDATED SCAFFOLD & BRIDGE CORP
# JSK CONSTRUCTION CORP 	 J.S.K. CONSTRUCTION CORP 	*
# PR 	 PR
# DAROR ASSOCIATES 	 DAROR ASSOCIATES
# MOONSHINE CONSTRUCTION 	 MOONSHINE CONSTRUCTION
# EVEREST SCAFFOLDING INC 	 EVEREST SCAFFOLDING INC. 	*
# BEN JOSEF GROUP 	 BEN JOSEF GROUP
# HPD 	 HPD
# VORNADO REALTY TRUST 	 VORNADO REALTY TRUST
# SILVERSTEIN PROPERTIES INC 	 SILVERSTEIN PROPERTIES INC. 	*
# CONSOLIDATED SCAFFOLD & BRIDGE CORP 	 CONSOLIDATED SCAFFOLD & BRIDGE CORP
# BERNSTEIN REAL ESTATE 	 BERNSTEIN REAL ESTATE
# THE BROMLEY COMPANIES 	 THE BROMLEY COMPANIES
# PR 	 PR
# nan 	 nan 	*
# NEW CITY BRIDGING CORP 	 NEW CITY BRIDGING CORP
# PR 	 PR
# PR 	 PR
# nan 	 nan 	*
# PR 	 PR
# nan 	 nan 	*
# THE ATLANTIC BKLN 	 THE ATLANTIC BKLN
# PR 	 PR
# CBRE 	 CBRE
# EVEREST SCAFFOLDING INC 	 EVEREST SCAFFOLDING INC. 	*
# ISSAC 	 ISSAC
# 133-43 35 AVE LLC 	 133-43 35 AVE LLC. 	*
# PR 	 PR
# PR 	 PR
# NYC DDC 	 NYC DDC
# ASHLAND BUILDING LLC 	 ASHLAND BUILDING LLC
# PR 	 PR
# PR 	 PR
# ALBA SERVICES INC 	 ALBA SERVICES INC
# PR 	 PR
# URBAN STANDARD CAPITAL 	 URBAN STANDARD CAPITAL
# PR 	 PR
# nan 	 nan 	*
# nan 	 nan 	*
# CONSOLIDATED SCAFFOLD & BRIDGE CORP 	 CONSOLIDATED SCAFFOLD & BRIDGE CORP
# nan 	 nan 	*
# PR 	 PR
# PARSONS CONSTRUCTION INC 	 PARSONS CONSTRUCTION INC
# AT&T 	 AT&T
# PR 	 PR
# PR 	 PR
# CONSOLIDATED SCAFFOLD & BRIDGE 	 CONSOLIDATED SCAFFOLD & BRIDGE
# UPTOWN CONSTRUCTION GROUP 	 UPTOWN CONSTRUCTION GROUP
# MUSS DEVELOPMENT LLC 	 MUSS DEVELOPMENT LLC
# SCUADRA PROPERTIES 	 SCUADRA PROPERTIES
# HOMEMADE TAQUERIA 14TH AVE 	 HOMEMADE TAQUERIA 14TH AVE. 	*
# BROADWAY BRETTON INC 	 BROADWAY BRETTON INC. 	*
# PR 	 PR
# CORE SERVICES GROUP 	 CORE SERVICES GROUP
# 13220 JAMAICA AVE BLS 	 13220 JAMAICA AVE BLS
# PR 	 PR
# EATLIKEPAUL LLC 	 EATLIKEPAUL LLC
# nan 	 nan 	*
# DEVENDRA BALKARRAN 	 DEVENDRA BALKARRAN
# FM RING ASSOCIATES INC 	 F.M. RING ASSOCIATES, INC. 	*
# PR 	 PR
# PR 	 PR
# L&L HOLDING COMPANY LLC 	 L&L HOLDING COMPANY LLC
# TITANIUM CONSTRUCTION SERVICES 	 TITANIUM CONSTRUCTION SERVICES
# COMPREHENSIVE DESIGNS 	 COMPREHENSIVE DESIGNS
# 4305735833 	 4305735833
# ASHLAND BUILDING LLC 	 ASHLAND BUILDING LLC
# BEN JOSEF GROUP 	 BEN JOSEF GROUP
# PR 	 PR
# AT&T 	 AT&T
# RUDIN MANAGEMENT CO INC 	 RUDIN MANAGEMENT CO INC
# TR DEVELOPMENT 	 TR DEVELOPMENT
# nan 	 nan 	*
# PR 	 PR
# SILVERSTEIN PROPERTIES INC 	 SILVERSTEIN PROPERTIES INC. 	*
# PR 	 PR
# SDG MANAGEMENT CORP 	 SDG MANAGEMENT CORP
# CUSHMAN AND WAKEFIELD 	 CUSHMAN AND WAKEFIELD
# NINE-G COOPERATIVE INC 	 NINE-G COOPERATIVE INC
# PR 	 PR
# EMPIRE STATE BANK 	 EMPIRE STATE BANK
# PR 	 PR
# 27E79 PROPERTY LLC 	 27E79 PROPERTY LLC
# PR 	 PR
# ======================
#
#
# column:  Approved Date
# Original,	 Cleaned
#
# 06/23/2021 12:00:00 AM 	 06/23/2021 12:00:00 AM
# 05/06/2021 12:00:00 AM 	 05/06/2021 12:00:00 AM
# 08/19/2021 12:00:00 AM 	 08/19/2021 12:00:00 AM
# 05/06/2021 12:00:00 AM 	 05/06/2021 12:00:00 AM
# 12/14/2020 12:00:00 AM 	 12/14/2020 12:00:00 AM
# 09/20/2021 12:00:00 AM 	 09/20/2021 12:00:00 AM
# 05/06/2021 12:00:00 AM 	 05/06/2021 12:00:00 AM
#
# TIMOTHY R. 	 TIMOTHY R.
# JOHN 	 JOHN
# GREGG 	 GREGG
# JOSEPH 	 JOSEPH
# SERGIY 	 SERGIY
# MANDIP 	 MANDIP
# MICHAEL 	 MICHAEL
# ARYEH 	 ARYEH
# ANDRZEJ 	 ANDRZEJ
# NEPHTALI 	 NEPHTALI
# JOHN 	 JOHN
# ARYEH 	 ARYEH
# HELEN 	 HELEN
# ABBAS 	 ABBAS
# CHRISTOPHER 	 CHRISTOPHER
# EFRAIM 	 EFRAIM
# CLEBER 	 CLEBER
# CHRISTOPHER 	 CHRISTOPHER
# JOHN 	 JOHN
# DONG WO 	 DONG WO
# KEITH 	 KEITH
# FELIX 	 FELIX
# KUZMA 	 KUZMA
# THOMAS 	 THOMAS
# ======================
#
#
# column:  Applicant Middle Name
# Original,	 Cleaned
#
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# nan 	 nan 	*
# ======================
#
#
# column:  Applicant Last Name
# Original,	 Cleaned
#
# WEISS 	 WEISS
# PERAS 	 PERAS
# WEISS 	 WEISS
# TALISSE 	 TALISSE
# TALLEY JR. 	 TALLEY JR.
# GIARRAPUTO 	 GIARRAPUTO
# DOWNES 	 DOWNES
# KOS 	 KOS
# FERNANDEZ 	 FERNANDEZ
# GANN 	 GANN
# SPINELLI 	 SPINELLI
# WEIDNER 	 WEIDNER
# LEOUTSAKOS 	 LEOUTSAKOS
# KELLY 	 KELLY
# PEDERSON 	 PEDERSON
# DIMAGGIO 	 DIMAGGIO
# KELLY 	 KELLY
# KOMAL 	 KOMAL
# HE 	 HE
# BRAUN 	 BRAUN
# MITCHELL 	 MITCHELL
# DOWNES 	 DOWNES
# ASSOULINE 	 ASSOULINE
# SINGH 	 SINGH
# CONWAY 	 CONWAY
# LUPINO 	 LUPINO
# KELLY 	 KELLY
# LEVINE 	 LEVINE
# CHIN 	 CHIN
# SCULLY 	 SCULLY
# LUO 	 LUO
# RIZWAN 	 RIZWAN
# LINDGREN 	 LINDGREN
# ZHANG 	 ZHANG
# HE 	 HE
# TSAMPAS 	 TSAMPAS
# ROCKHILL 	 ROCKHILL
# BOEGEMANN 	 BOEGEMANN
# RUSI 	 RUSI
# BRAGOLI 	 BRAGOLI
# DOWNES 	 DOWNES
# JACCARINO 	 JACCARINO
# JUNG 	 JUNG
# LINDGREN 	 LINDGREN
# LOMBARDO 	 LOMBARDO
# KLEIN 	 KLEIN
# DIMAGGIO 	 DIMAGGIO
# CHEN 	 CHEN
# LOMBARDO 	 LOMBARDO
# REDDY 	 REDDY
# MANSOUR 	 MANSOUR
# STAMBOULIS 	 STAMBOULIS
# MANSOUR 	 MANSOUR
# LENARD 	 LENARD
# CALLER 	 CALLER
# KELLY 	 KELLY
# POPIJAKOWSKA 	 POPIJAKOWSKA
# ASSOULINE 	 ASSOULINE
# KAUR 	 KAUR
# VARGAS 	 VARGAS
# WEIDNER 	 WEIDNER
# LOMBARDO 	 LOMBARDO
# KELLY 	 KELLY
# PACIULLO 	 PACIULLO
# ZOLLER 	 ZOLLER
# RAHMAN 	 RAHMAN
# JIMENEZ 	 JIMENEZ
# NIEVES 	 NIEVES
# MEENA 	 MEENA
# BROWN 	 BROWN
# ZHENG 	 ZHENG
# CHEN 	 CHEN
# LOMBARDO 	 LOMBARDO
# WONG 	 WONG
# THOMPSON 	 THOMPSON
# TOMAI, JR. 	 TOMAI, JR.
# WULFING 	 WULFING
# BORDONE 	 BORDONE
# GENOVESE 	 GENOVESE
# SENNA 	 SENNA
# MAMUSHKIN 	 MAMUSHKIN
# KAUR 	 KAUR
# DIMAGGIO 	 DIMAGGIO
# ASSOULINE 	 ASSOULINE
# CZECHOWSKI 	 CZECHOWSKI
# VARGAS 	 VARGAS
# MACCARONE 	 MACCARONE
# ASSOULINE 	 ASSOULINE
# ANDREADIS 	 ANDREADIS
# MALIK 	 MALIK
# LUPINO 	 LUPINO
# KAZTOW 	 KAZTOW
# CAMPOVERDE 	 CAMPOVERDE
# ASARO 	 ASARO
# TSAMPAS 	 TSAMPAS
# LIANG 	 LIANG
# CUMMINGS 	 CUMMINGS
# VASQUEZ 	 VASQUEZ
# KUCIC 	 KUCIC
# HART 	 HART
# ======================
#
#
# column:  Applicant Business Name
# Original,	 Cleaned
#
# MANHATTAN D ENTERPRISES 	 MANHATTAN D ENTERPRISES
# ULTIMATE SIGNS&DESIGNS CO 	 ULTIMATE SIGNS&DESIGNS CO
# MANHATTAN D ENTERPRISES 	 MANHATTAN D ENTERPRISES
# CS BRIDGE CORP 	 CS BRIDGE CORP
# ALL CITY MECHANICAL INC 	 ALL CITY MECHANICAL INC
# L.S. SIGN CO., INC 	 L.S. SIGN CO., INC
# EVEREST SCAFFOLDING INC 	 EVEREST SCAFFOLDING INC
# UNIPIPE PLBG&HTG CORP 	 UNIPIPE PLBG&HTG CORP
# FERNANDEZ HTG & MECH CORP 	 FERNANDEZ HTG & MECH CORP
# 7376 CONSTRUCTION LLC 	 7376 CONSTRUCTION LLC
# VMC PLUMBING & HEATING IN 	 VMC PLUMBING & HEATING IN
# TRI STATE PLBG & HTG INC 	 TRI STATE PLBG & HTG INC
# PEAK FIRE PROTECTION LLC 	 PEAK FIRE PROTECTION LLC
# CONSOLIDATED SCAFFOLDING 	 CONSOLIDATED SCAFFOLDING
# V & M DRAIN CLEANING INC 	 V & M DRAIN CLEANING INC
# K.M.D. MCHNCL 1443 LLC 	 K.M.D. MCHNCL 1443 LLC
# CONSOLIDATED SCAFFOLDING 	 CONSOLIDATED SCAFFOLDING
# J.S.K. CONSTRUCTION CORP 	 J.S.K. CONSTRUCTION CORP
# HIGH QUALITY CONSTRUCTION 	 HIGH QUALITY CONSTRUCTION
# BRAUN MANAGEMENT INC 	 BRAUN MANAGEMENT INC
# A. M. PLUMBING COMPANY 	 A. M. PLUMBING COMPANY
# EVEREST SCAFFOLDING INC 	 EVEREST SCAFFOLDING INC
# IMPACT BUILDERS CORP 	 IMPACT BUILDERS CORP
# LAKHI GENERAL CONTRACTOR 	 LAKHI GENERAL CONTRACTOR
# AMBASSADOR CONSTRUCTION C 	 AMBASSADOR CONSTRUCTION C
# AGGRESSIVE FIRE PROT LLC 	 AGGRESSIVE FIRE PROT LLC
# CONSOLIDATED SCAFFOLDING 	 CONSOLIDATED SCAFFOLDING
# PAR PLUMBING CO., INC 	 PAR PLUMBING CO., INC
# GOOD-WILL MECHANICAL CORP 	 GOOD-WILL MECHANICAL CORP
# SCULLY CONSTRUCTION LLC 	 SCULLY CONSTRUCTION LLC
# FLUSHING ONE CONSTRUCTION 	 FLUSHING ONE CONSTRUCTION
# NEW CITY BRIDGING CORP 	 NEW CITY BRIDGING CORP
# LAWRENCE EXTERIOR RESTORA 	 LAWRENCE EXTERIOR RESTORA
# SPLEN CONSTRUCTION INC 	 SPLEN CONSTRUCTION INC
# HIGH QUALITY CONSTRUCTION 	 HIGH QUALITY CONSTRUCTION
# SKYLINE RESTORATION INC 	 SKYLINE RESTORATION INC
# HATCHET WORKS CORP 	 HATCHET WORKS CORP
# PAUL SIGNS, INC 	 PAUL SIGNS, INC
# BENJAMIN GROUP ENTERPRIS 	 BENJAMIN GROUP ENTERPRIS
# NATIONAL MAINTENANCE, INC 	 NATIONAL MAINTENANCE, INC
# EVEREST SCAFFOLDING INC 	 EVEREST SCAFFOLDING INC
# QBK PLUMBING & HTNG INC 	 QBK PLUMBING & HTNG INC
# URBAN GC INC 	 URBAN GC INC
# LAWRENCE EXTERIOR RESTORA 	 LAWRENCE EXTERIOR RESTORA
# PIPING & PLUMBING SOLUTIO 	 PIPING & PLUMBING SOLUTIO
# THE FRANKLIN COMANY CONT* 	 THE FRANKLIN COMANY CONT*
# K.M.D. MCHNCL 1443 LLC 	 K.M.D. MCHNCL 1443 LLC
# LOXTON INC 	 LOXTON INC
# PIPING & PLUMBING SOLUTIO 	 PIPING & PLUMBING SOLUTIO
# CITI STRUCTURE LLC 	 CITI STRUCTURE LLC
# BUILDERS JOSEPH AND SONS 	 BUILDERS JOSEPH AND SONS
# BOULIS CONSTRUCTION CORP 	 BOULIS CONSTRUCTION CORP
# BUILDERS JOSEPH AND SONS 	 BUILDERS JOSEPH AND SONS
# TRIBUTE RESTORATION INC 	 TRIBUTE RESTORATION INC
# MARCAL CONTRACTING CO LLC 	 MARCAL CONTRACTING CO LLC
# CONSOLIDATED SCAFFOLDING 	 CONSOLIDATED SCAFFOLDING
# EURO ART CONSTRUCTION COR 	 EURO ART CONSTRUCTION COR
# IMPACT BUILDERS CORP 	 IMPACT BUILDERS CORP
# PARSONS CONSTRUCTION INC 	 PARSONS CONSTRUCTION INC
# OVERLAND CONTRACTING INC 	 OVERLAND CONTRACTING INC
# DW PLUMBING INC 	 DW PLUMBING INC
# PIPING & PLUMBING SOLUTIO 	 PIPING & PLUMBING SOLUTIO
# CONSOLIDATED SCAFFOLDING 	 CONSOLIDATED SCAFFOLDING
# UPTOWN CONSTRUCTION GROUP 	 UPTOWN CONSTRUCTION GROUP
# JAYEFF CONSTRUCTION CORP 	 JAYEFF CONSTRUCTION CORP
# HYPER STRUCTURE CORP 	 HYPER STRUCTURE CORP
# DONE RIGHT KITCHEN EXHAUS 	 DONE RIGHT KITCHEN EXHAUS
# EL-ROC CONTRACTING OF BK 	 EL-ROC CONTRACTING OF BK
# HUDSON BLACK INC 	 HUDSON BLACK INC
# CORE FACILITIES MGMT LLC 	 CORE FACILITIES MGMT LLC
# COS CONSTRUCTION INC 	 COS CONSTRUCTION INC
# CK COOLING & HEATING INC 	 CK COOLING & HEATING INC
# EMPIRE PLUMBING INC 	 EMPIRE PLUMBING INC
# A.A. MECHANICAL SOL INC 	 A.A. MECHANICAL SOL INC
# KISHAN PLBG & HEATING INC 	 KISHAN PLBG & HEATING INC
# SIGNATURE CONSTRUCTION GR 	 SIGNATURE CONSTRUCTION GR
# WULFING CONSTRUCTION LLC 	 WULFING CONSTRUCTION LLC
# WCD SERVICES CORP 	 WCD SERVICES CORP
# RIDGE CONSTRUCTION CORP 	 RIDGE CONSTRUCTION CORP
# TITANIUM CONSTRUCTION SER 	 TITANIUM CONSTRUCTION SER
# GW MECHANICAL CORP 	 GW MECHANICAL CORP
# PLATINUM SERVICES NY LLC 	 PLATINUM SERVICES NY LLC
# K.M.D. MCHNCL 1443 LLC 	 K.M.D. MCHNCL 1443 LLC
# IMPACT BUILDERS CORP 	 IMPACT BUILDERS CORP
# AJC PLUMBING & HTG CORP 	 AJC PLUMBING & HTG CORP
# OVERLAND CONTRACTING INC 	 OVERLAND CONTRACTING INC
# MACCARONE PLUMBING INC 	 MACCARONE PLUMBING INC
# IMPACT BUILDERS CORP 	 IMPACT BUILDERS CORP
# MASTERPIECE S.A. CORP 	 MASTERPIECE S.A. CORP
# K.E.S CONSTRUCTION CO INC 	 K.E.S CONSTRUCTION CO INC
# AGGRESSIVE FIRE PROT LLC 	 AGGRESSIVE FIRE PROT LLC
# KEY PLBNG & HTG SOL CORP 	 KEY PLBNG & HTG SOL CORP
# PEAK PLUMBING SOLUTIONS L 	 PEAK PLUMBING SOLUTIONS L
# HOLT CONSTRUCTION CORP 	 HOLT CONSTRUCTION CORP
# SKYLINE RESTORATION INC 	 SKYLINE RESTORATION INC
# CUBE BUILDERS GROUP NY 	 CUBE BUILDERS GROUP NY
# KCM PLUMBING & HEATING CO 	 KCM PLUMBING & HEATING CO
# NOVA VASQUEZ & ASSOCIATES 	 NOVA VASQUEZ & ASSOCIATES
# JULIAN SPRINKLER CORP 	 JULIAN SPRINKLER CORP
# DART RESTORATION CORP 	 DART RESTORATION CORP
# ======================
#
#
# column:  Applicant Business Address
# Original,	 Cleaned
#
# 111-07 101ST AVENUE 	 111-07 101ST AVENUE
# 13709 EASTGATE PLAZA 	 13709 EASTGATE PLAZA
# 111-07 101ST AVENUE 	 111-07 101ST AVENUE
# 1470 BRUCKNER BLVD 	 1470 BRUCKNER BLVD
# 521 BROOKLYN AVENUE 	 521 BROOKLYN AVENUE
# 16-40 CENTRE STREET 	 16-40 CENTRE STREET
# 1150 LONGWOOD AVE 	 1150 LONGWOOD AVE
# 37 CUMBERLAND STREET 	 37 CUMBERLAND STREET
# 241-15 BRADDOCK AVENUE 	 241-15 BRADDOCK AVENUE
# 200 BUSINESS PARK DR STE 203 	 200 BUSINESS PARK DR STE 203
# 838 BAY STREET 	 838 BAY STREET
# 33-70 PRINCE STREET, SUITE 706 	 33-70 PRINCE STREET, SUITE 706
# 191 DUPONT STREET 	 191 DUPONT STREET
# 3969 MERRITT AVE 	 3969 MERRITT AVE
# 422 CASTLETON AVENUE 	 422 CASTLETON AVENUE
# 105 STUYVESANT PL 	 105 STUYVESANT PL
# 3969 MERRITT AVE 	 3969 MERRITT AVE
# 430 MERRICK ROAD SUITE #5 	 430 MERRICK ROAD SUITE #5
# 7218 16TH AVENUE 	 7218 16TH AVENUE
# 160 BROADWAY 	 160 BROADWAY
# 4040 HYLAN BLVD 	 4040 HYLAN BLVD
# 1150 LONGWOOD AVE 	 1150 LONGWOOD AVE
# 10206 METROPOLITAN AVE STORE #2 	 10206 METROPOLITAN AVE STORE #2
# 15410 ROCKAWAY BLVD 	 15410 ROCKAWAY BLVD
# 105 MADISON AVENUE 	 105 MADISON AVENUE
# 45 WEST 25TH STREET 	 45 WEST 25TH STREET
# 3969 MERRITT AVE 	 3969 MERRITT AVE
# 101 PARK AVENUE LOWER LOBBY 	 101 PARK AVENUE LOWER LOBBY
# 1000 GRAND ST 	 1000 GRAND ST
# 141 LAFAYETTE AVENUE 	 141 LAFAYETTE AVENUE
# 37-12 PRINCE ST, STE 8C 	 37-12 PRINCE ST, STE 8C
# 2915 THROOP AVE 	 2915 THROOP AVE
# 150-44 11TH AVENUE 	 150-44 11TH AVENUE
# 29 FIELDSTONE DRIVE 	 29 FIELDSTONE DRIVE
# 7218 16TH AVENUE 	 7218 16TH AVENUE
# 49-28 31ST PLACE 	 49-28 31ST PLACE
# 628 GRAND AVE 	 628 GRAND AVE
# 654 4TH AVENUE 	 654 4TH AVENUE
# 104 22ND STEET 	 104 22ND STEET
# 23-41 BORDEN AVENUE 	 23-41 BORDEN AVENUE
# 1150 LONGWOOD AVE 	 1150 LONGWOOD AVE
# 92-14 LIBERTY AVENUE 	 92-14 LIBERTY AVENUE
# 150-15 41ST AVE APT 3C 	 150-15 41ST AVE APT 3C
# 150-44 11TH AVENUE 	 150-44 11TH AVENUE
# 4601C 1ST AVENUE#C 	 4601C 1ST AVENUE#C
# 22-44 119TH STREET 	 22-44 119TH STREET
# 105 STUYVESANT PL 	 105 STUYVESANT PL
# 136-31 41ST AVENUE SUITE 2A 	 136-31 41ST AVENUE SUITE 2A
# 4601C 1ST AVENUE#C 	 4601C 1ST AVENUE#C
# 44 HUDSON PLACE 2ND FLOOR 	 44 HUDSON PLACE 2ND FLOOR
# 1222 AVENUE M SUITE 505 	 1222 AVENUE M SUITE 505
# 40-43 100TH STREET, SUITE1 	 40-43 100TH STREET, SUITE1
# 1222 AVENUE M SUITE 505 	 1222 AVENUE M SUITE 505
# 231 NORMAN STREET#206 	 231 NORMAN STREET#206
# 2361 NOSTRAND AVENUE SUITE 901 	 2361 NOSTRAND AVENUE SUITE 901
# 3969 MERRITT AVE 	 3969 MERRITT AVE
# 71 WOLCOTT RD 2ND FL 	 71 WOLCOTT RD 2ND FL
# 10206 METROPOLITAN AVE STORE #2 	 10206 METROPOLITAN AVE STORE #2
# 179-36 HILLSIDE AVE 	 179-36 HILLSIDE AVE
# 600 NORTH GREENFIELD PARKWAY 	 600 NORTH GREENFIELD PARKWAY
# 33-70 PRINCE STREET, SUITE 706 	 33-70 PRINCE STREET, SUITE 706
# 4601C 1ST AVENUE#C 	 4601C 1ST AVENUE#C
# 3969 MERRITT AVE 	 3969 MERRITT AVE
# 268 S HARRISON AVE 	 268 S HARRISON AVE
# 1800 ROUTE 34 SUITE 403 	 1800 ROUTE 34 SUITE 403
# 1562 PACIFIC STREET 	 1562 PACIFIC STREET
# 107-63 121 STREET 	 107-63 121 STREET
# 140 18TH STREET 	 140 18TH STREET
# 270 SPARTA AVE.STE 104 	 270 SPARTA AVE.STE 104
# 45 MAIN STREET STE 711 	 45 MAIN STREET STE 711
# 39-15 MAIN STREET, STE #308 	 39-15 MAIN STREET, STE #308
# 25417 38TH AVENUE 	 25417 38TH AVENUE
# 4601C 1ST AVENUE 	 4601C 1ST AVENUE
# 168 COOK STREET 	 168 COOK STREET
# 112-15 FRANCIS LEWIS BLVD 	 112-15 FRANCIS LEWIS BLVD
# 160 7TH STREET 	 160 7TH STREET
# 1B CARROLL STREET 	 1B CARROLL STREET
# 58-60 57TH STREET 	 58-60 57TH STREET
# 280 TOWNE CENTER DRIVE, BLDG1 	 280 TOWNE CENTER DRIVE, BLDG1
# 247 W 30TH STREET FL 11 	 247 W 30TH STREET FL 11
# 854 HUMBOLDT STREET 	 854 HUMBOLDT STREET
# 53-28 11TH STREET 2ND FL 	 53-28 11TH STREET 2ND FL
# 105 STUYVESANT PL 	 105 STUYVESANT PL
# 10206 METROPOLITAN AVE STORE #2 	 10206 METROPOLITAN AVE STORE #2
# 37-28 61ST STREET 	 37-28 61ST STREET
# 600 NORTH GREENFIELD PARKWAY 	 600 NORTH GREENFIELD PARKWAY
# 199-02 32ND AVENUE 	 199-02 32ND AVENUE
# 10206 METROPOLITAN AVE STORE #2 	 10206 METROPOLITAN AVE STORE #2
# 18-57 41 ST 	 18-57 41 ST
# 15 SWAN STREET 	 15 SWAN STREET
# 45 WEST 25TH STREET 	 45 WEST 25TH STREET
# 252 JAVA STREET, SUITE 308 B 	 252 JAVA STREET, SUITE 308 B
# 191 DUPONT STREET 	 191 DUPONT STREET
# 50 EAST WASHINGTON AVENUE 	 50 EAST WASHINGTON AVENUE
# 49-28 31ST PLACE 	 49-28 31ST PLACE
# 217 BAY 28TH ST 	 217 BAY 28TH ST
# 198 PULASKI AVENUE 	 198 PULASKI AVENUE
# 414 PALISADE AVENUE 	 414 PALISADE AVENUE
# 1324 HERSCHELL STREET 	 1324 HERSCHELL STREET
# 365 SOUTH MAIN STREET 	 365 SOUTH MAIN STREET
# ======================

# %%
tp = 119
fp = 3

fn = 25
tn = 1500 - 119 - 3 - 25

# %%
precision(tp, fp)
# Out:
# 0.9754098360655737

# %%
recall(tp,fn)
# Out:
# 0.8263888888888888
